# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library
from sklearn.model_selection import train_test_split

# 사용할 주식 티커 목록
tickers = [
    "GM"
]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2018-01-01', end='2024-01-01')
    df['ticker'] = ticker  # 티커 열 추가

    # 이동 평균 (Moving Average)

    # 상대 강도 지수 (RSI: Relative Strength Index)
    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

    # MACD (Moving Average Convergence Divergence)
    macd = ta.trend.MACD(df['Close'])

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(df['Close'], window=20, window_dev=2)
    df['BB_High'] = bollinger.bollinger_hband()
    df['BB_Low'] = bollinger.bollinger_lband()
    df['BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    df['RSI'].fillna(df['RSI'].mean(), inplace=True)
    df['BB_High'].fillna(df['BB_High'].mean(), inplace=True)
    df['BB_Low'].fillna(df['BB_Low'].mean(), inplace=True)
    df['BB_Middle'].fillna(df['BB_Middle'].mean(), inplace=True)

    data[ticker] = df

# 여러 데이터프레임을 하나로 결합
combined_df = pd.concat(data.values(), ignore_index=False)

# 필요한 열 선택 (모든 feature 포함)
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'BB_High', 'BB_Low', 'BB_Middle', 'ticker']
combined_df = combined_df[features]

# 'Date'를 인덱스로 설정 (필요한 경우)
combined_df.index.name = 'Date'

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df, test_df = train_test_split(combined_df, test_size=0.3, shuffle=False)

print("Train Set:")
print(train_df.head())
print("Test Set:")
print(test_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Train Set:
#                  Open       High        Low      Close    Volume        RSI  \
# Date
# 2018-01-02  41.240002  41.869999  41.150002  41.799999   6934600  49.596247
# 2018-01-03  42.209999  42.950001  42.200001  42.820000  14591600  49.596247
# 2018-01-04  43.090000  44.250000  43.009998  44.139999  17298700  49.596247
# 2018-01-05  44.500000  44.639999  43.959999  44.009998   9643300  49.596247
# 2018-01-08  44.040001  44.590000  43.520000  44.220001  13099600  49.596247
#
#               BB_High     BB_Low  BB_Middle ticker
# Date
# 2018-01-02  42.560135  36.328955  39.444545     GM
# 2018-01-03  42.560135  36.328955  39.444545     GM
# 2018-01-04  42.560135  36.328955  39.444545     GM
# 2018-01-05  42.560135  36.328955  39.444545     GM
# 2018-01-08  42.560135  36.328955  39.444545     GM
# Test Set:
#                  Open       High        Low      Close    Volume        RSI  \
# Date
# 2022-03-14  41.740002  42.430000  40.369999  40.830002  18914000  32.089921
# 2022-03-15  40.830002  42.250000  40.799999  42.130001  16051000  37.503388
# 2022-03-16  43.000000  44.169998  42.369999  43.849998  17014500  43.877868
# 2022-03-17  42.919998  43.830002  42.599998  43.660000  13909000  43.351846
# 2022-03-18  43.230000  45.040001  43.130001  44.820000  19834400  47.490753
#
#               BB_High     BB_Low  BB_Middle ticker
# Date
# 2022-03-14  51.701181  38.719820    45.2105     GM
# 2022-03-15  51.346738  38.447263    44.8970     GM
# 2022-03-16  50.682457  38.529543    44.6060     GM
# 2022-03-17  49.731948  38.803052    44.2675     GM
# 2022-03-18  49.128744  39.006256    44.0675     GM

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import configure
import torch
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

cumu_lst = []
cumu_hap = 0

class StockTradingEnv(gym.Env):
    global cumu_lst, cumu_hap
    metadata = {'render.modes': ['human']}

    def __init__(self, df, initial_balance=100000):
        super(StockTradingEnv, self).__init__()

        self.df = df.drop(columns=['ticker'])  # ticker 열 제거
        self.action_space = spaces.Discrete(3)  # Buy, Hold, Sell
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(len(self.df.columns),), dtype=np.float32)

        self.initial_balance = initial_balance
        self.reset()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.total_profit = 0
        self.inventory = []
        self.balance = self.initial_balance
        self.state = self.df.iloc[self.current_step].values
        self.returns = [0]

        return self.state

    def step(self, action):
        global cumu_lst
        self.done = self.current_step >= len(self.df) - 1
        reward = 0
        additional_reward = 0

        if action == 0 and not self.done:  # Buy
            if self.balance >= self.state[3]:  # Check if balance is sufficient to buy
                self.inventory.append(self.state[3])  # Close price
                self.balance -= self.state[3]

        elif action == 1 and not self.done:  # Sell
            if len(self.inventory) > 0:
                bought_price = self.inventory.pop(0)
                reward = self.state[3] - bought_price  # Current price - Bought price
                self.total_profit += reward
                self.balance += self.state[3]

        # 추가된 보상 요소들
        if self.state[5] >= 70 and action == 1:  # RSI가 70 이상일 때 매도
            additional_reward += 1
        elif self.state[5] <= 30 and action == 0:  # RSI가 30 이하일 때 매수
            additional_reward += 1

        if self.state[3] >= self.state[6] and action == 1:  # 주가가 BB 상한선 이상일 때 매도
            additional_reward += 1
        elif self.state[3] <= self.state[7] and action == 0:  # 주가가 BB 하한선 이하일 때 매수
            additional_reward += 1

        if self.state[4] > self.df['Volume'].mean() and (action == 0 or action == 1):  # 거래량이 평균 이상일 때 매수 또는 매도
            additional_reward += 1

        total_reward = reward + additional_reward

        # Sharpe Ratio
        if len(self.returns) > 1:
            sharpe_ratio = np.mean(self.returns) / (np.std(self.returns) + 1e-10)
        else:
            sharpe_ratio = 0

        # Drawdown
        peak = np.max(self.returns)
        drawdown = peak - self.returns[-1]

        # 정규화된 Sharpe Ratio와 Drawdown
        normalized_sharpe = np.tanh(sharpe_ratio)  # -1에서 1 사이로 정규화
        normalized_drawdown = np.tanh(drawdown)  # -1에서 1 사이로 정규화

        # 스케일링 팩터
        sharpe_scale = 0.5
        drawdown_scale = 0.5

        # 보상 함수에 샤프 비율과 드로우다운 포함
        stability_bonus = sharpe_scale * normalized_sharpe - drawdown_scale * normalized_drawdown
        total_reward += stability_bonus

        # Update returns
        self.returns.append(total_reward)

        if not self.done:
            self.current_step += 1
            self.state = self.df.iloc[self.current_step].values
        else:
            self.state = np.zeros(self.observation_space.shape)  # Done 상태에서 반환할 값
            cumu_lst.append(self.total_profit)
            self.total_profit = 0

        return self.state, total_reward, self.done, {"reward": total_reward, "additional_reward": additional_reward, "sharpe_ratio": sharpe_ratio, "drawdown": drawdown, "stability_bonus": stability_bonus}

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}, Balance: {self.balance}, Total Profit: {self.total_profit}, Sharpe Ratio: {np.mean(self.returns) / np.std(self.returns) if len(self.returns) > 1 else 0}, Drawdown: {(self.max_balance - self.balance) / self.max_balance}')


class EvalCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(EvalCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.action_distribution = []
        self.state_visit_frequency = {}
        self.cumulative_rewards = []  # 누적 보상을 저장하기 위한 리스트

    def _on_step(self) -> bool:
        # Record current step action for action distribution analysis
        self.action_distribution.append(self.locals["actions"])
        # Record state visit frequency
        state_str = str(self.locals["new_obs"])
        if state_str in self.state_visit_frequency:
            self.state_visit_frequency[state_str] += 1
        else:
            self.state_visit_frequency[state_str] = 1
        return True

    def _on_rollout_end(self) -> None:
        # Log the reward and length for each episode
        episode_reward = sum(self.locals["rewards"])
        episode_length = len(self.locals["rewards"])
        self.episode_rewards.append(episode_reward)
        self.episode_lengths.append(episode_length)
        self.cumulative_rewards.append(sum(self.episode_rewards))  # 누적 보상을 추가
        self.logger.record('rollout/episode_reward', np.sum(self.episode_rewards))
        self.logger.record('rollout/episode_length', np.sum(self.episode_lengths))

    def _on_training_end(self) -> None:
        # Save evaluation results to file or print them
        print(f"Mean episode reward: {np.mean(self.episode_rewards)}")
        print(f"Mean episode length: {np.mean(self.episode_lengths)}")
        print(f"Cumulative reward: {np.sum(self.episode_rewards)}")

        # Plot action distribution
        plt.figure(figsize=(12, 6))
        plt.hist(self.action_distribution, bins=3, align='left', rwidth=0.8)
        plt.xticks(range(3), ['Buy', 'Hold', 'Sell'])
        plt.xlabel('Actions')
        plt.ylabel('Frequency')
        plt.title('Action Distribution')
        plt.show()

        # Plot episode rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.episode_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Episode Reward')
        plt.title('Episode Reward over Episodes')
        plt.show()

        # Plot cumulative rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.cumulative_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Cumulative Reward')
        plt.title('Cumulative Reward over Episodes')
        plt.show()

        # Plot state visit frequency
        state_visit_sorted = sorted(self.state_visit_frequency.items(), key=lambda item: item[1], reverse=True)
        states, visits = zip(*state_visit_sorted)
        plt.figure(figsize=(12, 6))
        plt.bar(states[:10], visits[:10])
        plt.xlabel('States')
        plt.ylabel('Visit Frequency')
        plt.title('Top 10 Most Visited States')
        plt.show()

# 데이터 로드 및 train/test 분할
train_df, test_df = train_test_split(df, test_size=0.3, shuffle=False)

# 학습 환경 설정
train_env = DummyVecEnv([lambda: StockTradingEnv(train_df)])

# CUDA 사용 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
log_dir = "./ppo_stock_trading_v11"
os.makedirs(log_dir, exist_ok=True)
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# PPO 모델 학습
from stable_baselines3.common.callbacks import CheckpointCallback

# 체크포인트 저장 콜백 설정 (예: 10000 타임스텝마다 저장)
checkpoint_callback = CheckpointCallback(save_freq=20000, save_path='./GM/GM_Checkpoint_6/',
                                         name_prefix='ppo_stock_trading')

# PPO 모델 학습
# model = PPO('MlpPolicy', train_env, learning_rate=0.0003, n_steps=2048, batch_size=64, n_epochs=10, gamma=0.99, verbose=1, device=device)
model = PPO('MlpPolicy', train_env, verbose=1, device=device)

model.set_logger(new_logger)

# 'stable_baselines3' 모듈에 임시로 '__version__' 속성을 추가합니다.
# import stable_baselines3 as sb3
# sb3.__version__ = "1.0.0"

model.learn(total_timesteps=200000, callback=[checkpoint_callback, EvalCallback()])

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 학습된 모델로 예측 및 결과 시각화
obs = test_env.reset()
total_rewards = 0
total_additional_rewards = 0
total_stability_bonus = 0

for _ in range(len(test_df)):
    action, _states = model.predict(obs)
    obs, rewards, done, info = test_env.step(action)
    total_rewards += info[0]['reward']
    total_additional_rewards += info[0]['additional_reward']
    total_stability_bonus += info[0]['stability_bonus']
    test_env.render()
    if done:
        break

print(f"Final Balance: {test_env.get_attr('balance')[0]}")
print(f"Total Profit: {test_env.get_attr('total_profit')[0]}")
print(f"Total Rewards: {total_rewards}")
print(f"Total Additional Rewards: {total_additional_rewards}")
print(f"Total Stability Bonus: {total_stability_bonus}")
print(f"profit: {total_rewards - total_additional_rewards - total_stability_bonus}")

# TensorBoard 로그 파일을 로컬에서 실행
# !tensorboard --logdir ./ppo_stock_trading
# Out:
# Logging to ./ppo_stock_trading_v11
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    episode_length  | 1        |
# |    episode_reward  | -0.389   |
# | time/              |          |
# |    fps             | 318      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 2           |
# |    episode_reward       | 1.96        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008313921 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 185         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 561         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 3           |
# |    episode_reward       | 1.66        |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011332275 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00784    |
# |    value_loss           | 149         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 4           |
# |    episode_reward       | 3.78        |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015432042 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00758    |
# |    value_loss           | 61.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 5           |
# |    episode_reward       | 3.68        |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 5           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006709735 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.972      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 71          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 6           |
# |    episode_reward       | 4.65        |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 6           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013432606 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00919    |
# |    value_loss           | 97.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 7           |
# |    episode_reward       | 7.15        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 7           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009871873 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.762      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00767    |
# |    value_loss           | 79.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 8           |
# |    episode_reward       | 8.19        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 8           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007432485 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 95.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 9           |
# |    episode_reward       | 9.19        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 9           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005421486 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.6        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 10           |
# |    episode_reward       | 11.4         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 10           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0041771843 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.485       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.2         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00381     |
# |    value_loss           | 98.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 11           |
# |    episode_reward       | 13.2         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 11           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0029334398 |
# |    clip_fraction        | 0.00767      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.3         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00078     |
# |    value_loss           | 91.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 12           |
# |    episode_reward       | 14.2         |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 12           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0030576377 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.6         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 95.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 13           |
# |    episode_reward       | 15.3         |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 13           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0019116431 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.305       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.6         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 92.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 14          |
# |    episode_reward       | 16.4        |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 14          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.001634798 |
# |    clip_fraction        | 0.00264     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.269      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.6        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.000307   |
# |    value_loss           | 105         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 15           |
# |    episode_reward       | 17.4         |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 15           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0015189986 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.4         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -2.69e-05    |
# |    value_loss           | 91.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 16           |
# |    episode_reward       | 18.5         |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 16           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0015026098 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.204       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.7         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 111          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 17            |
# |    episode_reward       | 20.9          |
# | time/                   |               |
# |    fps                  | 235           |
# |    iterations           | 17            |
# |    time_elapsed         | 147           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00040808163 |
# |    clip_fraction        | 0.0227        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.12         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 17.2          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | 0.000893      |
# |    value_loss           | 117           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 18           |
# |    episode_reward       | 22           |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 18           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0018149086 |
# |    clip_fraction        | 0.00752      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.139       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 84.6         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000519    |
# |    value_loss           | 85.9         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 19            |
# |    episode_reward       | 24.5          |
# | time/                   |               |
# |    fps                  | 234           |
# |    iterations           | 19            |
# |    time_elapsed         | 165           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00059950794 |
# |    clip_fraction        | 0.0169        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.112        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 19.5          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00163      |
# |    value_loss           | 129           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 20          |
# |    episode_reward       | 26.7        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 20          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.000454002 |
# |    clip_fraction        | 0.00913     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0931     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000208   |
# |    value_loss           | 122         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 21           |
# |    episode_reward       | 27.7         |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 21           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0013138079 |
# |    clip_fraction        | 0.00459      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0893      |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.7         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 6.9e-05      |
# |    value_loss           | 123          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 22            |
# |    episode_reward       | 28.7          |
# | time/                   |               |
# |    fps                  | 234           |
# |    iterations           | 22            |
# |    time_elapsed         | 191           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00029779514 |
# |    clip_fraction        | 0.0062        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0671       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 45            |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000881     |
# |    value_loss           | 124           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 23            |
# |    episode_reward       | 29.8          |
# | time/                   |               |
# |    fps                  | 234           |
# |    iterations           | 23            |
# |    time_elapsed         | 200           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00042207137 |
# |    clip_fraction        | 0.00425       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0687       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 56.7          |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000499     |
# |    value_loss           | 134           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 24            |
# |    episode_reward       | 30.8          |
# | time/                   |               |
# |    fps                  | 234           |
# |    iterations           | 24            |
# |    time_elapsed         | 209           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00017202154 |
# |    clip_fraction        | 0.00342       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0697       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 58.2          |
# |    n_updates            | 230           |
# |    policy_gradient_loss | 0.00026       |
# |    value_loss           | 135           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 25           |
# |    episode_reward       | 31.9         |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 25           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0005819585 |
# |    clip_fraction        | 0.00786      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0601      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.2         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000459    |
# |    value_loss           | 141          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 26           |
# |    episode_reward       | 32.9         |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 26           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0018166844 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0719      |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.6         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 3.06e-05     |
# |    value_loss           | 145          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 27           |
# |    episode_reward       | 34           |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 27           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0002270941 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0811      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 148          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 1.57e-05     |
# |    value_loss           | 136          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 28            |
# |    episode_reward       | 35            |
# | time/                   |               |
# |    fps                  | 232           |
# |    iterations           | 28            |
# |    time_elapsed         | 246           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00045924162 |
# |    clip_fraction        | 0.00342       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.094        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 159           |
# |    n_updates            | 270           |
# |    policy_gradient_loss | 0.000307      |
# |    value_loss           | 135           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 29            |
# |    episode_reward       | 36.1          |
# | time/                   |               |
# |    fps                  | 230           |
# |    iterations           | 29            |
# |    time_elapsed         | 257           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 1.0518823e-05 |
# |    clip_fraction        | 0.00347       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0588       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 29.9          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000149     |
# |    value_loss           | 138           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 30           |
# |    episode_reward       | 37.1         |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 30           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0006667966 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0531      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000558    |
# |    value_loss           | 144          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 31            |
# |    episode_reward       | 38.5          |
# | time/                   |               |
# |    fps                  | 232           |
# |    iterations           | 31            |
# |    time_elapsed         | 272           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00039558925 |
# |    clip_fraction        | 0.00439       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0557       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 219           |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000164     |
# |    value_loss           | 152           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 32            |
# |    episode_reward       | 39.6          |
# | time/                   |               |
# |    fps                  | 233           |
# |    iterations           | 32            |
# |    time_elapsed         | 280           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00075388025 |
# |    clip_fraction        | 0.00762       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0477       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 25.1          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.00143      |
# |    value_loss           | 147           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 33          |
# |    episode_reward       | 41.9        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 33          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.000296576 |
# |    clip_fraction        | 0.00542     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0344     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 180         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000421   |
# |    value_loss           | 153         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 34            |
# |    episode_reward       | 44.4          |
# | time/                   |               |
# |    fps                  | 235           |
# |    iterations           | 34            |
# |    time_elapsed         | 295           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 5.7690893e-05 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.038        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 50.8          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -6.12e-05     |
# |    value_loss           | 153           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 35           |
# |    episode_reward       | 46.9         |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 35           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 8.084142e-05 |
# |    clip_fraction        | 0.002        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0452      |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.5         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 1.89e-05     |
# |    value_loss           | 93.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 36           |
# |    episode_reward       | 47.9         |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 36           |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0005006211 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0297      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.7         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000941    |
# |    value_loss           | 156          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 37            |
# |    episode_reward       | 49            |
# | time/                   |               |
# |    fps                  | 237           |
# |    iterations           | 37            |
# |    time_elapsed         | 319           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00013662921 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.024        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 29.6          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000329     |
# |    value_loss           | 150           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 38            |
# |    episode_reward       | 50.1          |
# | time/                   |               |
# |    fps                  | 238           |
# |    iterations           | 38            |
# |    time_elapsed         | 326           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 2.1324231e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0271       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 46.2          |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -2.2e-05      |
# |    value_loss           | 151           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 39            |
# |    episode_reward       | 51.1          |
# | time/                   |               |
# |    fps                  | 238           |
# |    iterations           | 39            |
# |    time_elapsed         | 334           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 4.4451182e-05 |
# |    clip_fraction        | 0.00132       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0275       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 240           |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 1.94e-05      |
# |    value_loss           | 161           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 40            |
# |    episode_reward       | 52.2          |
# | time/                   |               |
# |    fps                  | 239           |
# |    iterations           | 40            |
# |    time_elapsed         | 342           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00026693678 |
# |    clip_fraction        | 0.00239       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0227       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 153           |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000241     |
# |    value_loss           | 159           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 41            |
# |    episode_reward       | 53.6          |
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 41            |
# |    time_elapsed         | 349           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 2.8161128e-05 |
# |    clip_fraction        | 0.00215       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0181       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 25.9          |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 2.56e-05      |
# |    value_loss           | 160           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 42            |
# |    episode_reward       | 54.6          |
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 42            |
# |    time_elapsed         | 357           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 2.5135378e-05 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0206       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 51.9          |
# |    n_updates            | 410           |
# |    policy_gradient_loss | 2.04e-06      |
# |    value_loss           | 161           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 43            |
# |    episode_reward       | 56.3          |
# | time/                   |               |
# |    fps                  | 241           |
# |    iterations           | 43            |
# |    time_elapsed         | 364           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00011539785 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0106       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 77.9          |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.00014      |
# |    value_loss           | 166           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 44           |
# |    episode_reward       | 58.8         |
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 44           |
# |    time_elapsed         | 372          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0011397175 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0145      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 108          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 7.8e-05      |
# |    value_loss           | 163          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 45           |
# |    episode_reward       | 59.8         |
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 45           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0002597146 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0176      |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29           |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 1.51e-05     |
# |    value_loss           | 165          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 46            |
# |    episode_reward       | 60.9          |
# | time/                   |               |
# |    fps                  | 243           |
# |    iterations           | 46            |
# |    time_elapsed         | 387           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 2.4038745e-05 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0119       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 31.4          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000195     |
# |    value_loss           | 167           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 47            |
# |    episode_reward       | 62            |
# | time/                   |               |
# |    fps                  | 244           |
# |    iterations           | 47            |
# |    time_elapsed         | 394           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00015118546 |
# |    clip_fraction        | 0.00083       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0172       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 29.5          |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000171     |
# |    value_loss           | 162           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 48           |
# |    episode_reward       | 63           |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 48           |
# |    time_elapsed         | 401          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 7.418217e-06 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0207      |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.9         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -2.95e-05    |
# |    value_loss           | 164          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 49           |
# |    episode_reward       | 64.1         |
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 49           |
# |    time_elapsed         | 408          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0003433156 |
# |    clip_fraction        | 0.00269      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0147      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.1         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000373    |
# |    value_loss           | 168          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 50           |
# |    episode_reward       | 66.6         |
# | time/                   |              |
# |    fps                  | 246          |
# |    iterations           | 50           |
# |    time_elapsed         | 415          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0004340568 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00722     |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.6         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000332    |
# |    value_loss           | 165          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 51            |
# |    episode_reward       | 67.6          |
# | time/                   |               |
# |    fps                  | 246           |
# |    iterations           | 51            |
# |    time_elapsed         | 423           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 2.5592715e-05 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00759      |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 36            |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -4.82e-05     |
# |    value_loss           | 108           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 52            |
# |    episode_reward       | 69.8          |
# | time/                   |               |
# |    fps                  | 247           |
# |    iterations           | 52            |
# |    time_elapsed         | 430           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 2.9883551e-05 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00742      |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 109           |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -1.39e-05     |
# |    value_loss           | 161           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 53            |
# |    episode_reward       | 72.3          |
# | time/                   |               |
# |    fps                  | 247           |
# |    iterations           | 53            |
# |    time_elapsed         | 438           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 4.6026806e-05 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0068       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 27.2          |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -9.25e-06     |
# |    value_loss           | 156           |
# -------------------------------------------
# --------------------------------------------
# ...
# |    episode_length       | 81        |
# |    episode_reward       | 110       |
# | time/                   |           |
# |    fps                  | 255       |
# |    iterations           | 81        |
# |    time_elapsed         | 650       |
# |    total_timesteps      | 165888    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 106       |
# |    n_updates            | 800       |
# |    policy_gradient_loss | -4.07e-10 |
# |    value_loss           | 165       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 82        |
# |    episode_reward       | 111       |
# | time/                   |           |
# |    fps                  | 255       |
# |    iterations           | 82        |
# |    time_elapsed         | 657       |
# |    total_timesteps      | 167936    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 28.7      |
# |    n_updates            | 810       |
# |    policy_gradient_loss | -3.26e-10 |
# |    value_loss           | 165       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 83        |
# |    episode_reward       | 113       |
# | time/                   |           |
# |    fps                  | 255       |
# |    iterations           | 83        |
# |    time_elapsed         | 665       |
# |    total_timesteps      | 169984    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 213       |
# |    n_updates            | 820       |
# |    policy_gradient_loss | -4.8e-10  |
# |    value_loss           | 164       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 84        |
# |    episode_reward       | 114       |
# | time/                   |           |
# |    fps                  | 255       |
# |    iterations           | 84        |
# |    time_elapsed         | 672       |
# |    total_timesteps      | 172032    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 23.2      |
# |    n_updates            | 830       |
# |    policy_gradient_loss | 2.63e-10  |
# |    value_loss           | 108       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 85        |
# |    episode_reward       | 117       |
# | time/                   |           |
# |    fps                  | 255       |
# |    iterations           | 85        |
# |    time_elapsed         | 680       |
# |    total_timesteps      | 174080    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 28.4      |
# |    n_updates            | 840       |
# |    policy_gradient_loss | -3.27e-10 |
# |    value_loss           | 162       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 86        |
# |    episode_reward       | 119       |
# | time/                   |           |
# |    fps                  | 256       |
# |    iterations           | 86        |
# |    time_elapsed         | 687       |
# |    total_timesteps      | 176128    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 57.4      |
# |    n_updates            | 850       |
# |    policy_gradient_loss | -1.02e-09 |
# |    value_loss           | 159       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 87        |
# |    episode_reward       | 120       |
# | time/                   |           |
# |    fps                  | 256       |
# |    iterations           | 87        |
# |    time_elapsed         | 695       |
# |    total_timesteps      | 178176    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 63.6      |
# |    n_updates            | 860       |
# |    policy_gradient_loss | -1.16e-11 |
# |    value_loss           | 153       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 88        |
# |    episode_reward       | 121       |
# | time/                   |           |
# |    fps                  | 256       |
# |    iterations           | 88        |
# |    time_elapsed         | 703       |
# |    total_timesteps      | 180224    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 20.6      |
# |    n_updates            | 870       |
# |    policy_gradient_loss | 6.49e-10  |
# |    value_loss           | 160       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 89        |
# |    episode_reward       | 122       |
# | time/                   |           |
# |    fps                  | 256       |
# |    iterations           | 89        |
# |    time_elapsed         | 710       |
# |    total_timesteps      | 182272    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 54        |
# |    n_updates            | 880       |
# |    policy_gradient_loss | -1.14e-09 |
# |    value_loss           | 163       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 90        |
# |    episode_reward       | 123       |
# | time/                   |           |
# |    fps                  | 256       |
# |    iterations           | 90        |
# |    time_elapsed         | 718       |
# |    total_timesteps      | 184320    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 143       |
# |    n_updates            | 890       |
# |    policy_gradient_loss | -4.07e-11 |
# |    value_loss           | 164       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 91        |
# |    episode_reward       | 124       |
# | time/                   |           |
# |    fps                  | 256       |
# |    iterations           | 91        |
# |    time_elapsed         | 725       |
# |    total_timesteps      | 186368    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 138       |
# |    n_updates            | 900       |
# |    policy_gradient_loss | -9.42e-10 |
# |    value_loss           | 164       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 92        |
# |    episode_reward       | 126       |
# | time/                   |           |
# |    fps                  | 256       |
# |    iterations           | 92        |
# |    time_elapsed         | 733       |
# |    total_timesteps      | 188416    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 26.2      |
# |    n_updates            | 910       |
# |    policy_gradient_loss | 1.02e-11  |
# |    value_loss           | 165       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 93        |
# |    episode_reward       | 127       |
# | time/                   |           |
# |    fps                  | 257       |
# |    iterations           | 93        |
# |    time_elapsed         | 740       |
# |    total_timesteps      | 190464    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 45.1      |
# |    n_updates            | 920       |
# |    policy_gradient_loss | 1.65e-09  |
# |    value_loss           | 165       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 94        |
# |    episode_reward       | 128       |
# | time/                   |           |
# |    fps                  | 257       |
# |    iterations           | 94        |
# |    time_elapsed         | 748       |
# |    total_timesteps      | 192512    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 58.8      |
# |    n_updates            | 930       |
# |    policy_gradient_loss | 4.29e-10  |
# |    value_loss           | 165       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 95        |
# |    episode_reward       | 129       |
# | time/                   |           |
# |    fps                  | 257       |
# |    iterations           | 95        |
# |    time_elapsed         | 755       |
# |    total_timesteps      | 194560    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 158       |
# |    n_updates            | 940       |
# |    policy_gradient_loss | 4.76e-10  |
# |    value_loss           | 165       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 96        |
# |    episode_reward       | 130       |
# | time/                   |           |
# |    fps                  | 257       |
# |    iterations           | 96        |
# |    time_elapsed         | 762       |
# |    total_timesteps      | 196608    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 128       |
# |    n_updates            | 950       |
# |    policy_gradient_loss | -7.51e-10 |
# |    value_loss           | 165       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 97        |
# |    episode_reward       | 131       |
# | time/                   |           |
# |    fps                  | 258       |
# |    iterations           | 97        |
# |    time_elapsed         | 769       |
# |    total_timesteps      | 198656    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 243       |
# |    n_updates            | 960       |
# |    policy_gradient_loss | 8.13e-10  |
# |    value_loss           | 165       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 98        |
# |    episode_reward       | 132       |
# | time/                   |           |
# |    fps                  | 258       |
# |    iterations           | 98        |
# |    time_elapsed         | 776       |
# |    total_timesteps      | 200704    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000651 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 74.1      |
# |    n_updates            | 970       |
# |    policy_gradient_loss | 5.24e-11  |
# |    value_loss           | 165       |
# ---------------------------------------
# Mean episode reward: 1.3492663111917826
# Mean episode length: 1.0
# Cumulative reward: 132.2280984967947
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Balance: 100000
# Total Profit: 0
# Total Rewards: 546.5270322334761
# Total Additional Rewards: 505
# Total Stability Bonus: 41.52703223347625
# profit: -1.2789769243681803e-13

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 테스트 환경 설정
test_df = df  # 테스트용 데이터프레임 설정 (기존 데이터프레임 사용)
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 체크포인트 디렉토리 설정
checkpoint_dir = './GM/GM_Checkpoint_6/'
checkpoint_files = [os.path.join(checkpoint_dir, f) for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]

results = []

# 각 체크포인트 평가
for checkpoint_file in checkpoint_files:
    model = PPO.load(checkpoint_file, env=test_env)

    obs = test_env.reset()
    total_rewards = 0
    total_additional_rewards = 0
    total_stability_bonus = 0
    done = False

    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = test_env.step(action)
        total_rewards += info[0]['reward']
        total_additional_rewards += info[0]['additional_reward']
        total_stability_bonus += info[0]['stability_bonus']

    results.append({
        'checkpoint': checkpoint_file,
        'total_rewards': total_rewards,
        'total_profit': total_rewards - total_additional_rewards - total_stability_bonus,
        'total_additional_rewards': total_additional_rewards,
        'total_stability_bonus': total_stability_bonus,
    })

# 결과 출력
for result in results:
    print(f"Checkpoint: {result['checkpoint']}")
    print(f"Total Rewards: {result['total_rewards']}")
    print(f"total_additional_rewards: {result['total_additional_rewards']}")
    print(f"Total Stability_bonus: {result['total_stability_bonus']}")
    print(f"Total Profit: {result['total_profit']}")
    print("="*50)
# Out:
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_100000_steps.zip
# Total Rewards: 2061.297508115766
# total_additional_rewards: 1847
# Total Stability_bonus: 215.36750399589363
# Total Profit: -1.0699958801275784
# ==================================================
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_120000_steps.zip
# Total Rewards: 2062.471561673977
# total_additional_rewards: 1847
# Total Stability_bonus: 215.47156167397577
# Total Profit: 1.0231815394945443e-12
# ==================================================
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_140000_steps.zip
# Total Rewards: 2062.471561673977
# total_additional_rewards: 1847
# Total Stability_bonus: 215.47156167397577
# Total Profit: 1.0231815394945443e-12
# ==================================================
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_160000_steps.zip
# Total Rewards: 2062.471561673977
# total_additional_rewards: 1847
# Total Stability_bonus: 215.47156167397577
# Total Profit: 1.0231815394945443e-12
# ==================================================
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_180000_steps.zip
# Total Rewards: 2062.471561673977
# total_additional_rewards: 1847
# Total Stability_bonus: 215.47156167397577
# Total Profit: 1.0231815394945443e-12
# ==================================================
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_200000_steps.zip
# Total Rewards: 2062.471561673977
# total_additional_rewards: 1847
# Total Stability_bonus: 215.47156167397577
# Total Profit: 1.0231815394945443e-12
# ==================================================
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_20000_steps.zip
# Total Rewards: 1744.8423768110076
# total_additional_rewards: 1704
# Total Stability_bonus: 43.00241099069253
# Total Profit: -2.1600341796849065
# ==================================================
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_40000_steps.zip
# Total Rewards: 2035.9651360693751
# total_additional_rewards: 1827
# Total Stability_bonus: 208.54514362247562
# Total Profit: 0.41999244689952775
# ==================================================
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_60000_steps.zip
# Total Rewards: 1983.058778192391
# total_additional_rewards: 1843
# Total Stability_bonus: 140.38878002344794
# Total Profit: -0.33000183105698966
# ==================================================
# Checkpoint: ./GM/GM_Checkpoint_6/ppo_stock_trading_80000_steps.zip
# Total Rewards: 2062.471561673977
# total_additional_rewards: 1847
# Total Stability_bonus: 215.47156167397577
# Total Profit: 1.0231815394945443e-12
# ==================================================

# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library
from sklearn.model_selection import train_test_split

# 사용할 주식 티커 목록
tickers = [
    "BXP"
]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2018-01-01', end='2024-01-01')
    df['ticker'] = ticker  # 티커 열 추가

    # 이동 평균 (Moving Average)

    # 상대 강도 지수 (RSI: Relative Strength Index)
    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

    # MACD (Moving Average Convergence Divergence)
    macd = ta.trend.MACD(df['Close'])

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(df['Close'], window=20, window_dev=2)
    df['BB_High'] = bollinger.bollinger_hband()
    df['BB_Low'] = bollinger.bollinger_lband()
    df['BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    df['RSI'].fillna(df['RSI'].mean(), inplace=True)
    df['BB_High'].fillna(df['BB_High'].mean(), inplace=True)
    df['BB_Low'].fillna(df['BB_Low'].mean(), inplace=True)
    df['BB_Middle'].fillna(df['BB_Middle'].mean(), inplace=True)

    data[ticker] = df

# 여러 데이터프레임을 하나로 결합
combined_df = pd.concat(data.values(), ignore_index=False)

# 필요한 열 선택 (모든 feature 포함)
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'BB_High', 'BB_Low', 'BB_Middle', 'ticker']
combined_df = combined_df[features]

# 'Date'를 인덱스로 설정 (필요한 경우)
combined_df.index.name = 'Date'

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df, test_df = train_test_split(combined_df, test_size=0.3, shuffle=False)

print("Train Set:")
print(train_df.head())
print("Test Set:")
print(test_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Train Set:
#                  Open       High        Low      Close    Volume        RSI  \
# Date
# 2018-01-02  41.240002  41.869999  41.150002  41.799999   6934600  49.596247
# 2018-01-03  42.209999  42.950001  42.200001  42.820000  14591600  49.596247
# 2018-01-04  43.090000  44.250000  43.009998  44.139999  17298700  49.596247
# 2018-01-05  44.500000  44.639999  43.959999  44.009998   9643300  49.596247
# 2018-01-08  44.040001  44.590000  43.520000  44.220001  13099600  49.596247
#
#               BB_High     BB_Low  BB_Middle ticker
# Date
# 2018-01-02  42.560135  36.328955  39.444545     GM
# 2018-01-03  42.560135  36.328955  39.444545     GM
# 2018-01-04  42.560135  36.328955  39.444545     GM
# 2018-01-05  42.560135  36.328955  39.444545     GM
# 2018-01-08  42.560135  36.328955  39.444545     GM
# Test Set:
#                  Open       High        Low      Close    Volume        RSI  \
# Date
# 2022-03-14  41.740002  42.430000  40.369999  40.830002  18914000  32.089921
# 2022-03-15  40.830002  42.250000  40.799999  42.130001  16051000  37.503388
# 2022-03-16  43.000000  44.169998  42.369999  43.849998  17014500  43.877868
# 2022-03-17  42.919998  43.830002  42.599998  43.660000  13909000  43.351846
# 2022-03-18  43.230000  45.040001  43.130001  44.820000  19834400  47.490753
#
#               BB_High     BB_Low  BB_Middle ticker
# Date
# 2022-03-14  51.701181  38.719820    45.2105     GM
# 2022-03-15  51.346738  38.447263    44.8970     GM
# 2022-03-16  50.682457  38.529543    44.6060     GM
# 2022-03-17  49.731948  38.803052    44.2675     GM
# 2022-03-18  49.128744  39.006256    44.0675     GM

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import configure
import torch
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

cumu_lst = []
cumu_hap = 0

class StockTradingEnv(gym.Env):
    global cumu_lst, cumu_hap
    metadata = {'render.modes': ['human']}

    def __init__(self, df, initial_balance=100000):
        super(StockTradingEnv, self).__init__()

        self.df = df.drop(columns=['ticker'])  # ticker 열 제거
        self.action_space = spaces.Discrete(3)  # Buy, Hold, Sell
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(len(self.df.columns),), dtype=np.float32)

        self.initial_balance = initial_balance
        self.reset()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.total_profit = 0
        self.inventory = []
        self.balance = self.initial_balance
        self.state = self.df.iloc[self.current_step].values
        self.returns = [0]

        return self.state

    def step(self, action):
        global cumu_lst
        self.done = self.current_step >= len(self.df) - 1
        reward = 0
        additional_reward = 0

        if action == 0 and not self.done:  # Buy
            if self.balance >= self.state[3]:  # Check if balance is sufficient to buy
                self.inventory.append(self.state[3])  # Close price
                self.balance -= self.state[3]

        elif action == 1 and not self.done:  # Sell
            if len(self.inventory) > 0:
                bought_price = self.inventory.pop(0)
                reward = self.state[3] - bought_price  # Current price - Bought price
                self.total_profit += reward
                self.balance += self.state[3]

        # 추가된 보상 요소들
        if self.state[5] >= 70 and action == 1:  # RSI가 70 이상일 때 매도
            additional_reward += 0.5
        elif self.state[5] <= 30 and action == 0:  # RSI가 30 이하일 때 매수
            additional_reward += 0.5

        if self.state[3] >= self.state[6] and action == 1:  # 주가가 BB 상한선 이상일 때 매도
            additional_reward += 0.5
        elif self.state[3] <= self.state[7] and action == 0:  # 주가가 BB 하한선 이하일 때 매수
            additional_reward += 0.5

        if self.state[4] > self.df['Volume'].mean() and (action == 0 or action == 1):  # 거래량이 평균 이상일 때 매수 또는 매도
            additional_reward += 0.5

        total_reward = reward + additional_reward

        # Sharpe Ratio
        if len(self.returns) > 1:
            sharpe_ratio = np.mean(self.returns) / (np.std(self.returns) + 1e-10)
        else:
            sharpe_ratio = 0

        # Drawdown
        peak = np.max(self.returns)
        drawdown = peak - self.returns[-1]

        # 정규화된 Sharpe Ratio와 Drawdown
        normalized_sharpe = np.tanh(sharpe_ratio)  # -1에서 1 사이로 정규화
        normalized_drawdown = np.tanh(drawdown)  # -1에서 1 사이로 정규화

        # 스케일링 팩터
        sharpe_scale = 0.5
        drawdown_scale = 0.5

        # 보상 함수에 샤프 비율과 드로우다운 포함
        stability_bonus = sharpe_scale * normalized_sharpe - drawdown_scale * normalized_drawdown
        total_reward += stability_bonus

        # Update returns
        self.returns.append(total_reward)

        if not self.done:
            self.current_step += 1
            self.state = self.df.iloc[self.current_step].values
        else:
            self.state = np.zeros(self.observation_space.shape)  # Done 상태에서 반환할 값
            cumu_lst.append(self.total_profit)
            self.total_profit = 0

        return self.state, total_reward, self.done, {"reward": total_reward, "additional_reward": additional_reward, "sharpe_ratio": sharpe_ratio, "drawdown": drawdown, "stability_bonus": stability_bonus}

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}, Balance: {self.balance}, Total Profit: {self.total_profit}, Sharpe Ratio: {np.mean(self.returns) / np.std(self.returns) if len(self.returns) > 1 else 0}, Drawdown: {(self.max_balance - self.balance) / self.max_balance}')


class EvalCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(EvalCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.action_distribution = []
        self.state_visit_frequency = {}
        self.cumulative_rewards = []  # 누적 보상을 저장하기 위한 리스트

    def _on_step(self) -> bool:
        # Record current step action for action distribution analysis
        self.action_distribution.append(self.locals["actions"])
        # Record state visit frequency
        state_str = str(self.locals["new_obs"])
        if state_str in self.state_visit_frequency:
            self.state_visit_frequency[state_str] += 1
        else:
            self.state_visit_frequency[state_str] = 1
        return True

    def _on_rollout_end(self) -> None:
        # Log the reward and length for each episode
        episode_reward = sum(self.locals["rewards"])
        episode_length = len(self.locals["rewards"])
        self.episode_rewards.append(episode_reward)
        self.episode_lengths.append(episode_length)
        self.cumulative_rewards.append(sum(self.episode_rewards))  # 누적 보상을 추가
        self.logger.record('rollout/episode_reward', np.sum(self.episode_rewards))
        self.logger.record('rollout/episode_length', np.sum(self.episode_lengths))

    def _on_training_end(self) -> None:
        # Save evaluation results to file or print them
        print(f"Mean episode reward: {np.mean(self.episode_rewards)}")
        print(f"Mean episode length: {np.mean(self.episode_lengths)}")
        print(f"Cumulative reward: {np.sum(self.episode_rewards)}")

        # Plot action distribution
        plt.figure(figsize=(12, 6))
        plt.hist(self.action_distribution, bins=3, align='left', rwidth=0.8)
        plt.xticks(range(3), ['Buy', 'Hold', 'Sell'])
        plt.xlabel('Actions')
        plt.ylabel('Frequency')
        plt.title('Action Distribution')
        plt.show()

        # Plot episode rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.episode_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Episode Reward')
        plt.title('Episode Reward over Episodes')
        plt.show()

        # Plot cumulative rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.cumulative_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Cumulative Reward')
        plt.title('Cumulative Reward over Episodes')
        plt.show()

        # Plot state visit frequency
        state_visit_sorted = sorted(self.state_visit_frequency.items(), key=lambda item: item[1], reverse=True)
        states, visits = zip(*state_visit_sorted)
        plt.figure(figsize=(12, 6))
        plt.bar(states[:10], visits[:10])
        plt.xlabel('States')
        plt.ylabel('Visit Frequency')
        plt.title('Top 10 Most Visited States')
        plt.show()

# 데이터 로드 및 train/test 분할
train_df, test_df = train_test_split(df, test_size=0.3, shuffle=False)

# 학습 환경 설정
train_env = DummyVecEnv([lambda: StockTradingEnv(train_df)])

# CUDA 사용 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
log_dir = "./ppo_stock_trading_v11"
os.makedirs(log_dir, exist_ok=True)
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# PPO 모델 학습
from stable_baselines3.common.callbacks import CheckpointCallback

# 체크포인트 저장 콜백 설정 (예: 10000 타임스텝마다 저장)
checkpoint_callback = CheckpointCallback(save_freq=20000, save_path='./BXP_Checkpoint_1/',
                                         name_prefix='ppo_stock_trading')

# PPO 모델 학습
# model = PPO('MlpPolicy', train_env, learning_rate=0.0003, n_steps=2048, batch_size=64, n_epochs=10, gamma=0.99, verbose=1, device=device)
model = PPO('MlpPolicy', train_env, verbose=1, device=device)

model.set_logger(new_logger)

# 'stable_baselines3' 모듈에 임시로 '__version__' 속성을 추가합니다.
# import stable_baselines3 as sb3
# sb3.__version__ = "1.0.0"

model.learn(total_timesteps=200000, callback=[checkpoint_callback, EvalCallback()])

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 학습된 모델로 예측 및 결과 시각화
obs = test_env.reset()
total_rewards = 0
total_additional_rewards = 0
total_stability_bonus = 0

for _ in range(len(test_df)):
    action, _states = model.predict(obs)
    obs, rewards, done, info = test_env.step(action)
    total_rewards += info[0]['reward']
    total_additional_rewards += info[0]['additional_reward']
    total_stability_bonus += info[0]['stability_bonus']
    test_env.render()
    if done:
        break

print(f"Final Balance: {test_env.get_attr('balance')[0]}")
print(f"Total Profit: {test_env.get_attr('total_profit')[0]}")
print(f"Total Rewards: {total_rewards}")
print(f"Total Additional Rewards: {total_additional_rewards}")
print(f"Total Stability Bonus: {total_stability_bonus}")
print(f"profit: {total_rewards - total_additional_rewards - total_stability_bonus}")

# TensorBoard 로그 파일을 로컬에서 실행
# !tensorboard --logdir ./ppo_stock_trading
# Out:
# Logging to ./ppo_stock_trading_v11
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    episode_length  | 1        |
# |    episode_reward  | 0        |
# | time/              |          |
# |    fps             | 374      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 2           |
# |    episode_reward       | 1           |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009374144 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 698         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 1.04e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 3            |
# |    episode_reward       | 10.8         |
# | time/                   |              |
# |    fps                  | 310          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0103841685 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 3.89e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 4            |
# |    episode_reward       | 31.6         |
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 4            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0077077625 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 5.67e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 5           |
# |    episode_reward       | 32.6        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011954378 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 4.55e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 6          |
# |    episode_reward       | 25.6       |
# | time/                   |            |
# |    fps                  | 299        |
# |    iterations           | 6          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02280739 |
# |    clip_fraction        | 0.0787     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 704        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00182   |
# |    value_loss           | 1.18e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 7            |
# |    episode_reward       | 26.6         |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 7            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0061350423 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.99e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 5.21e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 8           |
# |    episode_reward       | 26.6        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 8           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010572406 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.85e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00625    |
# |    value_loss           | 9.58e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 9            |
# |    episode_reward       | 28.8         |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 9            |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0032460853 |
# |    clip_fraction        | 0.00205      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.979       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1e+03      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 5.12e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 10          |
# |    episode_reward       | 27.7        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 10          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011836842 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.942      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00404     |
# |    value_loss           | 3.34e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 11           |
# |    episode_reward       | 28.7         |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 11           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0046879835 |
# |    clip_fraction        | 0.0957       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.862       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 425          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.0017       |
# |    value_loss           | 973          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 12           |
# |    episode_reward       | 30.7         |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 12           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0021028528 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.951       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.04e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 1.01e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 13          |
# |    episode_reward       | 28          |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 13          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008856421 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00101    |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 14           |
# |    episode_reward       | 29           |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 14           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0051791854 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.951       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.02e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.000234     |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 15           |
# |    episode_reward       | 29.9         |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 15           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0026702909 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.95e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 8.35e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 16           |
# |    episode_reward       | 30.9         |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 16           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0023177299 |
# |    clip_fraction        | 0.00161      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.911       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.51e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000697    |
# |    value_loss           | 8.79e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 17           |
# |    episode_reward       | 31.9         |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 17           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0073971543 |
# |    clip_fraction        | 0.00991      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 6.85e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 18         |
# |    episode_reward       | 33.8       |
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 18         |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00381533 |
# |    clip_fraction        | 0.0776     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.901     |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 631        |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00101    |
# |    value_loss           | 1.34e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 19           |
# |    episode_reward       | 33.8         |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 19           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0012936178 |
# |    clip_fraction        | 0.0832       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 217          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.000872     |
# |    value_loss           | 586          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 20           |
# |    episode_reward       | 39.5         |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 20           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0012558107 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 342          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000536    |
# |    value_loss           | 841          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 21          |
# |    episode_reward       | 39.5        |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 21          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015118451 |
# |    clip_fraction        | 0.0126      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 518         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.000101    |
# |    value_loss           | 1.09e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 22          |
# |    episode_reward       | 40.5        |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 22          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014401577 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.1        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 146         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 23         |
# |    episode_reward       | 41.1       |
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 23         |
# |    time_elapsed         | 161        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01097035 |
# |    clip_fraction        | 0.0951     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.742     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.1       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00387   |
# |    value_loss           | 114        |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 24            |
# |    episode_reward       | 42.1          |
# | time/                   |               |
# |    fps                  | 291           |
# |    iterations           | 24            |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00074835133 |
# |    clip_fraction        | 0.0428        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.741        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 68.3          |
# |    n_updates            | 230           |
# |    policy_gradient_loss | 0.000282      |
# |    value_loss           | 92.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 25          |
# |    episode_reward       | 42.1        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 25          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006110421 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.737      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.000344    |
# |    value_loss           | 98.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 26           |
# |    episode_reward       | 43.1         |
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 26           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0035138652 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.746       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.7         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.000223     |
# |    value_loss           | 105          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 27         |
# |    episode_reward       | 45.2       |
# | time/                   |            |
# |    fps                  | 289        |
# |    iterations           | 27         |
# |    time_elapsed         | 191        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00939315 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.659     |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 121        |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00764   |
# |    value_loss           | 118        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 28          |
# |    episode_reward       | 46.6        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 28          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008192025 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 153         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00575    |
# |    value_loss           | 115         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 29           |
# |    episode_reward       | 47.6         |
# | time/                   |              |
# |    fps                  | 286          |
# |    iterations           | 29           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0030127561 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.61        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.5         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.000947     |
# |    value_loss           | 97.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 30          |
# |    episode_reward       | 48.6        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 30          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006071114 |
# |    clip_fraction        | 0.0513      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.1        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 98.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 31           |
# |    episode_reward       | 50.1         |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 31           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0059785955 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.4         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 101          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 32           |
# |    episode_reward       | 52.2         |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 32           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0034606415 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.438       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63           |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 109          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 33          |
# |    episode_reward       | 54.2        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 33          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.002167372 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.451      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.8        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000718   |
# |    value_loss           | 98.4        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 34            |
# |    episode_reward       | 56.2          |
# | time/                   |               |
# |    fps                  | 283           |
# |    iterations           | 34            |
# |    time_elapsed         | 245           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00016901383 |
# |    clip_fraction        | 0.00464       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.448        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 11.4          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | 8.83e-05      |
# |    value_loss           | 102           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 35           |
# |    episode_reward       | 58.5         |
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 35           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0038393955 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.41        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 60.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 36           |
# |    episode_reward       | 59.5         |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 36           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0044124266 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.371       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.9         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 102          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 37           |
# |    episode_reward       | 60.5         |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 37           |
# |    time_elapsed         | 268          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0019173145 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.329       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.7         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000489    |
# |    value_loss           | 101          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 38           |
# |    episode_reward       | 61.5         |
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 38           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0015154696 |
# |    clip_fraction        | 0.00269      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.281       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.1         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000171    |
# |    value_loss           | 102          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 39            |
# |    episode_reward       | 62.5          |
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 39            |
# |    time_elapsed         | 285           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00063974777 |
# |    clip_fraction        | 0.00698       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.261        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.96          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 0.000219      |
# |    value_loss           | 106           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 40            |
# |    episode_reward       | 63.5          |
# | time/                   |               |
# |    fps                  | 279           |
# |    iterations           | 40            |
# |    time_elapsed         | 293           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00072986714 |
# |    clip_fraction        | 0.0185        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.251        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 37.4          |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000959     |
# |    value_loss           | 110           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 41            |
# |    episode_reward       | 64.5          |
# | time/                   |               |
# |    fps                  | 278           |
# |    iterations           | 41            |
# |    time_elapsed         | 301           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00033864455 |
# |    clip_fraction        | 0.00801       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.259        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 27.8          |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -8.48e-05     |
# |    value_loss           | 109           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 42           |
# |    episode_reward       | 65.5         |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 42           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0013112896 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.209       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 98.4         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000903    |
# |    value_loss           | 115          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 43            |
# |    episode_reward       | 67.5          |
# | time/                   |               |
# |    fps                  | 276           |
# |    iterations           | 43            |
# |    time_elapsed         | 317           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00016272638 |
# |    clip_fraction        | 0.00083       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.196        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 16.7          |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000134     |
# |    value_loss           | 110           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 44           |
# |    episode_reward       | 69.5         |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 44           |
# |    time_elapsed         | 325          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0010014003 |
# |    clip_fraction        | 0.00347      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.2         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -1.48e-05    |
# |    value_loss           | 111          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 45           |
# |    episode_reward       | 70.5         |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 45           |
# |    time_elapsed         | 333          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0016180256 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.225       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.6         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000203     |
# |    value_loss           | 110          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 46            |
# |    episode_reward       | 71.5          |
# | time/                   |               |
# |    fps                  | 276           |
# |    iterations           | 46            |
# |    time_elapsed         | 341           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00010783339 |
# |    clip_fraction        | 0.0146        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.218        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 151           |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 0.000327      |
# |    value_loss           | 113           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 47           |
# |    episode_reward       | 72.5         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 47           |
# |    time_elapsed         | 348          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0007832623 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.3         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -3.53e-05    |
# |    value_loss           | 110          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 48           |
# |    episode_reward       | 73.5         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 48           |
# |    time_elapsed         | 356          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0011624575 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.163       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.2         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000584    |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 49          |
# |    episode_reward       | 74.5        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 49          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.000763978 |
# |    clip_fraction        | 0.0226      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.182      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 111         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 50           |
# |    episode_reward       | 76.5         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 50           |
# |    time_elapsed         | 371          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0011762101 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.156       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 120          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 112          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 51            |
# |    episode_reward       | 77.5          |
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 51            |
# |    time_elapsed         | 379           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00041216682 |
# |    clip_fraction        | 0.00444       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.14         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 22.5          |
# |    n_updates            | 500           |
# |    policy_gradient_loss | 0.000182      |
# |    value_loss           | 69.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 52           |
# |    episode_reward       | 79.5         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 52           |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 9.138425e-05 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.162       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.000157     |
# |    value_loss           | 115          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 53           |
# |    episode_reward       | 81.5         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 53           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0010167878 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.19        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 144          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000331    |
# |    value_loss           | 112          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 54          |
# |    episode_reward       | 82.5        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 54          |
# |    time_elapsed         | 401         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 3.75355e-05 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# ...
# |    approx_kl            | 0.00022274631 |
# |    clip_fraction        | 0.00332       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0305       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 62.3          |
# |    n_updates            | 810           |
# |    policy_gradient_loss | -2.33e-05     |
# |    value_loss           | 117           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 83           |
# |    episode_reward       | 117          |
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 83           |
# |    time_elapsed         | 606          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0001880028 |
# |    clip_fraction        | 0.00459      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.041       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 147          |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.000211    |
# |    value_loss           | 117          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 84           |
# |    episode_reward       | 118          |
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 84           |
# |    time_elapsed         | 613          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 1.639413e-05 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0427      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.9         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -5.13e-05    |
# |    value_loss           | 71.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 85            |
# |    episode_reward       | 120           |
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 85            |
# |    time_elapsed         | 619           |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 1.6535458e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0393       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 269           |
# |    n_updates            | 840           |
# |    policy_gradient_loss | 1.86e-05      |
# |    value_loss           | 117           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 86           |
# |    episode_reward       | 122          |
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 86           |
# |    time_elapsed         | 626          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 3.701239e-05 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0354      |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 84.9         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | 5.15e-05     |
# |    value_loss           | 114          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 87            |
# |    episode_reward       | 123           |
# | time/                   |               |
# |    fps                  | 281           |
# |    iterations           | 87            |
# |    time_elapsed         | 634           |
# |    total_timesteps      | 178176        |
# | train/                  |               |
# |    approx_kl            | 0.00020904321 |
# |    clip_fraction        | 0.00518       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0274       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.59          |
# |    n_updates            | 860           |
# |    policy_gradient_loss | 9.33e-06      |
# |    value_loss           | 112           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 88           |
# |    episode_reward       | 124          |
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 88           |
# |    time_elapsed         | 641          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 8.024878e-05 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0231      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.6         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000136    |
# |    value_loss           | 115          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 89            |
# |    episode_reward       | 125           |
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 89            |
# |    time_elapsed         | 649           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 4.3750828e-05 |
# |    clip_fraction        | 0.00166       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0253       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 167           |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -0.000205     |
# |    value_loss           | 117           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 90            |
# |    episode_reward       | 126           |
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 90            |
# |    time_elapsed         | 657           |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 1.3066368e-05 |
# |    clip_fraction        | 0.00117       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.027        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 14.4          |
# |    n_updates            | 890           |
# |    policy_gradient_loss | 0.000106      |
# |    value_loss           | 117           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 91            |
# |    episode_reward       | 127           |
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 91            |
# |    time_elapsed         | 664           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 7.0544484e-06 |
# |    clip_fraction        | 0.00103       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.028        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 10.3          |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -6.4e-05      |
# |    value_loss           | 118           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 92            |
# |    episode_reward       | 128           |
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 92            |
# |    time_elapsed         | 671           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 2.4654146e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.028        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 30.2          |
# |    n_updates            | 910           |
# |    policy_gradient_loss | -4.57e-06     |
# |    value_loss           | 118           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 93           |
# |    episode_reward       | 129          |
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 93           |
# |    time_elapsed         | 678          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 6.811862e-05 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0279      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.2         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | 1.6e-05      |
# |    value_loss           | 118          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 94            |
# |    episode_reward       | 130           |
# | time/                   |               |
# |    fps                  | 281           |
# |    iterations           | 94            |
# |    time_elapsed         | 684           |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 7.6933065e-06 |
# |    clip_fraction        | 0.00181       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0257       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 102           |
# |    n_updates            | 930           |
# |    policy_gradient_loss | 5.2e-05       |
# |    value_loss           | 118           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 95            |
# |    episode_reward       | 131           |
# | time/                   |               |
# |    fps                  | 281           |
# |    iterations           | 95            |
# |    time_elapsed         | 691           |
# |    total_timesteps      | 194560        |
# | train/                  |               |
# |    approx_kl            | 0.00024127829 |
# |    clip_fraction        | 0.00181       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0334       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 113           |
# |    n_updates            | 940           |
# |    policy_gradient_loss | -0.000115     |
# |    value_loss           | 118           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 96            |
# |    episode_reward       | 132           |
# | time/                   |               |
# |    fps                  | 281           |
# |    iterations           | 96            |
# |    time_elapsed         | 697           |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 3.0906318e-05 |
# |    clip_fraction        | 0.00229       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0414       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 116           |
# |    n_updates            | 950           |
# |    policy_gradient_loss | -0.000104     |
# |    value_loss           | 118           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 97           |
# |    episode_reward       | 133          |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 97           |
# |    time_elapsed         | 704          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 9.677315e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0399      |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.6         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 6.24e-06     |
# |    value_loss           | 118          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 98            |
# |    episode_reward       | 134           |
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 98            |
# |    time_elapsed         | 710           |
# |    total_timesteps      | 200704        |
# | train/                  |               |
# |    approx_kl            | 0.00025145197 |
# |    clip_fraction        | 0.0021        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0374       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 11.2          |
# |    n_updates            | 970           |
# |    policy_gradient_loss | 0.000132      |
# |    value_loss           | 119           |
# -------------------------------------------
# Mean episode reward: 1.3641836205307318
# Mean episode length: 1.0
# Cumulative reward: 133.68999481201172
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Total Rewards: 504.38000106811523
# Total Additional Rewards: 505
# profit: -0.6199989318847656

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 테스트 환경 설정
test_df = df  # 테스트용 데이터프레임 설정 (기존 데이터프레임 사용)
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 체크포인트 디렉토리 설정
checkpoint_dir = './check__12/'
checkpoint_files = [os.path.join(checkpoint_dir, f) for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]

results = []

# 각 체크포인트 평가
for checkpoint_file in checkpoint_files:
    model = PPO.load(checkpoint_file, env=test_env)
    
    obs = test_env.reset()
    total_rewards = 0
    total_additional_rewards = 0
    done = False
    
    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = test_env.step(action)
        total_rewards += info[0]['reward']
        total_additional_rewards += info[0]['additional_reward']

    
    results.append({
        'checkpoint': checkpoint_file,
        'total_rewards': total_rewards,
        'total_profit': total_rewards - total_additional_rewards,
        'total_additional_rewards': total_additional_rewards,
    })

# 결과 출력
for result in results:
    print(f"total_additional_rewards: {result['total_additional_rewards']}")
    print(f"Checkpoint: {result['checkpoint']}")
    print(f"Total Rewards: {result['total_profit']}")
    print("="*50)
# Out:
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# total_additional_rewards: 1832
# Checkpoint: ./check__12/ppo_stock_trading_100000_steps.zip
# Total Rewards: 0.7700176239013672
# ==================================================
# total_additional_rewards: 1840
# Checkpoint: ./check__12/ppo_stock_trading_120000_steps.zip
# Total Rewards: -12.650001525878906
# ==================================================
# total_additional_rewards: 1836
# Checkpoint: ./check__12/ppo_stock_trading_140000_steps.zip
# Total Rewards: 4.169979095458984
# ==================================================
# total_additional_rewards: 1844
# Checkpoint: ./check__12/ppo_stock_trading_160000_steps.zip
# Total Rewards: 0.7599945068359375
# ==================================================
# total_additional_rewards: 1846
# Checkpoint: ./check__12/ppo_stock_trading_180000_steps.zip
# Total Rewards: 1.989999771118164
# ==================================================
# total_additional_rewards: 1845
# Checkpoint: ./check__12/ppo_stock_trading_200000_steps.zip
# Total Rewards: -1.1600017547607422
# ==================================================
# total_additional_rewards: 1466
# Checkpoint: ./check__12/ppo_stock_trading_20000_steps.zip
# Total Rewards: -856.0399913787842
# ==================================================
# total_additional_rewards: 1546
# Checkpoint: ./check__12/ppo_stock_trading_40000_steps.zip
# Total Rewards: 399.3799533843994
# ==================================================
# total_additional_rewards: 1732
# Checkpoint: ./check__12/ppo_stock_trading_60000_steps.zip
# Total Rewards: 54.409996032714844
# ==================================================
# total_additional_rewards: 1818
# Checkpoint: ./check__12/ppo_stock_trading_80000_steps.zip
# Total Rewards: 1.6900157928466797
# ==================================================

# %%
length = len(cumu_lst)
for i in range(length):
    cumu_lst.pop()
plt.figure(figsize=(12, 6))
plt.plot(cumu_lst, linestyle='-')
plt.title('Episode Rewards')
plt.xlabel('Episode')
plt.ylabel('Reward')

plt.show()

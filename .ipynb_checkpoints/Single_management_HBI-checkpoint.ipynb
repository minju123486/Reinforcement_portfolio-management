# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library
from sklearn.model_selection import train_test_split

# 사용할 주식 티커 목록
tickers = [
    "HBI"
]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2018-01-01', end='2024-01-01')
    df['ticker'] = ticker  # 티커 열 추가

    # 이동 평균 (Moving Average)

    # 상대 강도 지수 (RSI: Relative Strength Index)
    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

    # MACD (Moving Average Convergence Divergence)
    macd = ta.trend.MACD(df['Close'])

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(df['Close'], window=20, window_dev=2)
    df['BB_High'] = bollinger.bollinger_hband()
    df['BB_Low'] = bollinger.bollinger_lband()
    df['BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    df['RSI'].fillna(df['RSI'].mean(), inplace=True)
    df['BB_High'].fillna(df['BB_High'].mean(), inplace=True)
    df['BB_Low'].fillna(df['BB_Low'].mean(), inplace=True)
    df['BB_Middle'].fillna(df['BB_Middle'].mean(), inplace=True)

    data[ticker] = df

# 여러 데이터프레임을 하나로 결합
combined_df = pd.concat(data.values(), ignore_index=False)

# 필요한 열 선택 (모든 feature 포함)
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'BB_High', 'BB_Low', 'BB_Middle', 'ticker']
combined_df = combined_df[features]

# 'Date'를 인덱스로 설정 (필요한 경우)
combined_df.index.name = 'Date'

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df, test_df = train_test_split(combined_df, test_size=0.3, shuffle=False)

print("Train Set:")
print(train_df.head())
print("Test Set:")
print(test_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Train Set:
#                  Open       High        Low      Close    Volume        RSI  \
# Date
# 2018-01-02  41.240002  41.869999  41.150002  41.799999   6934600  49.596247
# 2018-01-03  42.209999  42.950001  42.200001  42.820000  14591600  49.596247
# 2018-01-04  43.090000  44.250000  43.009998  44.139999  17298700  49.596247
# 2018-01-05  44.500000  44.639999  43.959999  44.009998   9643300  49.596247
# 2018-01-08  44.040001  44.590000  43.520000  44.220001  13099600  49.596247
#
#               BB_High     BB_Low  BB_Middle ticker
# Date
# 2018-01-02  42.560135  36.328955  39.444545     GM
# 2018-01-03  42.560135  36.328955  39.444545     GM
# 2018-01-04  42.560135  36.328955  39.444545     GM
# 2018-01-05  42.560135  36.328955  39.444545     GM
# 2018-01-08  42.560135  36.328955  39.444545     GM
# Test Set:
#                  Open       High        Low      Close    Volume        RSI  \
# Date
# 2022-03-14  41.740002  42.430000  40.369999  40.830002  18914000  32.089921
# 2022-03-15  40.830002  42.250000  40.799999  42.130001  16051000  37.503388
# 2022-03-16  43.000000  44.169998  42.369999  43.849998  17014500  43.877868
# 2022-03-17  42.919998  43.830002  42.599998  43.660000  13909000  43.351846
# 2022-03-18  43.230000  45.040001  43.130001  44.820000  19834400  47.490753
#
#               BB_High     BB_Low  BB_Middle ticker
# Date
# 2022-03-14  51.701181  38.719820    45.2105     GM
# 2022-03-15  51.346738  38.447263    44.8970     GM
# 2022-03-16  50.682457  38.529543    44.6060     GM
# 2022-03-17  49.731948  38.803052    44.2675     GM
# 2022-03-18  49.128744  39.006256    44.0675     GM

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import configure
import torch
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

cumu_lst = []
cumu_hap = 0

class StockTradingEnv(gym.Env):
    global cumu_lst, cumu_hap
    metadata = {'render.modes': ['human']}

    def __init__(self, df, initial_balance=100000):
        super(StockTradingEnv, self).__init__()

        self.df = df.drop(columns=['ticker'])  # ticker 열 제거
        self.action_space = spaces.Discrete(3)  # Buy, Hold, Sell
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(len(self.df.columns),), dtype=np.float32)

        self.initial_balance = initial_balance
        self.reset()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.total_profit = 0
        self.inventory = []
        self.balance = self.initial_balance
        self.state = self.df.iloc[self.current_step].values
        self.returns = [0]

        return self.state

    def step(self, action):
        global cumu_lst
        self.done = self.current_step >= len(self.df) - 1
        reward = 0
        additional_reward = 0

        if action == 0 and not self.done:  # Buy
            if self.balance >= self.state[3]:  # Check if balance is sufficient to buy
                self.inventory.append(self.state[3])  # Close price
                self.balance -= self.state[3]

        elif action == 1 and not self.done:  # Sell
            if len(self.inventory) > 0:
                bought_price = self.inventory.pop(0)
                reward = self.state[3] - bought_price  # Current price - Bought price
                self.total_profit += reward
                self.balance += self.state[3]

        # 추가된 보상 요소들
        if self.state[5] >= 70 and action == 1:  # RSI가 70 이상일 때 매도
            additional_reward += 0.5
        elif self.state[5] <= 30 and action == 0:  # RSI가 30 이하일 때 매수
            additional_reward += 0.5

        if self.state[3] >= self.state[6] and action == 1:  # 주가가 BB 상한선 이상일 때 매도
            additional_reward += 0.5
        elif self.state[3] <= self.state[7] and action == 0:  # 주가가 BB 하한선 이하일 때 매수
            additional_reward += 0.5

        if self.state[4] > self.df['Volume'].mean() and (action == 0 or action == 1):  # 거래량이 평균 이상일 때 매수 또는 매도
            additional_reward += 0.5

        total_reward = reward + additional_reward

        # Sharpe Ratio
        if len(self.returns) > 1:
            sharpe_ratio = np.mean(self.returns) / (np.std(self.returns) + 1e-10)
        else:
            sharpe_ratio = 0

        # Drawdown
        peak = np.max(self.returns)
        drawdown = peak - self.returns[-1]

        # 정규화된 Sharpe Ratio와 Drawdown
        normalized_sharpe = np.tanh(sharpe_ratio)  # -1에서 1 사이로 정규화
        normalized_drawdown = np.tanh(drawdown)  # -1에서 1 사이로 정규화

        # 스케일링 팩터
        sharpe_scale = 0.5
        drawdown_scale = 0.5

        # 보상 함수에 샤프 비율과 드로우다운 포함
        stability_bonus = sharpe_scale * normalized_sharpe - drawdown_scale * normalized_drawdown
        total_reward += stability_bonus

        # Update returns
        self.returns.append(total_reward)

        if not self.done:
            self.current_step += 1
            self.state = self.df.iloc[self.current_step].values
        else:
            self.state = np.zeros(self.observation_space.shape)  # Done 상태에서 반환할 값
            cumu_lst.append(self.total_profit)
            self.total_profit = 0

        return self.state, total_reward, self.done, {"reward": total_reward, "additional_reward": additional_reward, "sharpe_ratio": sharpe_ratio, "drawdown": drawdown, "stability_bonus": stability_bonus}

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}, Balance: {self.balance}, Total Profit: {self.total_profit}, Sharpe Ratio: {np.mean(self.returns) / np.std(self.returns) if len(self.returns) > 1 else 0}, Drawdown: {(self.max_balance - self.balance) / self.max_balance}')


class EvalCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(EvalCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.action_distribution = []
        self.state_visit_frequency = {}
        self.cumulative_rewards = []  # 누적 보상을 저장하기 위한 리스트

    def _on_step(self) -> bool:
        # Record current step action for action distribution analysis
        self.action_distribution.append(self.locals["actions"])
        # Record state visit frequency
        state_str = str(self.locals["new_obs"])
        if state_str in self.state_visit_frequency:
            self.state_visit_frequency[state_str] += 1
        else:
            self.state_visit_frequency[state_str] = 1
        return True

    def _on_rollout_end(self) -> None:
        # Log the reward and length for each episode
        episode_reward = sum(self.locals["rewards"])
        episode_length = len(self.locals["rewards"])
        self.episode_rewards.append(episode_reward)
        self.episode_lengths.append(episode_length)
        self.cumulative_rewards.append(sum(self.episode_rewards))  # 누적 보상을 추가
        self.logger.record('rollout/episode_reward', np.sum(self.episode_rewards))
        self.logger.record('rollout/episode_length', np.sum(self.episode_lengths))

    def _on_training_end(self) -> None:
        # Save evaluation results to file or print them
        print(f"Mean episode reward: {np.mean(self.episode_rewards)}")
        print(f"Mean episode length: {np.mean(self.episode_lengths)}")
        print(f"Cumulative reward: {np.sum(self.episode_rewards)}")

        # Plot action distribution
        plt.figure(figsize=(12, 6))
        plt.hist(self.action_distribution, bins=3, align='left', rwidth=0.8)
        plt.xticks(range(3), ['Buy', 'Hold', 'Sell'])
        plt.xlabel('Actions')
        plt.ylabel('Frequency')
        plt.title('Action Distribution')
        plt.show()

        # Plot episode rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.episode_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Episode Reward')
        plt.title('Episode Reward over Episodes')
        plt.show()

        # Plot cumulative rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.cumulative_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Cumulative Reward')
        plt.title('Cumulative Reward over Episodes')
        plt.show()

        # Plot state visit frequency
        state_visit_sorted = sorted(self.state_visit_frequency.items(), key=lambda item: item[1], reverse=True)
        states, visits = zip(*state_visit_sorted)
        plt.figure(figsize=(12, 6))
        plt.bar(states[:10], visits[:10])
        plt.xlabel('States')
        plt.ylabel('Visit Frequency')
        plt.title('Top 10 Most Visited States')
        plt.show()

# 데이터 로드 및 train/test 분할
train_df, test_df = train_test_split(df, test_size=0.3, shuffle=False)

# 학습 환경 설정
train_env = DummyVecEnv([lambda: StockTradingEnv(train_df)])

# CUDA 사용 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
log_dir = "./ppo_stock_trading_v11"
os.makedirs(log_dir, exist_ok=True)
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# PPO 모델 학습
from stable_baselines3.common.callbacks import CheckpointCallback

# 체크포인트 저장 콜백 설정 (예: 10000 타임스텝마다 저장)
checkpoint_callback = CheckpointCallback(save_freq=20000, save_path='./HBI_Checkpoint_1/',
                                         name_prefix='ppo_stock_trading')

# PPO 모델 학습
# model = PPO('MlpPolicy', train_env, learning_rate=0.0003, n_steps=2048, batch_size=64, n_epochs=10, gamma=0.99, verbose=1, device=device)
model = PPO('MlpPolicy', train_env, verbose=1, device=device)

model.set_logger(new_logger)

# 'stable_baselines3' 모듈에 임시로 '__version__' 속성을 추가합니다.
# import stable_baselines3 as sb3
# sb3.__version__ = "1.0.0"

model.learn(total_timesteps=200000, callback=[checkpoint_callback, EvalCallback()])

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 학습된 모델로 예측 및 결과 시각화
obs = test_env.reset()
total_rewards = 0
total_additional_rewards = 0
total_stability_bonus = 0

for _ in range(len(test_df)):
    action, _states = model.predict(obs)
    obs, rewards, done, info = test_env.step(action)
    total_rewards += info[0]['reward']
    total_additional_rewards += info[0]['additional_reward']
    total_stability_bonus += info[0]['stability_bonus']
    test_env.render()
    if done:
        break

print(f"Final Balance: {test_env.get_attr('balance')[0]}")
print(f"Total Profit: {test_env.get_attr('total_profit')[0]}")
print(f"Total Rewards: {total_rewards}")
print(f"Total Additional Rewards: {total_additional_rewards}")
print(f"Total Stability Bonus: {total_stability_bonus}")
print(f"profit: {total_rewards - total_additional_rewards - total_stability_bonus}")

# TensorBoard 로그 파일을 로컬에서 실행
# !tensorboard --logdir ./ppo_stock_trading
# Out:
# Logging to ./ppo_stock_trading_v11
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    episode_length  | 1        |
# |    episode_reward  | 0        |
# | time/              |          |
# |    fps             | 546      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 2            |
# |    episode_reward       | -8.26        |
# | time/                   |              |
# |    fps                  | 455          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0039308807 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.59e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.000234     |
# |    value_loss           | 3.11e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 3            |
# |    episode_reward       | -7.46        |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 3            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0056402665 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 950          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 3.2e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 4           |
# |    episode_reward       | 6.68        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010315426 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 136         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 248         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 5           |
# |    episode_reward       | 9.24        |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 5           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011644596 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 158         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.000349    |
# |    value_loss           | 439         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 6           |
# |    episode_reward       | 14.2        |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 6           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013475753 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 100         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 197         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 7           |
# |    episode_reward       | 15          |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 7           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010301427 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 101         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 8             |
# |    episode_reward       | 15            |
# | time/                   |               |
# |    fps                  | 384           |
# |    iterations           | 8             |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00017669241 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.91e+03      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000324     |
# |    value_loss           | 3.65e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 9             |
# |    episode_reward       | 17            |
# | time/                   |               |
# |    fps                  | 377           |
# |    iterations           | 9             |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 2.8071896e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.12e+03      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000199     |
# |    value_loss           | 2.9e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 10           |
# |    episode_reward       | 14.9         |
# | time/                   |              |
# |    fps                  | 365          |
# |    iterations           | 10           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 8.293259e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000175    |
# |    value_loss           | 5.07e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 11            |
# |    episode_reward       | 14.9          |
# | time/                   |               |
# |    fps                  | 355           |
# |    iterations           | 11            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00084644894 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.56e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00052      |
# |    value_loss           | 2.88e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 12           |
# |    episode_reward       | 21.2         |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 12           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0061045075 |
# |    clip_fraction        | 0.0727       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 437          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000593    |
# |    value_loss           | 1.46e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 13          |
# |    episode_reward       | 22          |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 13          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007950763 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.3        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0055     |
# |    value_loss           | 163         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 14         |
# |    episode_reward       | 22.8       |
# | time/                   |            |
# |    fps                  | 338        |
# |    iterations           | 14         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01592769 |
# |    clip_fraction        | 0.0921     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.988     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 123        |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00356   |
# |    value_loss           | 187        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 15          |
# |    episode_reward       | 23.6        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 15          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012247285 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 70.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 16          |
# |    episode_reward       | 24.4        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 16          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008594818 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00775    |
# |    value_loss           | 60          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 17           |
# |    episode_reward       | 25.3         |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 17           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0055910116 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 105          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0053      |
# |    value_loss           | 47.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 18           |
# |    episode_reward       | 25.4         |
# | time/                   |              |
# |    fps                  | 326          |
# |    iterations           | 18           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0048225373 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 34.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 19           |
# |    episode_reward       | 27           |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 19           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0060771652 |
# |    clip_fraction        | 0.0592       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.635       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.3         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00486     |
# |    value_loss           | 51.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 20           |
# |    episode_reward       | 28.6         |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 20           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0014321826 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.01         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000751    |
# |    value_loss           | 49.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 21           |
# |    episode_reward       | 29.4         |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 21           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0046534594 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.518       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.2         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00328     |
# |    value_loss           | 53.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 22           |
# |    episode_reward       | 30.2         |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 22           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0035986826 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.31         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 1.36e-05     |
# |    value_loss           | 53.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 23            |
# |    episode_reward       | 31            |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 23            |
# |    time_elapsed         | 148           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00085303385 |
# |    clip_fraction        | 0.014         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.417        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 67.2          |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.0013       |
# |    value_loss           | 58.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 24           |
# |    episode_reward       | 31.8         |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 24           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0010234707 |
# |    clip_fraction        | 0.00835      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.11         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000386    |
# |    value_loss           | 56.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 25           |
# |    episode_reward       | 33.1         |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 25           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0005283434 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.421       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.9         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -1.7e-05     |
# |    value_loss           | 58.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 26           |
# |    episode_reward       | 33.9         |
# | time/                   |              |
# |    fps                  | 313          |
# |    iterations           | 26           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0028172508 |
# |    clip_fraction        | 0.00933      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.2         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000578    |
# |    value_loss           | 61.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 27          |
# |    episode_reward       | 34.7        |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 27          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.002223012 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.35       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.3        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000956   |
# |    value_loss           | 62.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 28           |
# |    episode_reward       | 35.5         |
# | time/                   |              |
# |    fps                  | 312          |
# |    iterations           | 28           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0006322196 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.363       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.11         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.000476     |
# |    value_loss           | 64.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 29           |
# |    episode_reward       | 36.3         |
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 29           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0016174761 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.333       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.48         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000384    |
# |    value_loss           | 65.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 30           |
# |    episode_reward       | 37.1         |
# | time/                   |              |
# |    fps                  | 310          |
# |    iterations           | 30           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0022787782 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.296       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.9         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 68.6         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 31            |
# |    episode_reward       | 37.9          |
# | time/                   |               |
# |    fps                  | 309           |
# |    iterations           | 31            |
# |    time_elapsed         | 205           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00070672436 |
# |    clip_fraction        | 0.0217        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.258        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.38          |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 68.4          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 32            |
# |    episode_reward       | 38.7          |
# | time/                   |               |
# |    fps                  | 308           |
# |    iterations           | 32            |
# |    time_elapsed         | 212           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00033469687 |
# |    clip_fraction        | 0.00566       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.253        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 33.8          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000615     |
# |    value_loss           | 68.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 33           |
# |    episode_reward       | 40.3         |
# | time/                   |              |
# |    fps                  | 306          |
# |    iterations           | 33           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0011609269 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.2         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000695    |
# |    value_loss           | 69.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 34            |
# |    episode_reward       | 41.9          |
# | time/                   |               |
# |    fps                  | 305           |
# |    iterations           | 34            |
# |    time_elapsed         | 227           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00012646423 |
# |    clip_fraction        | 0.00391       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.211        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 20.4          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000233     |
# |    value_loss           | 69.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 35          |
# |    episode_reward       | 43.5        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 35          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.002133639 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.194      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.72        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0006     |
# |    value_loss           | 42.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 36          |
# |    episode_reward       | 44.3        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 36          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.001566997 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.156      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.9        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 70.4        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 37            |
# |    episode_reward       | 45.1          |
# | time/                   |               |
# |    fps                  | 302           |
# |    iterations           | 37            |
# |    time_elapsed         | 250           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00015681708 |
# |    clip_fraction        | 0.00762       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.169        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.44          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.00028      |
# |    value_loss           | 67.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 38            |
# |    episode_reward       | 45.9          |
# | time/                   |               |
# |    fps                  | 300           |
# |    iterations           | 38            |
# |    time_elapsed         | 258           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00033849527 |
# |    clip_fraction        | 0.0106        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.145        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 82.3          |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000421     |
# |    value_loss           | 69.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 39            |
# |    episode_reward       | 46.7          |
# | time/                   |               |
# |    fps                  | 299           |
# |    iterations           | 39            |
# |    time_elapsed         | 266           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00014293869 |
# |    clip_fraction        | 0.0114        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.16         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 69.3          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000388     |
# |    value_loss           | 72.6          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 40            |
# |    episode_reward       | 47.5          |
# | time/                   |               |
# |    fps                  | 299           |
# |    iterations           | 40            |
# |    time_elapsed         | 273           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 4.6080473e-05 |
# |    clip_fraction        | 0.00347       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.138        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 49            |
# |    n_updates            | 390           |
# |    policy_gradient_loss | 8.86e-05      |
# |    value_loss           | 71.4          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 41            |
# |    episode_reward       | 48.3          |
# | time/                   |               |
# |    fps                  | 298           |
# |    iterations           | 41            |
# |    time_elapsed         | 281           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00016282886 |
# |    clip_fraction        | 0.00708       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.149        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 145           |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -8.52e-05     |
# |    value_loss           | 71.2          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 42          |
# |    episode_reward       | 49.1        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 42          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.000252324 |
# |    clip_fraction        | 0.00684     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.143      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.97        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000335   |
# |    value_loss           | 71.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 43           |
# |    episode_reward       | 50.7         |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 43           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0008730254 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.12        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.99         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 74.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 44            |
# |    episode_reward       | 52.3          |
# | time/                   |               |
# |    fps                  | 295           |
# |    iterations           | 44            |
# |    time_elapsed         | 305           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00073598593 |
# |    clip_fraction        | 0.00718       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.108        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 23            |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000304     |
# |    value_loss           | 73.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 45            |
# |    episode_reward       | 53.1          |
# | time/                   |               |
# |    fps                  | 294           |
# |    iterations           | 45            |
# |    time_elapsed         | 313           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00029643145 |
# |    clip_fraction        | 0.00503       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0968       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 71.5          |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000653     |
# |    value_loss           | 74.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 46            |
# |    episode_reward       | 53.9          |
# | time/                   |               |
# |    fps                  | 293           |
# |    iterations           | 46            |
# |    time_elapsed         | 320           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00044762826 |
# |    clip_fraction        | 0.0122        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0876       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 14.2          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.00031      |
# |    value_loss           | 73.4          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 47           |
# |    episode_reward       | 54.7         |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 47           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0006067307 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0837      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.9         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000382    |
# |    value_loss           | 73.5         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 48            |
# |    episode_reward       | 55.5          |
# | time/                   |               |
# |    fps                  | 290           |
# |    iterations           | 48            |
# |    time_elapsed         | 337           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 4.7322508e-05 |
# |    clip_fraction        | 0.00107       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0767       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 13.6          |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 3.9e-05       |
# |    value_loss           | 73.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 49            |
# |    episode_reward       | 56.3          |
# | time/                   |               |
# |    fps                  | 289           |
# |    iterations           | 49            |
# |    time_elapsed         | 346           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00030776928 |
# |    clip_fraction        | 0.00752       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0676       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 51.7          |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000362     |
# |    value_loss           | 74.8          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 50            |
# |    episode_reward       | 57.9          |
# | time/                   |               |
# |    fps                  | 288           |
# |    iterations           | 50            |
# |    time_elapsed         | 354           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.00020885709 |
# |    clip_fraction        | 0.00508       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0718       |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.78          |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000354     |
# |    value_loss           | 73.6          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 51            |
# |    episode_reward       | 58.7          |
# | time/                   |               |
# |    fps                  | 288           |
# |    iterations           | 51            |
# |    time_elapsed         | 362           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00024338593 |
# |    clip_fraction        | 0.00635       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0603       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.46          |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.00087      |
# |    value_loss           | 45.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 52           |
# |    episode_reward       | 60.3         |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 52           |
# |    time_elapsed         | 370          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 5.996079e-05 |
# |    clip_fraction        | 0.00103      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.057       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.3         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -2.54e-05    |
# |    value_loss           | 73.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 53            |
# |    episode_reward       | 61.9          |
# | time/                   |               |
# |    fps                  | 286           |
# |    iterations           | 53            |
# |    time_elapsed         | 378           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 0.00022986523 |
# |    clip_fraction        | 0.00454       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0693       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 51.6          |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000253     |
# |    value_loss           | 72.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 54            |
# ...
# | train/                  |               |
# |    approx_kl            | 0.00010484451 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.063        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.36          |
# |    n_updates            | 810           |
# |    policy_gradient_loss | 2.07e-05      |
# |    value_loss           | 75.2          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 83            |
# |    episode_reward       | 89.9          |
# | time/                   |               |
# |    fps                  | 284           |
# |    iterations           | 83            |
# |    time_elapsed         | 596           |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 0.00038689587 |
# |    clip_fraction        | 0.00532       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0532       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.15          |
# |    n_updates            | 820           |
# |    policy_gradient_loss | -0.000254     |
# |    value_loss           | 74.7          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 84            |
# |    episode_reward       | 90.7          |
# | time/                   |               |
# |    fps                  | 284           |
# |    iterations           | 84            |
# |    time_elapsed         | 603           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 0.00017889566 |
# |    clip_fraction        | 0.00327       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0444       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 16.4          |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -0.000125     |
# |    value_loss           | 46.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 85           |
# |    episode_reward       | 92.3         |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 85           |
# |    time_elapsed         | 610          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0001215933 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0424      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.87         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -1.49e-05    |
# |    value_loss           | 74.5         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 86            |
# |    episode_reward       | 93.9          |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 86            |
# |    time_elapsed         | 617           |
# |    total_timesteps      | 176128        |
# | train/                  |               |
# |    approx_kl            | 0.00012464463 |
# |    clip_fraction        | 0.00161       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0337       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 23.3          |
# |    n_updates            | 850           |
# |    policy_gradient_loss | -7.62e-05     |
# |    value_loss           | 74.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 87           |
# |    episode_reward       | 94.7         |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 87           |
# |    time_elapsed         | 624          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 7.281688e-05 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0283      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.000326    |
# |    value_loss           | 72           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 88           |
# |    episode_reward       | 95.5         |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 88           |
# |    time_elapsed         | 631          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 5.322433e-05 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0248      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.4         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -4.9e-05     |
# |    value_loss           | 73.9         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 89            |
# |    episode_reward       | 96.3          |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 89            |
# |    time_elapsed         | 638           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 0.00010814043 |
# |    clip_fraction        | 0.00371       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0289       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 38.9          |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -0.000177     |
# |    value_loss           | 74.7          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 90            |
# |    episode_reward       | 97.1          |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 90            |
# |    time_elapsed         | 645           |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 0.00010409477 |
# |    clip_fraction        | 0.00166       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0245       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 76            |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -8.38e-05     |
# |    value_loss           | 74.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 91            |
# |    episode_reward       | 97.9          |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 91            |
# |    time_elapsed         | 652           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.00016040308 |
# |    clip_fraction        | 0.00137       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0216       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 18.9          |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -9.08e-05     |
# |    value_loss           | 75.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 92            |
# |    episode_reward       | 98.7          |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 92            |
# |    time_elapsed         | 659           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 0.00013155292 |
# |    clip_fraction        | 0.00483       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0157       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 39.8          |
# |    n_updates            | 910           |
# |    policy_gradient_loss | -0.000687     |
# |    value_loss           | 76.4          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 93            |
# |    episode_reward       | 99.5          |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 93            |
# |    time_elapsed         | 666           |
# |    total_timesteps      | 190464        |
# | train/                  |               |
# |    approx_kl            | 6.4932654e-05 |
# |    clip_fraction        | 0.00117       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0141       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 19.5          |
# |    n_updates            | 920           |
# |    policy_gradient_loss | -6.86e-05     |
# |    value_loss           | 75.7          |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 94        |
# |    episode_reward       | 100       |
# | time/                   |           |
# |    fps                  | 285       |
# |    iterations           | 94        |
# |    time_elapsed         | 673       |
# |    total_timesteps      | 192512    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0132   |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 15.1      |
# |    n_updates            | 930       |
# |    policy_gradient_loss | 4.7e-10   |
# |    value_loss           | 75.8      |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 95            |
# |    episode_reward       | 101           |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 95            |
# |    time_elapsed         | 680           |
# |    total_timesteps      | 194560        |
# | train/                  |               |
# |    approx_kl            | 0.00012476972 |
# |    clip_fraction        | 0.0022        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0102       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 79.9          |
# |    n_updates            | 940           |
# |    policy_gradient_loss | -0.000718     |
# |    value_loss           | 76.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 96            |
# |    episode_reward       | 102           |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 96            |
# |    time_elapsed         | 687           |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 2.1866232e-05 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0111       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 18            |
# |    n_updates            | 950           |
# |    policy_gradient_loss | -3.31e-05     |
# |    value_loss           | 75.4          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 97            |
# |    episode_reward       | 103           |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 97            |
# |    time_elapsed         | 695           |
# |    total_timesteps      | 198656        |
# | train/                  |               |
# |    approx_kl            | 3.9691484e-05 |
# |    clip_fraction        | 0.00103       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00998      |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 11.8          |
# |    n_updates            | 960           |
# |    policy_gradient_loss | -4.95e-05     |
# |    value_loss           | 75.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 98           |
# |    episode_reward       | 104          |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 98           |
# |    time_elapsed         | 704          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 3.669213e-05 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0119      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.3         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00016     |
# |    value_loss           | 75.6         |
# ------------------------------------------
# Mean episode reward: 1.05622457043857
# Mean episode length: 1.0
# Cumulative reward: 103.51000790297985
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Total Rewards: 404.0000000000031
# Total Additional Rewards: 404.0000000000031
# profit: 0.0

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 테스트 환경 설정
test_df = df  # 테스트용 데이터프레임 설정 (기존 데이터프레임 사용)
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 체크포인트 디렉토리 설정
checkpoint_dir = './checkpo/'
checkpoint_files = [os.path.join(checkpoint_dir, f) for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]

results = []

# 각 체크포인트 평가
for checkpoint_file in checkpoint_files:
    model = PPO.load(checkpoint_file, env=test_env)

    obs = test_env.reset()
    total_rewards = 0
    total_additional_rewards = 0
    total_stability_bonus = 0
    done = False

    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = test_env.step(action)
        total_rewards += info[0]['reward']
        total_additional_rewards += info[0]['additional_reward']
        total_stability_bonus += info[0]['stability_bonus']

    results.append({
        'checkpoint': checkpoint_file,
        'total_rewards': total_rewards,
        'total_profit': total_rewards - total_additional_rewards - total_stability_bonus,
        'total_additional_rewards': total_additional_rewards,
        'total_stability_bonus': total_stability_bonus,
    })

# 결과 출력
for result in results:
    print(f"Checkpoint: {result['checkpoint']}")
    print(f"Total Rewards: {result['total_rewards']}")
    print(f"total_additional_rewards: {result['total_additional_rewards']}")
    print(f"Total Stability_bonus: {result['total_stability_bonus']}")
    print(f"Total Profit: {result['total_profit']}")
    print("="*50)
# Out:
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# total_additional_rewards: 1471.9999999999698
# Checkpoint: ./check__10/ppo_stock_trading_100000_steps.zip
# Total Rewards: 3.9999999999997726
# ==================================================
# total_additional_rewards: 1473.5999999999697
# Checkpoint: ./check__10/ppo_stock_trading_120000_steps.zip
# Total Rewards: -6.8899917602534515
# ==================================================
# total_additional_rewards: 1475.1999999999694
# Checkpoint: ./check__10/ppo_stock_trading_140000_steps.zip
# Total Rewards: 0.0200042724609375
# ==================================================
# total_additional_rewards: 1473.5999999999694
# Checkpoint: ./check__10/ppo_stock_trading_160000_steps.zip
# Total Rewards: -6.77999305724984
# ==================================================
# total_additional_rewards: 1475.1999999999694
# Checkpoint: ./check__10/ppo_stock_trading_180000_steps.zip
# Total Rewards: 3.759998321533203
# ==================================================
# total_additional_rewards: 1477.5999999999692
# Checkpoint: ./check__10/ppo_stock_trading_200000_steps.zip
# Total Rewards: -1.6400032043454758
# ==================================================
# total_additional_rewards: 988.7999999999878
# Checkpoint: ./check__10/ppo_stock_trading_20000_steps.zip
# Total Rewards: -520.930025100715
# ==================================================
# total_additional_rewards: 1362.3999999999762
# Checkpoint: ./check__10/ppo_stock_trading_40000_steps.zip
# Total Rewards: -12.609956741330961
# ==================================================
# total_additional_rewards: 1439.999999999972
# Checkpoint: ./check__10/ppo_stock_trading_60000_steps.zip
# Total Rewards: -2.9600048065190094
# ==================================================
# total_additional_rewards: 1461.5999999999706
# Checkpoint: ./check__10/ppo_stock_trading_80000_steps.zip
# Total Rewards: 8.359991073607716
# ==================================================

# %%
length = len(cumu_lst)
for i in range(length//2):
    cumu_lst.pop()
plt.figure(figsize=(12, 6))
plt.plot(cumu_lst, linestyle='-')
plt.title('Episode Rewards')
plt.xlabel('Episode')
plt.ylabel('Reward')

plt.show()

# %%
tmp_lst = []
hap = sum(cumu_lst)
for k in range(len(cumu_lst)-1,-1,-1):
    hap -= cumu_lst[k]
    tmp_lst.append(hap)
cum_lst = []
for i in range(len(tmp_lst)-1,-1,-1):
    cum_lst.append(tmp_lst[i])
    
plt.figure(figsize=(12, 6))
plt.plot(cum_lst, linestyle='-')
plt.title('Episode Rewards')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.grid(True)
plt.show()

# %%
import gym
import numpy as np
import random
from IPython.display import clear_output
from time import sleep

def train_frozen_lake():
    env = gym.make("FrozenLake-v1", is_slippery=False)  # 격자 환경 생성, 미끄러짐 없음
    q_table = np.zeros([env.observation_space.n, env.action_space.n])  # Q-Table 초기화

    # 하이퍼파라미터
    num_episodes = 10000
    max_steps_per_episode = 100

    learning_rate = 0.1
    discount_rate = 0.99

    exploration_rate = 1
    max_exploration_rate = 1
    min_exploration_rate = 0.01
    exploration_decay_rate = 0.001

    rewards_all_episodes = []

    # Q-Learning 알고리즘
    for episode in range(num_episodes):
        state = env.reset()
        done = False
        rewards_current_episode = 0

        for step in range(max_steps_per_episode): 
            # 탐험 또는 활용
            exploration_threshold = random.uniform(0, 1)
            if exploration_threshold > exploration_rate:
                action = np.argmax(q_table[state,:])
            else:
                action = env.action_space.sample()
            
            new_state, reward, done,t, info = env.step(action)

            # Q-Table 업데이트
            print(new_state)
            print(state)
            q_table[state[0], action] = q_table[state[0], action] * (1 - learning_rate) + \
                                     learning_rate * (reward + discount_rate * np.max(q_table[new_state, :]))

            state = new_state
            rewards_current_episode += reward
            
            if done:
                break

        # 탐험률 감소
        exploration_rate = min_exploration_rate + \
                           (max_exploration_rate - min_exploration_rate) * np.exp(-exploration_decay_rate * episode)

        rewards_all_episodes.append(rewards_current_episode)

    # 결과 출력
    print("Training finished.\n")
    return q_table, rewards_all_episodes

q_table, rewards = train_frozen_lake()

def play_frozen_lake(trained_q_table):
    env = gym.make("FrozenLake-v1", is_slippery=False)
    state = env.reset()
    done = False
    print("***** 게임 시작 *****\n")
    env.render()

    while not done:
        action = np.argmax(trained_q_table[state, :])
        state, reward, done, info = env.step(action)
        clear_output(wait=True)
        env.render()
        if done:
            if reward == 1:
                print("**** 성공적으로 목표 도달 ****")
            else:
                print("**** 구멍에 빠짐 ****")
            sleep(2)
            clear_output(wait=True)

play_frozen_lake(q_table)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 63
#      60     print("Training finished.\n")
#      61     return q_table, rewards_all_episodes
# ---> 63 q_table, rewards = train_frozen_lake()
#      65 def play_frozen_lake(trained_q_table):
#      66     env = gym.make("FrozenLake-v1", is_slippery=False)
#
# Cell In[10], line 39, in train_frozen_lake()
#      36 else:
#      37     action = env.action_space.sample()
# ---> 39 new_state, reward, done,t, info = env.step(action)
#      41 # Q-Table 업데이트
#      42 print(new_state)
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
import numpy as np
import random

# Bandit arms을 설정합니다. 각 팔은 다른 평균 보상을 가집니다.
arms = [np.random.normal(0.2, 1), np.random.normal(0.5, 1), np.random.normal(1.5, 1), np.random.normal(1.0, 1)]
num_arms = len(arms)

# Q-values(추정 보상), 선택된 횟수 초기화
Q_values = np.zeros(num_arms)
counts = np.zeros(num_arms)

# 하이퍼파라미터
num_episodes = 100000
epsilon = 0.1  # 탐색률

# 학습 프로세스
for i in range(num_episodes):
    if random.random() > epsilon:
        # 최대 Q-value를 가진 arm 선택 (활용)
        action = np.argmax(Q_values)
    else:
        # 무작위로 arm 선택 (탐색)
        action = np.random.randint(0, num_arms)
    
    # 선택된 arm으로부터 보상을 받습니다.
    reward = np.random.normal(arms[action], 1)
    
    # 선택 횟수와 Q-value 업데이트
    counts[action] += 1
    Q_values[action] += (reward - Q_values[action]) / counts[action]

print("Estimated values:", Q_values)
# Out:
# Estimated values: [0.41702435 1.78572271 1.37593423 2.1988222 ]

# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library

# 사용할 주식 티커 목록
# Splitting the input string into a list of values based on newline separation and converting to comma-separated format
tickers = [
    "MMM", "AOS", "ABT", "ABBV", "ACN", "ATVI", "AYI", "ADBE", "AAP", "AMD", 
    "AES", "AET", "AMG", "AFL", "A", "APD", "AKAM", "ALK", "ALB", "ARE", 
    "ALXN", "ALGN", "ALLE", "AGN", "ADS", "LNT", "ALL", "GOOGL", "GOOG", 
    "MO", "AMZN", "AEE", "AAL", "AEP", "AXP", "AIG", "AMT", "AWK", "AMP", 
    "ABC", "AME", "AMGN", "APH", "APC", "ADI", "ANDV", "ANSS", "ANTM", "AON", 
    "APA", "AIV", "AAPL", "AMAT", "APTV", "ADM", "ARNC", "AJG", "AIZ", "T", 
    "ADSK", "ADP", "AZO", "AVB", "AVY", "BHGE", "BLL", "BAC", "BAX", "BBT", 
    "BDX", "BRK.B", "BBY", "BIIB", "BLK", "HRB", "BA", "BWA", "BXP", "BSX", 
    "BHF", "BMY", "AVGO", "BF.B", "CHRW", "CA", "COG", "CDNS", "CPB", "COF", 
    "CAH", "KMX", "CCL", "CAT", "CBOE", "CBG", "CBS", "CELG", "CNC", "CNP", 
    "CTL", "CERN", "CF", "SCHW", "CHTR", "CHK", "CVX", "CMG", "CB", "CHD", 
    "CI", "XEC", "CINF", "CTAS", "CSCO", "C", "CFG", "CTXS", "CME", "CMS", 
    "KO", "CTSH", "CL", "CMCSA", "CMA", "CAG", "CXO", "COP", "ED", "STZ", 
    "GLW", "COST", "COTY", "CCI", "CSRA", "CSX", "CMI", "CVS", "DHI", "DHR", 
    "DRI", "DVA", "DE", "DAL", "XRAY", "DVN", "DLR", "DFS", "DISCA", "DISCK", 
    "DISH", "DG", "DLTR", "D", "DOV", "DWDP", "DPS", "DTE", "DUK", "DRE", 
    "DXC", "ETFC", "EMN", "ETN", "EBAY", "ECL", "EIX", "EW", "EA", "EMR", 
    "ETR", "EVHC", "EOG", "EQT", "EFX", "EQIX", "EQR", "ESS", "EL", "RE", 
    "ES", "EXC", "EXPE", "EXPD", "ESRX", "EXR", "XOM", "FFIV", "FB", "FAST", 
    "FRT", "FDX", "FIS", "FITB", "FE", "FISV", "FLIR", "FLS", "FLR", "FMC", 
    "FL", "F", "FTV", "FBHS", "BEN", "FCX", "GPS", "GRMN", "IT", "GD", "GE", 
    "GGP", "GIS", "GM", "GPC", "GILD", "GPN", "GS", "GT", "GWW", "HAL", 
    "HBI", "HOG", "HRS", "HIG", "HAS", "HCA", "HCP", "HP", "HSIC", "HES", 
    "HPE", "HLT", "HOLX", "HD", "HON", "HRL", "HST", "HPQ", "HUM", "HBAN", 
    "HII", "IDXX", "INFO", "ITW", "ILMN", "INCY", "IR", "INTC", "ICE", "IBM", 
    "IP", "IPG", "IFF", "INTU", "ISRG", "IVZ", "IQV", "IRM", "JBHT", "JEC", 
    "SJM", "JNJ", "JCI", "JPM", "JNPR", "KSU", "K", "KEY", "KMB", "KIM", 
    "KMI", "KLAC", "KSS", "KHC", "KR", "LB", "LLL", "LH", "LRCX", "LEG", 
    "LEN", "LUK", "LLY", "LNC", "LKQ", "LMT", "L", "LOW", "LYB", "MTB", 
    "MAC", "M", "MRO", "MPC", "MAR", "MMC", "MLM", "MAS", "MA", "MAT", 
    "MKC", "MCD", "MCK", "MDT", "MRK", "MET", "MTD", "MGM", "KORS", "MCHP", 
    "MU", "MSFT", "MAA", "MHK", "TAP", "MDLZ", "MON", "MNST", "MCO", "MS", 
    "MSI", "MYL", "NDAQ", "NOV", "NAVI", "NTAP", "NFLX", "NWL", "NFX", 
    "NEM", "NWSA", "NWS", "NEE", "NLSN", "NKE", "NI", "NBL", "JWN", "NSC", 
    "NTRS", "NOC", "NCLH", "NRG", "NUE", "NVDA", "ORLY", "OXY", "OMC", 
    "OKE", "ORCL", "PCAR", "PKG", "PH", "PDCO", "PAYX", "PYPL", "PNR", 
    "PBCT", "PEP", "PKI", "PRGO", "PFE", "PCG", "PM", "PSX", "PNW", "PXD", 
    "PNC", "RL", "PPG", "PPL", "PX", "PCLN", "PFG", "PG", "PGR", "PLD", 
    "PRU", "PEG", "PSA", "PHM", "PVH", "QRVO", "QCOM", "PWR", "DGX", "RRC", 
    "RJF", "RTN", "O", "RHT", "REG", "REGN", "RF", "RSG", "RMD", "RHI", 
    "ROK", "COL", "ROP", "ROST", "RCL", "SPGI", "CRM", "SBAC", "SCG", 
    "SLB", "SNI", "STX", "SEE", "SRE", "SHW", "SIG", "SPG", "SWKS", "SLG", 
    "SNA", "SO", "LUV", "SWK", "SBUX", "STT", "SRCL", "SYK", "STI", "SYMC", 
    "SYF", "SNPS", "SYY", "TROW", "TPR", "TGT", "TEL", "FTI", "TXN", "TXT", 
    "BK", "CLX", "COO", "HSY", "MOS", "TRV", "DIS", "TMO", "TIF", "TWX", 
    "TJX", "TMK", "TSS", "TSCO", "TDG", "TRIP", "FOXA", "FOX", "TSN", 
    "USB", "UDR", "ULTA", "UAA", "UA", "UNP", "UAL", "UNH", "UPS", "URI", 
    "UTX", "UHS", "UNM", "VFC", "VLO", "VAR", "VTR", "VRSN", "VRSK", "VZ", 
    "VRTX", "VIAB", "V", "VNO", "VMC", "WMT", "WBA", "WM", "WAT", "WEC", 
    "WFC", "HCN", "WDC", "WU", "WRK", "WY", "WHR", "WMB", "WLTW", "WYN", 
    "WYNN", "XEL", "XRX", "XLNX", "XL", "XYL", "YUM", "ZBH", "ZION", "ZTS"
]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2019-01-01', end='2020-01-01')
    df['ticker'] = ticker  # 티커 열 추가

    # 이동 평균 (Moving Average)

    # 상대 강도 지수 (RSI: Relative Strength Index)
    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

    # MACD (Moving Average Convergence Divergence)
    macd = ta.trend.MACD(df['Close'])

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(df['Close'], window=20, window_dev=2)
    df['BB_High'] = bollinger.bollinger_hband()
    df['BB_Low'] = bollinger.bollinger_lband()
    df['BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    df['RSI'].fillna(df['RSI'].mean(), inplace=True)
    df['BB_High'].fillna(df['BB_High'].mean(), inplace=True)
    df['BB_Low'].fillna(df['BB_Low'].mean(), inplace=True)
    df['BB_Middle'].fillna(df['BB_Middle'].mean(), inplace=True)

    data[ticker] = df

# 여러 데이터프레임을 하나로 결합
combined_df = pd.concat(data.values(), ignore_index=False)

# 'Date'를 인덱스로 설정

# 필요한 열 선택 (모든 feature 포함)
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'BB_High', 'BB_Low', 'BB_Middle', 'ticker']
combined_df = combined_df[features]

print(combined_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ATVI']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AET']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# $AET: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALXN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AGN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['APC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ANDV']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# $ANDV: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ANTM']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ARNC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BHGE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BLL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BBT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# $BF.B: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CA']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['COG']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CBG']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $CBG: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CBS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CELG']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CTL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CERN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CHK']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['XEC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CTXS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CXO']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CSRA']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $CSRA: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DISCA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DISCK']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DISH']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DWDP']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DPS']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $DPS: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DRE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ETFC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EVHC']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $EVHC: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['RE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ESRX']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# $ESRX: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FB']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FISV']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FLIR']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FBHS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['GGP']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $GGP: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HRS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HCP']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['INFO']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['JEC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KSU']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LB']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LLL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LUK']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $LUK: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KORS']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $KORS: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MON']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MYL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NLSN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NBL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PBCT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PKI']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PX']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PCLN']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $PCLN: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 65
#      63 # 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
#      64 for ticker in tickers:
# ---> 65     df = yf.download(ticker, start='2019-01-01', end='2020-01-01')
#      66     df['ticker'] = ticker  # 티커 열 추가
#      68     # 이동 평균 (Moving Average)
#      69
#      70     # 상대 강도 지수 (RSI: Relative Strength Index)
#
# File ~\anaconda3\lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~\anaconda3\lib\site-packages\yfinance\multi.py:205, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session)
#     203 if len(tickers) == 1:
#     204     ticker = tickers[0]
# --> 205     return shared._DFS[ticker]
#     207 try:
#     208     data = _pd.concat(shared._DFS.values(), axis=1, sort=True,
#     209                       keys=shared._DFS.keys(), names=['Ticker', 'Price'])
#
# KeyError: 'PFG'

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

class StockTradingEnv(gym.Env):
    def __init__(self, df):
        super(StockTradingEnv, self).__init__()
        self.df = df
        self.action_space = spaces.Discrete(3)  # {0: Hold, 1: Buy, 2: Sell}
        self.observation_space = spaces.Box(low=0, high=1, shape=(len(df.columns) - 1,), dtype=np.float32)  # 'ticker' 제외

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.balance = 10000  # initial balance
        self.holdings = 0  # initial holdings
        self.total_asset = self.balance
        return self._next_observation(), {}

    def _next_observation(self):
        obs = self.df.iloc[self.current_step].drop('ticker').values
        obs_max = obs.max()
        if obs_max != 0:
            obs = obs / obs_max  # 정규화
        return np.array(obs, dtype=np.float32)


    def step(self, action):
        current_price = self.df.iloc[self.current_step]['Close']

        if action == 1:  # Buy
            if self.balance > 0:
                self.holdings += self.balance / current_price
                self.balance = 0
        elif action == 2:  # Sell
            if self.holdings > 0:
                self.balance += self.holdings * current_price
                self.holdings = 0

        self.current_step += 1
        done = self.current_step >= len(self.df) - 1
        self.total_asset = self.balance + self.holdings * current_price
        reward = self.total_asset - 10000

        obs = self._next_observation()

        if np.any(np.isnan(obs)):
            print(f"NaN found in observation at step {self.current_step}")
            print(obs)

        info = {'total_asset': self.total_asset}
        return obs, reward, done, False, info



    def render(self, mode='human'):
        pass

# 주식 거래 환경 초기화
env = StockTradingEnv(combined_df)

# 환경 체크
check_env(env)

# PPO 에이전트 정의
model = model = PPO(
        "MlpPolicy", 
        env, 
        verbose=1,
        learning_rate=0.002,
        batch_size=64,
        n_steps=2048
    )

# 에이전트 훈련
model.learn(total_timesteps=100000)

# 에이전트 평가
state, _ = env.reset()
total_rewards = 0

for _ in range(len(env.df) - 1):
    action, _ = model.predict(state)
    state, reward, done, _, info = env.step(action)
    total_rewards += reward
    if done:
        break

print(f"Total Reward: {total_rewards}")
print(f"Final Total Asset: {info['total_asset']}")

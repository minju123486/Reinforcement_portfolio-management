# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library
from sklearn.model_selection import train_test_split

# 사용할 주식 티커 목록
tickers = [
    "HBI"
]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2018-01-01', end='2024-01-01')
    df['ticker'] = ticker  # 티커 열 추가

    # 이동 평균 (Moving Average)

    # 상대 강도 지수 (RSI: Relative Strength Index)
    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

    # MACD (Moving Average Convergence Divergence)
    macd = ta.trend.MACD(df['Close'])

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(df['Close'], window=20, window_dev=2)
    df['BB_High'] = bollinger.bollinger_hband()
    df['BB_Low'] = bollinger.bollinger_lband()
    df['BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    df['RSI'].fillna(df['RSI'].mean(), inplace=True)
    df['BB_High'].fillna(df['BB_High'].mean(), inplace=True)
    df['BB_Low'].fillna(df['BB_Low'].mean(), inplace=True)
    df['BB_Middle'].fillna(df['BB_Middle'].mean(), inplace=True)

    data[ticker] = df

# 여러 데이터프레임을 하나로 결합
combined_df = pd.concat(data.values(), ignore_index=False)

# 필요한 열 선택 (모든 feature 포함)
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'BB_High', 'BB_Low', 'BB_Middle', 'ticker']
combined_df = combined_df[features]

# 'Date'를 인덱스로 설정 (필요한 경우)
combined_df.index.name = 'Date'

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df, test_df = train_test_split(combined_df, test_size=0.3, shuffle=False)

print("Train Set:")
print(train_df.head())
print("Test Set:")
print(test_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Train Set:
#                  Open       High        Low      Close   Volume        RSI  \
# Date
# 2018-01-02  21.000000  21.639999  20.930000  21.299999  4906900  47.689706
# 2018-01-03  21.340000  21.459999  20.910000  21.030001  3093300  47.689706
# 2018-01-04  21.120001  21.290001  20.850000  21.260000  4158200  47.689706
# 2018-01-05  21.290001  21.350000  21.020000  21.230000  4362300  47.689706
# 2018-01-08  21.299999  21.840000  21.299999  21.600000  5278300  47.689706
#
#               BB_High     BB_Low  BB_Middle ticker
# Date
# 2018-01-02  14.887307  12.554393   13.72085    HBI
# 2018-01-03  14.887307  12.554393   13.72085    HBI
# 2018-01-04  14.887307  12.554393   13.72085    HBI
# 2018-01-05  14.887307  12.554393   13.72085    HBI
# 2018-01-08  14.887307  12.554393   13.72085    HBI
# Test Set:
#              Open   High    Low  Close   Volume        RSI    BB_High  \
# Date
# 2022-03-14  15.63  15.79  15.05  15.16  3409900  45.354648  15.922127
# 2022-03-15  15.10  15.33  14.69  14.89  5546000  42.454551  15.936891
# 2022-03-16  14.95  15.67  14.95  15.33  7055700  48.260664  15.925616
# 2022-03-17  15.31  15.35  15.07  15.30  4230000  47.905759  15.882347
# 2022-03-18  15.02  15.47  14.91  15.39  9566500  49.114745  15.890931
#
#                BB_Low  BB_Middle ticker
# Date
# 2022-03-14  14.782873    15.3525    HBI
# 2022-03-15  14.729109    15.3330    HBI
# 2022-03-16  14.725384    15.3255    HBI
# 2022-03-17  14.729653    15.3060    HBI
# 2022-03-18  14.742069    15.3165    HBI

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import configure
import torch
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

cumu_lst = []
cumu_hap = 0

class StockTradingEnv(gym.Env):
    global cumu_lst, cumu_hap
    metadata = {'render.modes': ['human']}

    def __init__(self, df, initial_balance=100000):
        super(StockTradingEnv, self).__init__()

        self.df = df.drop(columns=['ticker'])  # ticker 열 제거
        self.action_space = spaces.Discrete(3)  # Buy, Hold, Sell
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(len(self.df.columns),), dtype=np.float32)

        self.initial_balance = initial_balance
        self.reset()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.total_profit = 0
        self.inventory = []
        self.balance = self.initial_balance
        self.state = self.df.iloc[self.current_step].values
        self.returns = [0]

        return self.state

    def step(self, action):
        global cumu_lst
        self.done = self.current_step >= len(self.df) - 1
        reward = 0
        additional_reward = 0

        if action == 0 and not self.done:  # Buy
            if self.balance >= self.state[3]:  # Check if balance is sufficient to buy
                self.inventory.append(self.state[3])  # Close price
                self.balance -= self.state[3]

        elif action == 1 and not self.done:  # Sell
            if len(self.inventory) > 0:
                bought_price = self.inventory.pop(0)
                reward = self.state[3] - bought_price  # Current price - Bought price
                self.total_profit += reward
                self.balance += self.state[3]

        # 추가된 보상 요소들
        if self.state[5] >= 70 and action == 1:  # RSI가 70 이상일 때 매도
            additional_reward += 0.9
        elif self.state[5] <= 30 and action == 0:  # RSI가 30 이하일 때 매수
            additional_reward += 0.9

        if self.state[3] >= self.state[6] and action == 1:  # 주가가 BB 상한선 이상일 때 매도
            additional_reward += 0.9
        elif self.state[3] <= self.state[7] and action == 0:  # 주가가 BB 하한선 이하일 때 매수
            additional_reward += 0.9

        if self.state[4] > self.df['Volume'].mean() and (action == 0 or action == 1):  # 거래량이 평균 이상일 때 매수 또는 매도
            additional_reward += 0.9

        total_reward = reward + additional_reward

        # Sharpe Ratio
        if len(self.returns) > 1:
            sharpe_ratio = np.mean(self.returns) / (np.std(self.returns) + 1e-10)
        else:
            sharpe_ratio = 0

        # Drawdown
        peak = np.max(self.returns)
        drawdown = peak - self.returns[-1]

        # 정규화된 Sharpe Ratio와 Drawdown
        normalized_sharpe = np.tanh(sharpe_ratio)  # -1에서 1 사이로 정규화
        normalized_drawdown = np.tanh(drawdown)  # -1에서 1 사이로 정규화

        # 스케일링 팩터
        sharpe_scale = 0.5
        drawdown_scale = 0.5

        # 보상 함수에 샤프 비율과 드로우다운 포함
        stability_bonus = sharpe_scale * normalized_sharpe - drawdown_scale * normalized_drawdown
        total_reward += stability_bonus

        # Update returns
        self.returns.append(total_reward)

        if not self.done:
            self.current_step += 1
            self.state = self.df.iloc[self.current_step].values
        else:
            self.state = np.zeros(self.observation_space.shape)  # Done 상태에서 반환할 값
            cumu_lst.append(self.total_profit)
            self.total_profit = 0

        return self.state, total_reward, self.done, {"reward": total_reward, "additional_reward": additional_reward, "sharpe_ratio": sharpe_ratio, "drawdown": drawdown, "stability_bonus": stability_bonus}

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}, Balance: {self.balance}, Total Profit: {self.total_profit}, Sharpe Ratio: {np.mean(self.returns) / np.std(self.returns) if len(self.returns) > 1 else 0}, Drawdown: {(self.max_balance - self.balance) / self.max_balance}')

# %%
class EvalCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(EvalCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.action_distribution = []
        self.state_visit_frequency = {}
        self.cumulative_rewards = []  # 누적 보상을 저장하기 위한 리스트

    def _on_step(self) -> bool:
        # Record current step action for action distribution analysis
        self.action_distribution.append(self.locals["actions"])
        # Record state visit frequency
        state_str = str(self.locals["new_obs"])
        if state_str in self.state_visit_frequency:
            self.state_visit_frequency[state_str] += 1
        else:
            self.state_visit_frequency[state_str] = 1
        return True

    def _on_rollout_end(self) -> None:
        # Log the reward and length for each episode
        episode_reward = sum(self.locals["rewards"])
        episode_length = len(self.locals["rewards"])
        self.episode_rewards.append(episode_reward)
        self.episode_lengths.append(episode_length)
        self.cumulative_rewards.append(sum(self.episode_rewards))  # 누적 보상을 추가
        self.logger.record('rollout/episode_reward', np.sum(self.episode_rewards))
        self.logger.record('rollout/episode_length', np.sum(self.episode_lengths))

    def _on_training_end(self) -> None:
        # Save evaluation results to file or print them
        print(f"Mean episode reward: {np.mean(self.episode_rewards)}")
        print(f"Mean episode length: {np.mean(self.episode_lengths)}")
        print(f"Cumulative reward: {np.sum(self.episode_rewards)}")

        # Plot action distribution
        plt.figure(figsize=(12, 6))
        plt.hist(self.action_distribution, bins=3, align='left', rwidth=0.8)
        plt.xticks(range(3), ['Buy', 'Hold', 'Sell'])
        plt.xlabel('Actions')
        plt.ylabel('Frequency')
        plt.title('Action Distribution')
        plt.show()

        # Plot episode rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.episode_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Episode Reward')
        plt.title('Episode Reward over Episodes')
        plt.show()

        # Plot cumulative rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.cumulative_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Cumulative Reward')
        plt.title('Cumulative Reward over Episodes')
        plt.show()

        # Plot state visit frequency
        state_visit_sorted = sorted(self.state_visit_frequency.items(), key=lambda item: item[1], reverse=True)
        states, visits = zip(*state_visit_sorted)
        plt.figure(figsize=(12, 6))
        plt.bar(states[:10], visits[:10])
        plt.xlabel('States')
        plt.ylabel('Visit Frequency')
        plt.title('Top 10 Most Visited States')
        plt.show()

# 데이터 로드 및 train/test 분할
train_df, test_df = train_test_split(df, test_size=0.3, shuffle=False)

# 학습 환경 설정
train_env = DummyVecEnv([lambda: StockTradingEnv(train_df)])

# CUDA 사용 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
log_dir = "./ppo_stock_trading_v11"
os.makedirs(log_dir, exist_ok=True)
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# PPO 모델 학습
from stable_baselines3.common.callbacks import CheckpointCallback

# 체크포인트 저장 콜백 설정 (예: 10000 타임스텝마다 저장)
checkpoint_callback = CheckpointCallback(save_freq=20000, save_path='./HBI/HBI_Checkpoint_6/',
                                         name_prefix='ppo_stock_trading')

# PPO 모델 학습
# model = PPO('MlpPolicy', train_env, learning_rate=0.0003, n_steps=2048, batch_size=64, n_epochs=10, gamma=0.99, verbose=1, device=device)
model = PPO('MlpPolicy', train_env, verbose=1, device=device)

model.set_logger(new_logger)

# 'stable_baselines3' 모듈에 임시로 '__version__' 속성을 추가합니다.
# import stable_baselines3 as sb3
# sb3.__version__ = "1.0.0"

model.learn(total_timesteps=200000, callback=[checkpoint_callback, EvalCallback()])

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 학습된 모델로 예측 및 결과 시각화
obs = test_env.reset()
total_rewards = 0
total_additional_rewards = 0
total_stability_bonus = 0

for _ in range(len(test_df)):
    action, _states = model.predict(obs)
    obs, rewards, done, info = test_env.step(action)
    total_rewards += info[0]['reward']
    total_additional_rewards += info[0]['additional_reward']
    total_stability_bonus += info[0]['stability_bonus']
    test_env.render()
    if done:
        break

print(f"Final Balance: {test_env.get_attr('balance')[0]}")
print(f"Total Profit: {test_env.get_attr('total_profit')[0]}")
print(f"Total Rewards: {total_rewards}")
print(f"Total Additional Rewards: {total_additional_rewards}")
print(f"Total Stability Bonus: {total_stability_bonus}")
print(f"profit: {total_rewards - total_additional_rewards - total_stability_bonus}")

# TensorBoard 로그 파일을 로컬에서 실행
# !tensorboard --logdir ./ppo_stock_trading
# Out:
# Logging to ./ppo_stock_trading_v11
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    episode_length  | 1        |
# |    episode_reward  | 0.592    |
# | time/              |          |
# |    fps             | 278      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 2           |
# |    episode_reward       | -0.243      |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 2           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011569907 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.7        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 101         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 3         |
# |    episode_reward       | 0.576     |
# | time/                   |           |
# |    fps                  | 240       |
# |    iterations           | 3         |
# |    time_elapsed         | 25        |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0131252 |
# |    clip_fraction        | 0.0795    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.06     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 18.9      |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.00407  |
# |    value_loss           | 49.9      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 4            |
# |    episode_reward       | 0.433        |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 4            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0074984017 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.8          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00605     |
# |    value_loss           | 38.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 5            |
# |    episode_reward       | 1.23         |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 5            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0046384092 |
# |    clip_fraction        | 0.052        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.988       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00749     |
# |    value_loss           | 49.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 6           |
# |    episode_reward       | 2.17        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 6           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013940213 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 50.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 7           |
# |    episode_reward       | 3.21        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 7           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016103514 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.856      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.28        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 48.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 8            |
# |    episode_reward       | 4.35         |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 8            |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0029685642 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.801       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.29         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 47.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 9           |
# |    episode_reward       | 5.34        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 9           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005858332 |
# |    clip_fraction        | 0.0214      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.81       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.18        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 48.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 10          |
# |    episode_reward       | 6.36        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 10          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011518454 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.38        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00581    |
# |    value_loss           | 46.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 11         |
# |    episode_reward       | 7.42       |
# | time/                   |            |
# |    fps                  | 233        |
# |    iterations           | 11         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01051167 |
# |    clip_fraction        | 0.0592     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.695     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 48.8       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00383   |
# |    value_loss           | 44.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 12           |
# |    episode_reward       | 8.49         |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 12           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0064351587 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.7         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -6.28e-05    |
# |    value_loss           | 49.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 13          |
# |    episode_reward       | 9.57        |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 13          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005853232 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 51.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 14           |
# |    episode_reward       | 10.6         |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 14           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0033457708 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.658       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.87         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.000173     |
# |    value_loss           | 51.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 15           |
# |    episode_reward       | 11.9         |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 15           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0064185513 |
# |    clip_fraction        | 0.074        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.4         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 53.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 16           |
# |    episode_reward       | 13.3         |
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 16           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0046650255 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.8         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 56.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 17           |
# |    episode_reward       | 14.1         |
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 17           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0024756773 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85           |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 60.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 18           |
# |    episode_reward       | 15.2         |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 18           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0068912297 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.55         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00382     |
# |    value_loss           | 33.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 19           |
# |    episode_reward       | 16.3         |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 19           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0073283864 |
# |    clip_fraction        | 0.0694       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.422       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.3         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00475     |
# |    value_loss           | 65.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 20          |
# |    episode_reward       | 17.3        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 20          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002756456 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.5        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00328    |
# |    value_loss           | 70.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 21          |
# |    episode_reward       | 18.4        |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 21          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.001108266 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.99        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.000163    |
# |    value_loss           | 70.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 22           |
# |    episode_reward       | 19.4         |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 22           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0009101082 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.432       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.7         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00066     |
# |    value_loss           | 75.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 23           |
# |    episode_reward       | 19.4         |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 23           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0031922795 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.4         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000362     |
# |    value_loss           | 74.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 24         |
# |    episode_reward       | 20.5       |
# | time/                   |            |
# |    fps                  | 232        |
# |    iterations           | 24         |
# |    time_elapsed         | 210        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00505261 |
# |    clip_fraction        | 0.054      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.504     |
# |    explained_variance   | -2.38e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.8       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.000816  |
# |    value_loss           | 77.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 25          |
# |    episode_reward       | 21.5        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 25          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.000143302 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000154   |
# |    value_loss           | 77.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 26           |
# |    episode_reward       | 22.6         |
# | time/                   |              |
# |    fps                  | 228          |
# |    iterations           | 26           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0016065727 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.86         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.000706     |
# |    value_loss           | 77.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 27           |
# |    episode_reward       | 23.7         |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 27           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0023693456 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.481       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18           |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.000134     |
# |    value_loss           | 77.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 28           |
# |    episode_reward       | 24.8         |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 28           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0011639446 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.3         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.000222     |
# |    value_loss           | 74.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 29           |
# |    episode_reward       | 26.3         |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 29           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0010105522 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.517       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.1         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 76.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 30         |
# |    episode_reward       | 27.4       |
# | time/                   |            |
# |    fps                  | 233        |
# |    iterations           | 30         |
# |    time_elapsed         | 263        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00482155 |
# |    clip_fraction        | 0.00649    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.5       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.8       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.000337  |
# |    value_loss           | 78.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 31          |
# |    episode_reward       | 28.5        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 31          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.003382257 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.02        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 78.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 32           |
# |    episode_reward       | 29.7         |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 32           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0033552295 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.497       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31           |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000803    |
# |    value_loss           | 78.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 33            |
# |    episode_reward       | 30.7          |
# | time/                   |               |
# |    fps                  | 236           |
# |    iterations           | 33            |
# |    time_elapsed         | 286           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00068827055 |
# |    clip_fraction        | 0.0271        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.472        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 60.1          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000305     |
# |    value_loss           | 81            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 34           |
# |    episode_reward       | 31.8         |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 34           |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0034229513 |
# |    clip_fraction        | 0.077        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.516       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 73.6         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 78.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 35           |
# |    episode_reward       | 32.8         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 35           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0057803476 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.5         |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.8         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -6.58e-05    |
# |    value_loss           | 41.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 36           |
# |    episode_reward       | 33.8         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 36           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0037081218 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.5         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000216    |
# |    value_loss           | 81.6         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 37            |
# |    episode_reward       | 37.3          |
# | time/                   |               |
# |    fps                  | 238           |
# |    iterations           | 37            |
# |    time_elapsed         | 317           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00064078736 |
# |    clip_fraction        | 0.00776       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.41         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.55          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | 0.000465      |
# |    value_loss           | 81            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 38           |
# |    episode_reward       | 38.3         |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 38           |
# |    time_elapsed         | 324          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0033761687 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 84.5         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000974    |
# |    value_loss           | 83           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 39          |
# |    episode_reward       | 39.3        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 39          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.001840105 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.413      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.6        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.000226    |
# |    value_loss           | 83.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 40           |
# |    episode_reward       | 40.3         |
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 40           |
# |    time_elapsed         | 340          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0025135246 |
# |    clip_fraction        | 0.00459      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.395       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.2         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000716    |
# |    value_loss           | 78.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 41           |
# |    episode_reward       | 41.5         |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 41           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0017828903 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.364       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.1         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 8.5e-05      |
# |    value_loss           | 81.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 42           |
# |    episode_reward       | 42.7         |
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 42           |
# |    time_elapsed         | 355          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0013052572 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.365       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.56         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 83.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 43          |
# |    episode_reward       | 43.8        |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 43          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.003029232 |
# |    clip_fraction        | 0.0399      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.325      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.4        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00204    |
# |    value_loss           | 80.7        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 44            |
# |    episode_reward       | 44.9          |
# | time/                   |               |
# |    fps                  | 243           |
# |    iterations           | 44            |
# |    time_elapsed         | 370           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00037131505 |
# |    clip_fraction        | 0.0119        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.306        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 10.2          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000204     |
# |    value_loss           | 83.7          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 45          |
# |    episode_reward       | 45.9        |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 45          |
# |    time_elapsed         | 395         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.001427103 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.337      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22          |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000451   |
# |    value_loss           | 87.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 46          |
# |    episode_reward       | 47          |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 46          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.003383316 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.371      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.5        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.000593   |
# |    value_loss           | 86.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 47           |
# |    episode_reward       | 48           |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 47           |
# |    time_elapsed         | 410          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0025105502 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.425       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.67         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000663    |
# |    value_loss           | 83.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 48           |
# |    episode_reward       | 49.2         |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 48           |
# |    time_elapsed         | 418          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0018527957 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.475       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.7         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 6.49e-05     |
# |    value_loss           | 81.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 49           |
# |    episode_reward       | 50           |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 49           |
# |    time_elapsed         | 425          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0013949224 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -1.58e-05    |
# |    value_loss           | 81.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 50           |
# |    episode_reward       | 50.8         |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 50           |
# |    time_elapsed         | 433          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0052568726 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000739    |
# |    value_loss           | 80.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 51           |
# |    episode_reward       | 51.8         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 51           |
# |    time_elapsed         | 440          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0015079573 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.9         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 4.5e-05      |
# |    value_loss           | 42.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 52          |
# |    episode_reward       | 52.8        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 52          |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.001192501 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.66        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -2.6e-05    |
# |    value_loss           | 80.6        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 53            |
# |    episode_reward       | 53.8          |
# | time/                   |               |
# |    fps                  | 238           |
# |    iterations           | 53            |
# |    time_elapsed         | 455           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 0.00021706594 |
# |    clip_fraction        | 0.0359        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.509        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.01          |
# |    n_updates            | 520           |
# |    policy_gradient_loss | 2.55e-05      |
# |    value_loss           | 80.4          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 54           |
# |    episode_reward       | 54.8         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 54           |
# |    time_elapsed         | 462          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0059914337 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.492       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# ...
# |    fps                  | 250          |
# |    iterations           | 82           |
# |    time_elapsed         | 671          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0013523238 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 80.3         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.000589    |
# |    value_loss           | 100          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 83           |
# |    episode_reward       | 85.3         |
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 83           |
# |    time_elapsed         | 678          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0013275277 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.274       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.5         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -1.63e-05    |
# |    value_loss           | 98.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 84           |
# |    episode_reward       | 86.3         |
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 84           |
# |    time_elapsed         | 686          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0014068427 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.305       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | 1.27e-05     |
# |    value_loss           | 50.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 85            |
# |    episode_reward       | 87.5          |
# | time/                   |               |
# |    fps                  | 250           |
# |    iterations           | 85            |
# |    time_elapsed         | 693           |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 0.00045488853 |
# |    clip_fraction        | 0.0287        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.3          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 64.1          |
# |    n_updates            | 840           |
# |    policy_gradient_loss | 0.000201      |
# |    value_loss           | 98.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 86           |
# |    episode_reward       | 89.4         |
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 86           |
# |    time_elapsed         | 701          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0008560329 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.37        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.2         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | 0.000664     |
# |    value_loss           | 100          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 87         |
# |    episode_reward       | 90.5       |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 87         |
# |    time_elapsed         | 708        |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.00749291 |
# |    clip_fraction        | 0.0468     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.401     |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57.7       |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.000172  |
# |    value_loss           | 97.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 88           |
# |    episode_reward       | 91.5         |
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 88           |
# |    time_elapsed         | 716          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0025139586 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.406       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.2         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | 0.000549     |
# |    value_loss           | 92.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 89            |
# |    episode_reward       | 92.5          |
# | time/                   |               |
# |    fps                  | 251           |
# |    iterations           | 89            |
# |    time_elapsed         | 723           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 0.00013243058 |
# |    clip_fraction        | 0.0724        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.44         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 46.6          |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -0.00208      |
# |    value_loss           | 87.6          |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 90         |
# |    episode_reward       | 93.3       |
# | time/                   |            |
# |    fps                  | 252        |
# |    iterations           | 90         |
# |    time_elapsed         | 731        |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.00323501 |
# |    clip_fraction        | 0.0209     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.471     |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.44       |
# |    n_updates            | 890        |
# |    policy_gradient_loss | 0.000546   |
# |    value_loss           | 90.4       |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 91            |
# |    episode_reward       | 94.3          |
# | time/                   |               |
# |    fps                  | 252           |
# |    iterations           | 91            |
# |    time_elapsed         | 738           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.00082664913 |
# |    clip_fraction        | 0.0264        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.498        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 79.9          |
# |    n_updates            | 900           |
# |    policy_gradient_loss | 4.3e-05       |
# |    value_loss           | 85            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 92           |
# |    episode_reward       | 95.4         |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 92           |
# |    time_elapsed         | 744          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0008168119 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24           |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -4.35e-05    |
# |    value_loss           | 85           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 93          |
# |    episode_reward       | 96.4        |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 93          |
# |    time_elapsed         | 751         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.006917662 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 80.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 94          |
# |    episode_reward       | 97.5        |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 94          |
# |    time_elapsed         | 758         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.004355341 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.2        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.000364   |
# |    value_loss           | 81.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 95          |
# |    episode_reward       | 98.7        |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 95          |
# |    time_elapsed         | 764         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.005332768 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.384      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.8        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.000436   |
# |    value_loss           | 82.2        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 96            |
# |    episode_reward       | 99.8          |
# | time/                   |               |
# |    fps                  | 255           |
# |    iterations           | 96            |
# |    time_elapsed         | 770           |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.00014016847 |
# |    clip_fraction        | 0.0158        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.323        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 60.8          |
# |    n_updates            | 950           |
# |    policy_gradient_loss | 0.000117      |
# |    value_loss           | 83.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 97           |
# |    episode_reward       | 101          |
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 97           |
# |    time_elapsed         | 776          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0014060352 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.356       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.57         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 0.000353     |
# |    value_loss           | 83.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 98           |
# |    episode_reward       | 102          |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 98           |
# |    time_elapsed         | 782          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0016602601 |
# |    clip_fraction        | 0.00347      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.306       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15           |
# |    n_updates            | 970          |
# |    policy_gradient_loss | 0.000118     |
# |    value_loss           | 82.5         |
# ------------------------------------------
# Mean episode reward: 1.0450009909287399
# Mean episode length: 1.0
# Cumulative reward: 102.41009711101651
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Balance: 100000
# Total Profit: 0
# Total Rewards: 510.0538597878761
# Total Additional Rewards: 453
# Total Stability Bonus: 57.523861008579296
# profit: -0.47000122070320316

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 테스트 환경 설정
test_df = df  # 테스트용 데이터프레임 설정 (기존 데이터프레임 사용)
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 체크포인트 디렉토리 설정
checkpoint_dir = './Single_management/HBI/HBI_Checkpoint_5/'
checkpoint_files = [os.path.join(checkpoint_dir, f) for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]

results = []

# 각 체크포인트 평가
for checkpoint_file in checkpoint_files:
    model = PPO.load(checkpoint_file, env=test_env)

    obs = test_env.reset()
    total_rewards = 0
    total_additional_rewards = 0
    total_stability_bonus = 0
    done = False

    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = test_env.step(action)
        total_rewards += info[0]['reward']
        total_additional_rewards += info[0]['additional_reward']
        total_stability_bonus += info[0]['stability_bonus']

    results.append({
        'checkpoint': checkpoint_file,
        'total_rewards': total_rewards,
        'total_profit': total_rewards - total_additional_rewards - total_stability_bonus,
        'total_additional_rewards': total_additional_rewards,
        'total_stability_bonus': total_stability_bonus,
    })

# 결과 출력
for result in results:
    print(f"Checkpoint: {result['checkpoint']}")
    print(f"Total Rewards: {result['total_rewards']}")
    print(f"total_additional_rewards: {result['total_additional_rewards']}")
    print(f"Total Stability_bonus: {result['total_stability_bonus']}")
    print(f"Total Profit: {result['total_profit']}")
    print("="*50)
# Out:
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_100000_steps.zip
# Total Rewards: 1639.091503668045
# total_additional_rewards: 1350.0000000000148
# Total Stability_bonus: 300.9914966108556
# Total Profit: -11.899992942825293
# ==================================================
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_120000_steps.zip
# Total Rewards: 1400.7625913967668
# total_additional_rewards: 1343.7000000000141
# Total Stability_bonus: 70.46261128087441
# Total Profit: -13.40001988412179
# ==================================================
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_140000_steps.zip
# Total Rewards: 1463.406143189668
# total_additional_rewards: 1343.7000000000141
# Total Stability_bonus: 126.16612820744233
# Total Profit: -6.459985017788469
# ==================================================
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_160000_steps.zip
# Total Rewards: 1415.598816767234
# total_additional_rewards: 1341.900000000014
# Total Stability_bonus: 61.28882526447395
# Total Profit: 12.409991502746074
# ==================================================
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_180000_steps.zip
# Total Rewards: 1482.7995773263615
# total_additional_rewards: 1352.700000000015
# Total Stability_bonus: 124.8295821138051
# Total Profit: 5.269995212541332
# ==================================================
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_200000_steps.zip
# Total Rewards: 1489.9965295562422
# total_additional_rewards: 1353.6000000000151
# Total Stability_bonus: 133.77653014752028
# Total Profit: 2.619999408706775
# ==================================================
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_20000_steps.zip
# Total Rewards: 621.6619525138203
# total_additional_rewards: 1087.1999999999882
# Total Stability_bonus: -288.05804651343414
# Total Profit: -177.48000097273376
# ==================================================
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_40000_steps.zip
# Total Rewards: 1343.6988016822802
# total_additional_rewards: 1313.100000000011
# Total Stability_bonus: 32.868811676785114
# Total Profit: -2.2700099945159735
# ==================================================
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_60000_steps.zip
# Total Rewards: 1340.123023507907
# total_additional_rewards: 1332.900000000013
# Total Stability_bonus: 14.783003185105837
# Total Profit: -7.559979677211924
# ==================================================
# Checkpoint: ./Single_management/HBI/HBI_Checkpoint_5/ppo_stock_trading_80000_steps.zip
# Total Rewards: 1406.0574268231194
# total_additional_rewards: 1335.6000000000133
# Total Stability_bonus: 76.92745760772607
# Total Profit: -6.470030784620008
# ==================================================

# %%
length = len(cumu_lst)
for i in range(length//2):
    cumu_lst.pop()
plt.figure(figsize=(12, 6))
plt.plot(cumu_lst, linestyle='-')
plt.title('Episode Rewards')
plt.xlabel('Episode')
plt.ylabel('Reward')

plt.show()

# %%
tmp_lst = []
hap = sum(cumu_lst)
for k in range(len(cumu_lst)-1,-1,-1):
    hap -= cumu_lst[k]
    tmp_lst.append(hap)
cum_lst = []
for i in range(len(tmp_lst)-1,-1,-1):
    cum_lst.append(tmp_lst[i])
    
plt.figure(figsize=(12, 6))
plt.plot(cum_lst, linestyle='-')
plt.title('Episode Rewards')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.grid(True)
plt.show()

# %%
import gym
import numpy as np
import random
from IPython.display import clear_output
from time import sleep

def train_frozen_lake():
    env = gym.make("FrozenLake-v1", is_slippery=False)  # 격자 환경 생성, 미끄러짐 없음
    q_table = np.zeros([env.observation_space.n, env.action_space.n])  # Q-Table 초기화

    # 하이퍼파라미터
    num_episodes = 10000
    max_steps_per_episode = 100

    learning_rate = 0.1
    discount_rate = 0.99

    exploration_rate = 1
    max_exploration_rate = 1
    min_exploration_rate = 0.01
    exploration_decay_rate = 0.001

    rewards_all_episodes = []

    # Q-Learning 알고리즘
    for episode in range(num_episodes):
        state = env.reset()
        done = False
        rewards_current_episode = 0

        for step in range(max_steps_per_episode): 
            # 탐험 또는 활용
            exploration_threshold = random.uniform(0, 1)
            if exploration_threshold > exploration_rate:
                action = np.argmax(q_table[state,:])
            else:
                action = env.action_space.sample()
            
            new_state, reward, done,t, info = env.step(action)

            # Q-Table 업데이트
            print(new_state)
            print(state)
            q_table[state[0], action] = q_table[state[0], action] * (1 - learning_rate) + \
                                     learning_rate * (reward + discount_rate * np.max(q_table[new_state, :]))

            state = new_state
            rewards_current_episode += reward
            
            if done:
                break

        # 탐험률 감소
        exploration_rate = min_exploration_rate + \
                           (max_exploration_rate - min_exploration_rate) * np.exp(-exploration_decay_rate * episode)

        rewards_all_episodes.append(rewards_current_episode)

    # 결과 출력
    print("Training finished.\n")
    return q_table, rewards_all_episodes

q_table, rewards = train_frozen_lake()

def play_frozen_lake(trained_q_table):
    env = gym.make("FrozenLake-v1", is_slippery=False)
    state = env.reset()
    done = False
    print("***** 게임 시작 *****\n")
    env.render()

    while not done:
        action = np.argmax(trained_q_table[state, :])
        state, reward, done, info = env.step(action)
        clear_output(wait=True)
        env.render()
        if done:
            if reward == 1:
                print("**** 성공적으로 목표 도달 ****")
            else:
                print("**** 구멍에 빠짐 ****")
            sleep(2)
            clear_output(wait=True)

play_frozen_lake(q_table)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 63
#      60     print("Training finished.\n")
#      61     return q_table, rewards_all_episodes
# ---> 63 q_table, rewards = train_frozen_lake()
#      65 def play_frozen_lake(trained_q_table):
#      66     env = gym.make("FrozenLake-v1", is_slippery=False)
#
# Cell In[10], line 39, in train_frozen_lake()
#      36 else:
#      37     action = env.action_space.sample()
# ---> 39 new_state, reward, done,t, info = env.step(action)
#      41 # Q-Table 업데이트
#      42 print(new_state)
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
import numpy as np
import random

# Bandit arms을 설정합니다. 각 팔은 다른 평균 보상을 가집니다.
arms = [np.random.normal(0.2, 1), np.random.normal(0.5, 1), np.random.normal(1.5, 1), np.random.normal(1.0, 1)]
num_arms = len(arms)

# Q-values(추정 보상), 선택된 횟수 초기화
Q_values = np.zeros(num_arms)
counts = np.zeros(num_arms)

# 하이퍼파라미터
num_episodes = 100000
epsilon = 0.1  # 탐색률

# 학습 프로세스
for i in range(num_episodes):
    if random.random() > epsilon:
        # 최대 Q-value를 가진 arm 선택 (활용)
        action = np.argmax(Q_values)
    else:
        # 무작위로 arm 선택 (탐색)
        action = np.random.randint(0, num_arms)
    
    # 선택된 arm으로부터 보상을 받습니다.
    reward = np.random.normal(arms[action], 1)
    
    # 선택 횟수와 Q-value 업데이트
    counts[action] += 1
    Q_values[action] += (reward - Q_values[action]) / counts[action]

print("Estimated values:", Q_values)
# Out:
# Estimated values: [0.41702435 1.78572271 1.37593423 2.1988222 ]

# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library

# 사용할 주식 티커 목록
# Splitting the input string into a list of values based on newline separation and converting to comma-separated format
tickers = [
    "MMM", "AOS", "ABT", "ABBV", "ACN", "ATVI", "AYI", "ADBE", "AAP", "AMD", 
    "AES", "AET", "AMG", "AFL", "A", "APD", "AKAM", "ALK", "ALB", "ARE", 
    "ALXN", "ALGN", "ALLE", "AGN", "ADS", "LNT", "ALL", "GOOGL", "GOOG", 
    "MO", "AMZN", "AEE", "AAL", "AEP", "AXP", "AIG", "AMT", "AWK", "AMP", 
    "ABC", "AME", "AMGN", "APH", "APC", "ADI", "ANDV", "ANSS", "ANTM", "AON", 
    "APA", "AIV", "AAPL", "AMAT", "APTV", "ADM", "ARNC", "AJG", "AIZ", "T", 
    "ADSK", "ADP", "AZO", "AVB", "AVY", "BHGE", "BLL", "BAC", "BAX", "BBT", 
    "BDX", "BRK.B", "BBY", "BIIB", "BLK", "HRB", "BA", "BWA", "BXP", "BSX", 
    "BHF", "BMY", "AVGO", "BF.B", "CHRW", "CA", "COG", "CDNS", "CPB", "COF", 
    "CAH", "KMX", "CCL", "CAT", "CBOE", "CBG", "CBS", "CELG", "CNC", "CNP", 
    "CTL", "CERN", "CF", "SCHW", "CHTR", "CHK", "CVX", "CMG", "CB", "CHD", 
    "CI", "XEC", "CINF", "CTAS", "CSCO", "C", "CFG", "CTXS", "CME", "CMS", 
    "KO", "CTSH", "CL", "CMCSA", "CMA", "CAG", "CXO", "COP", "ED", "STZ", 
    "GLW", "COST", "COTY", "CCI", "CSRA", "CSX", "CMI", "CVS", "DHI", "DHR", 
    "DRI", "DVA", "DE", "DAL", "XRAY", "DVN", "DLR", "DFS", "DISCA", "DISCK", 
    "DISH", "DG", "DLTR", "D", "DOV", "DWDP", "DPS", "DTE", "DUK", "DRE", 
    "DXC", "ETFC", "EMN", "ETN", "EBAY", "ECL", "EIX", "EW", "EA", "EMR", 
    "ETR", "EVHC", "EOG", "EQT", "EFX", "EQIX", "EQR", "ESS", "EL", "RE", 
    "ES", "EXC", "EXPE", "EXPD", "ESRX", "EXR", "XOM", "FFIV", "FB", "FAST", 
    "FRT", "FDX", "FIS", "FITB", "FE", "FISV", "FLIR", "FLS", "FLR", "FMC", 
    "FL", "F", "FTV", "FBHS", "BEN", "FCX", "GPS", "GRMN", "IT", "GD", "GE", 
    "GGP", "GIS", "GM", "GPC", "GILD", "GPN", "GS", "GT", "GWW", "HAL", 
    "HBI", "HOG", "HRS", "HIG", "HAS", "HCA", "HCP", "HP", "HSIC", "HES", 
    "HPE", "HLT", "HOLX", "HD", "HON", "HRL", "HST", "HPQ", "HUM", "HBAN", 
    "HII", "IDXX", "INFO", "ITW", "ILMN", "INCY", "IR", "INTC", "ICE", "IBM", 
    "IP", "IPG", "IFF", "INTU", "ISRG", "IVZ", "IQV", "IRM", "JBHT", "JEC", 
    "SJM", "JNJ", "JCI", "JPM", "JNPR", "KSU", "K", "KEY", "KMB", "KIM", 
    "KMI", "KLAC", "KSS", "KHC", "KR", "LB", "LLL", "LH", "LRCX", "LEG", 
    "LEN", "LUK", "LLY", "LNC", "LKQ", "LMT", "L", "LOW", "LYB", "MTB", 
    "MAC", "M", "MRO", "MPC", "MAR", "MMC", "MLM", "MAS", "MA", "MAT", 
    "MKC", "MCD", "MCK", "MDT", "MRK", "MET", "MTD", "MGM", "KORS", "MCHP", 
    "MU", "MSFT", "MAA", "MHK", "TAP", "MDLZ", "MON", "MNST", "MCO", "MS", 
    "MSI", "MYL", "NDAQ", "NOV", "NAVI", "NTAP", "NFLX", "NWL", "NFX", 
    "NEM", "NWSA", "NWS", "NEE", "NLSN", "NKE", "NI", "NBL", "JWN", "NSC", 
    "NTRS", "NOC", "NCLH", "NRG", "NUE", "NVDA", "ORLY", "OXY", "OMC", 
    "OKE", "ORCL", "PCAR", "PKG", "PH", "PDCO", "PAYX", "PYPL", "PNR", 
    "PBCT", "PEP", "PKI", "PRGO", "PFE", "PCG", "PM", "PSX", "PNW", "PXD", 
    "PNC", "RL", "PPG", "PPL", "PX", "PCLN", "PFG", "PG", "PGR", "PLD", 
    "PRU", "PEG", "PSA", "PHM", "PVH", "QRVO", "QCOM", "PWR", "DGX", "RRC", 
    "RJF", "RTN", "O", "RHT", "REG", "REGN", "RF", "RSG", "RMD", "RHI", 
    "ROK", "COL", "ROP", "ROST", "RCL", "SPGI", "CRM", "SBAC", "SCG", 
    "SLB", "SNI", "STX", "SEE", "SRE", "SHW", "SIG", "SPG", "SWKS", "SLG", 
    "SNA", "SO", "LUV", "SWK", "SBUX", "STT", "SRCL", "SYK", "STI", "SYMC", 
    "SYF", "SNPS", "SYY", "TROW", "TPR", "TGT", "TEL", "FTI", "TXN", "TXT", 
    "BK", "CLX", "COO", "HSY", "MOS", "TRV", "DIS", "TMO", "TIF", "TWX", 
    "TJX", "TMK", "TSS", "TSCO", "TDG", "TRIP", "FOXA", "FOX", "TSN", 
    "USB", "UDR", "ULTA", "UAA", "UA", "UNP", "UAL", "UNH", "UPS", "URI", 
    "UTX", "UHS", "UNM", "VFC", "VLO", "VAR", "VTR", "VRSN", "VRSK", "VZ", 
    "VRTX", "VIAB", "V", "VNO", "VMC", "WMT", "WBA", "WM", "WAT", "WEC", 
    "WFC", "HCN", "WDC", "WU", "WRK", "WY", "WHR", "WMB", "WLTW", "WYN", 
    "WYNN", "XEL", "XRX", "XLNX", "XL", "XYL", "YUM", "ZBH", "ZION", "ZTS"
]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2019-01-01', end='2020-01-01')
    df['ticker'] = ticker  # 티커 열 추가

    # 이동 평균 (Moving Average)

    # 상대 강도 지수 (RSI: Relative Strength Index)
    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

    # MACD (Moving Average Convergence Divergence)
    macd = ta.trend.MACD(df['Close'])

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(df['Close'], window=20, window_dev=2)
    df['BB_High'] = bollinger.bollinger_hband()
    df['BB_Low'] = bollinger.bollinger_lband()
    df['BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    df['RSI'].fillna(df['RSI'].mean(), inplace=True)
    df['BB_High'].fillna(df['BB_High'].mean(), inplace=True)
    df['BB_Low'].fillna(df['BB_Low'].mean(), inplace=True)
    df['BB_Middle'].fillna(df['BB_Middle'].mean(), inplace=True)

    data[ticker] = df

# 여러 데이터프레임을 하나로 결합
combined_df = pd.concat(data.values(), ignore_index=False)

# 'Date'를 인덱스로 설정

# 필요한 열 선택 (모든 feature 포함)
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'BB_High', 'BB_Low', 'BB_Middle', 'ticker']
combined_df = combined_df[features]

print(combined_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ATVI']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AET']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# $AET: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALXN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AGN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['APC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ANDV']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# $ANDV: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ANTM']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ARNC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BHGE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BLL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BBT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# $BF.B: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CA']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['COG']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CBG']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $CBG: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CBS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CELG']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CTL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CERN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CHK']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['XEC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CTXS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CXO']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['CSRA']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $CSRA: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DISCA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DISCK']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DISH']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DWDP']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DPS']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $DPS: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['DRE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ETFC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EVHC']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $EVHC: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['RE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ESRX']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# $ESRX: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FB']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FISV']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FLIR']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['FBHS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['GGP']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $GGP: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HRS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['HCP']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['INFO']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['JEC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KSU']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LB']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LLL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['LUK']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $LUK: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['KORS']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $KORS: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MON']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MYL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NLSN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NBL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PBCT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PKI']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PX']: YFChartError("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1577854800")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['PCLN']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)')
# $PCLN: possibly delisted; No price data found  (1d 2019-01-01 -> 2020-01-01)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 65
#      63 # 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
#      64 for ticker in tickers:
# ---> 65     df = yf.download(ticker, start='2019-01-01', end='2020-01-01')
#      66     df['ticker'] = ticker  # 티커 열 추가
#      68     # 이동 평균 (Moving Average)
#      69
#      70     # 상대 강도 지수 (RSI: Relative Strength Index)
#
# File ~\anaconda3\lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~\anaconda3\lib\site-packages\yfinance\multi.py:205, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session)
#     203 if len(tickers) == 1:
#     204     ticker = tickers[0]
# --> 205     return shared._DFS[ticker]
#     207 try:
#     208     data = _pd.concat(shared._DFS.values(), axis=1, sort=True,
#     209                       keys=shared._DFS.keys(), names=['Ticker', 'Price'])
#
# KeyError: 'PFG'

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

class StockTradingEnv(gym.Env):
    def __init__(self, df):
        super(StockTradingEnv, self).__init__()
        self.df = df
        self.action_space = spaces.Discrete(3)  # {0: Hold, 1: Buy, 2: Sell}
        self.observation_space = spaces.Box(low=0, high=1, shape=(len(df.columns) - 1,), dtype=np.float32)  # 'ticker' 제외

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.balance = 10000  # initial balance
        self.holdings = 0  # initial holdings
        self.total_asset = self.balance
        return self._next_observation(), {}

    def _next_observation(self):
        obs = self.df.iloc[self.current_step].drop('ticker').values
        obs_max = obs.max()
        if obs_max != 0:
            obs = obs / obs_max  # 정규화
        return np.array(obs, dtype=np.float32)


    def step(self, action):
        current_price = self.df.iloc[self.current_step]['Close']

        if action == 1:  # Buy
            if self.balance > 0:
                self.holdings += self.balance / current_price
                self.balance = 0
        elif action == 2:  # Sell
            if self.holdings > 0:
                self.balance += self.holdings * current_price
                self.holdings = 0

        self.current_step += 1
        done = self.current_step >= len(self.df) - 1
        self.total_asset = self.balance + self.holdings * current_price
        reward = self.total_asset - 10000

        obs = self._next_observation()

        if np.any(np.isnan(obs)):
            print(f"NaN found in observation at step {self.current_step}")
            print(obs)

        info = {'total_asset': self.total_asset}
        return obs, reward, done, False, info



    def render(self, mode='human'):
        pass

# 주식 거래 환경 초기화
env = StockTradingEnv(combined_df)

# 환경 체크
check_env(env)

# PPO 에이전트 정의
model = model = PPO(
        "MlpPolicy", 
        env, 
        verbose=1,
        learning_rate=0.002,
        batch_size=64,
        n_steps=2048
    )

# 에이전트 훈련
model.learn(total_timesteps=100000)

# 에이전트 평가
state, _ = env.reset()
total_rewards = 0

for _ in range(len(env.df) - 1):
    action, _ = model.predict(state)
    state, reward, done, _, info = env.step(action)
    total_rewards += reward
    if done:
        break

print(f"Total Reward: {total_rewards}")
print(f"Final Total Asset: {info['total_asset']}")

# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library
from sklearn.model_selection import train_test_split

# 사용할 주식 티커 목록
tickers = ["HBI", "GM", "BXP"]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2018-01-01', end='2024-01-01')
    df.rename(columns={
        'Open': f'{ticker}_Open',
        'High': f'{ticker}_High',
        'Low': f'{ticker}_Low',
        'Close': f'{ticker}_Close',
        'Volume': f'{ticker}_Volume',
        'Adj Close': f'{ticker}_Adj_Close'
    }, inplace=True)
    df[f'{ticker}_ticker'] = ticker  # 티커 열 추가
    data[ticker] = df

# 데이터프레임을 동일한 날짜 인덱스로 결합
combined_df = pd.concat(data.values(), axis=1)

# 결합된 데이터프레임에 기술 지표 추가
for ticker in tickers:
    # 상대 강도 지수 (RSI: Relative Strength Index)
    combined_df[f'{ticker}_RSI'] = ta.momentum.RSIIndicator(combined_df[f'{ticker}_Close'], window=14).rsi()

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(combined_df[f'{ticker}_Close'], window=20, window_dev=2)
    combined_df[f'{ticker}_BB_High'] = bollinger.bollinger_hband()
    combined_df[f'{ticker}_BB_Low'] = bollinger.bollinger_lband()
    combined_df[f'{ticker}_BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    combined_df[f'{ticker}_RSI'].fillna(combined_df[f'{ticker}_RSI'].mean(), inplace=True)
    combined_df[f'{ticker}_BB_High'].fillna(combined_df[f'{ticker}_BB_High'].mean(), inplace=True)
    combined_df[f'{ticker}_BB_Low'].fillna(combined_df[f'{ticker}_BB_Low'].mean(), inplace=True)
    combined_df[f'{ticker}_BB_Middle'].fillna(combined_df[f'{ticker}_BB_Middle'].mean(), inplace=True)

# 필요한 열 선택 (모든 feature 포함)
features = []
for ticker in tickers:
    features.extend([f'{ticker}_Open', f'{ticker}_High', f'{ticker}_Low', f'{ticker}_Close', f'{ticker}_Volume', f'{ticker}_RSI', f'{ticker}_BB_High', f'{ticker}_BB_Low', f'{ticker}_BB_Middle', f'{ticker}_ticker'])

combined_df = combined_df[features]

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df, test_df = train_test_split(combined_df, test_size=0.3, shuffle=False)

# 'Date'를 인덱스로 설정 (필요한 경우)
train_df.index.name = 'Date'
test_df.index.name = 'Date'

print("Train Set:")
print(train_df.head())
print("Test Set:")
print(test_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Train Set:
#              HBI_Open   HBI_High    HBI_Low  HBI_Close  HBI_Volume    HBI_RSI  \
# Date
# 2018-01-02  21.000000  21.639999  20.930000  21.299999     4906900  47.689706
# 2018-01-03  21.340000  21.459999  20.910000  21.030001     3093300  47.689706
# 2018-01-04  21.120001  21.290001  20.850000  21.260000     4158200  47.689706
# 2018-01-05  21.290001  21.350000  21.020000  21.230000     4362300  47.689706
# 2018-01-08  21.299999  21.840000  21.299999  21.600000     5278300  47.689706
#
#             HBI_BB_High  HBI_BB_Low  HBI_BB_Middle HBI_ticker  ...  \
# Date                                                           ...
# 2018-01-02    14.887307   12.554393       13.72085        HBI  ...
# 2018-01-03    14.887307   12.554393       13.72085        HBI  ...
# 2018-01-04    14.887307   12.554393       13.72085        HBI  ...
# 2018-01-05    14.887307   12.554393       13.72085        HBI  ...
# 2018-01-08    14.887307   12.554393       13.72085        HBI  ...
#
#               BXP_Open    BXP_High     BXP_Low   BXP_Close  BXP_Volume  \
# Date
# 2018-01-02  130.389999  130.389999  128.889999  129.279999      690000
# 2018-01-03  129.570007  129.800003  128.729996  129.350006      570600
# 2018-01-04  129.000000  129.000000  126.459999  126.480003     2079000
# 2018-01-05  126.830002  127.970001  126.519997  127.860001      860900
# 2018-01-08  127.540001  128.000000  125.820000  126.739998      724300
#
#               BXP_RSI  BXP_BB_High  BXP_BB_Low  BXP_BB_Middle BXP_ticker
# Date
# 2018-01-02  49.709772     109.5883   97.412739     103.500519        BXP
# 2018-01-03  49.709772     109.5883   97.412739     103.500519        BXP
# 2018-01-04  49.709772     109.5883   97.412739     103.500519        BXP
# 2018-01-05  49.709772     109.5883   97.412739     103.500519        BXP
# 2018-01-08  49.709772     109.5883   97.412739     103.500519        BXP
#
# [5 rows x 30 columns]
# Test Set:
#             HBI_Open  HBI_High  HBI_Low  HBI_Close  HBI_Volume    HBI_RSI  \
# Date
# 2022-03-14     15.63     15.79    15.05      15.16     3409900  45.354648
# 2022-03-15     15.10     15.33    14.69      14.89     5546000  42.454551
# 2022-03-16     14.95     15.67    14.95      15.33     7055700  48.260664
# 2022-03-17     15.31     15.35    15.07      15.30     4230000  47.905759
# 2022-03-18     15.02     15.47    14.91      15.39     9566500  49.114745
#
#             HBI_BB_High  HBI_BB_Low  HBI_BB_Middle HBI_ticker  ...  \
# Date                                                           ...
# 2022-03-14    15.922127   14.782873        15.3525        HBI  ...
# 2022-03-15    15.936891   14.729109        15.3330        HBI  ...
# 2022-03-16    15.925616   14.725384        15.3255        HBI  ...
# 2022-03-17    15.882347   14.729653        15.3060        HBI  ...
# 2022-03-18    15.890931   14.742069        15.3165        HBI  ...
#
#               BXP_Open    BXP_High     BXP_Low   BXP_Close  BXP_Volume  \
# Date
# 2022-03-14  124.669998  125.680000  122.239998  122.800003      876800
# 2022-03-15  123.470001  124.239998  121.419998  122.660004      674000
# 2022-03-16  124.120003  125.000000  121.410004  123.779999      760000
# 2022-03-17  123.269997  124.750000  122.879997  124.739998      536200
# 2022-03-18  124.339996  124.690002  122.589996  124.550003     1226100
#
#               BXP_RSI  BXP_BB_High  BXP_BB_Low  BXP_BB_Middle BXP_ticker
# Date
# 2022-03-14  55.073707   125.532769  118.051231     121.792000        BXP
# 2022-03-15  54.666765   125.098923  119.056078     122.077501        BXP
# 2022-03-16  57.379937   125.205755  119.337245     122.271500        BXP
# 2022-03-17  59.611250   125.504057  119.254943     122.379500        BXP
# 2022-03-18  58.953424   125.764101  119.247900     122.506001        BXP
#
# [5 rows x 30 columns]

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import configure
import torch
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

cumu_lst = []
cumu_hap = 0

class StockTradingEnv(gym.Env):
    global cumu_lst, cumu_hap
    metadata = {'render.modes': ['human']}

    def __init__(self, df_list, initial_balance=100000):
        super(StockTradingEnv, self).__init__()

        self.df_list = [df.drop(columns=[col for col in df.columns if 'ticker' in col]) for df in df_list]  # ticker 열 제거
        self.n_stocks = len(df_list)
        self.action_space = spaces.MultiDiscrete([3] * self.n_stocks)  # 각 주식에 대해 Buy, Hold, Sell
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.n_stocks, len(self.df_list[0].columns)), dtype=np.float32)

        self.initial_balance = initial_balance
        self.reset()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.total_profit = 0
        self.inventory = [[] for _ in range(self.n_stocks)]
        self.balance = self.initial_balance
        self.state = np.array([df.iloc[self.current_step].values for df in self.df_list])
        self.returns = [0]

        return self.state

    def step(self, action):
        global cumu_lst
        self.done = self.current_step >= len(self.df_list[0]) - 1
        reward = 0
        additional_reward = 0

        for i, act in enumerate(action):
            if act == 0 and not self.done:  # Buy
                if self.balance >= self.state[i][3]:  # Check if balance is sufficient to buy
                    self.inventory[i].append(self.state[i][3])  # Close price
                    self.balance -= self.state[i][3]

            elif act == 1 and not self.done:  # Sell
                if len(self.inventory[i]) > 0:
                    bought_price = self.inventory[i].pop(0)
                    reward += self.state[i][3] - bought_price  # Current price - Bought price
                    self.total_profit += reward
                    self.balance += self.state[i][3]

            # 추가된 보상 요소들
            if self.state[i][5] >= 70 and act == 1:  # RSI가 70 이상일 때 매도
                additional_reward += 0.35
            elif self.state[i][5] <= 30 and act == 0:  # RSI가 30 이하일 때 매수
                additional_reward += 0.35

            if self.state[i][3] >= self.state[i][6] and act == 1:  # 주가가 BB 상한선 이상일 때 매도
                additional_reward += 0.35
            elif self.state[i][3] <= self.state[i][7] and act == 0:  # 주가가 BB 하한선 이하일 때 매수
                additional_reward += 0.35

            if self.state[i][4] > self.df_list[i].iloc[:, 4].mean() and (act == 0 or act == 1):  # 거래량이 평균 이상일 때 매수 또는 매도
                additional_reward += 0.35

        total_reward = reward + additional_reward

        # Sharpe Ratio
        if len(self.returns) > 1:
            sharpe_ratio = np.mean(self.returns) / (np.std(self.returns) + 1e-10)
        else:
            sharpe_ratio = 0

        # Drawdown
        peak = np.max(self.returns)
        drawdown = peak - self.returns[-1]

        # 정규화된 Sharpe Ratio와 Drawdown
        normalized_sharpe = np.tanh(sharpe_ratio)  # -1에서 1 사이로 정규화
        normalized_drawdown = np.tanh(drawdown)  # -1에서 1 사이로 정규화

        # 스케일링 팩터
        sharpe_scale = 0.5
        drawdown_scale = 0.5

        # 보상 함수에 샤프 비율과 드로우다운 포함
        stability_bonus = sharpe_scale * normalized_sharpe - drawdown_scale * normalized_drawdown
        total_reward += stability_bonus

        # Update returns
        self.returns.append(total_reward)

        if not self.done:
            self.current_step += 1
            self.state = np.array([df.iloc[self.current_step].values for df in self.df_list])
        else:
            self.state = np.zeros(self.observation_space.shape)  # Done 상태에서 반환할 값
            cumu_lst.append(self.total_profit)
            self.total_profit = 0

        return self.state, total_reward, self.done, {"reward": total_reward, "additional_reward": additional_reward, "sharpe_ratio": sharpe_ratio, "drawdown": drawdown, "stability_bonus": stability_bonus}

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}, Balance: {self.balance}, Total Profit: {self.total_profit}, Sharpe Ratio: {np.mean(self.returns) / np.std(self.returns) if len(self.returns) > 1 else 0}, Drawdown: {(self.max_balance - self.balance) / self.max_balance}')

# %%
class EvalCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(EvalCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.action_distribution = []
        self.state_visit_frequency = {}
        self.cumulative_rewards = []  # 누적 보상을 저장하기 위한 리스트

    def _on_step(self) -> bool:
        # Record current step action for action distribution analysis
        actions = self.locals["actions"].flatten()  # Flatten actions to 1D
        self.action_distribution.extend(actions)
        
        # Record state visit frequency
        state_str = str(self.locals["new_obs"])
        if state_str in self.state_visit_frequency:
            self.state_visit_frequency[state_str] += 1
        else:
            self.state_visit_frequency[state_str] = 1
        return True

    def _on_rollout_end(self) -> None:
        # Log the reward and length for each episode
        episode_reward = sum(self.locals["rewards"])
        episode_length = len(self.locals["rewards"])
        self.episode_rewards.append(episode_reward)
        self.episode_lengths.append(episode_length)
        self.cumulative_rewards.append(sum(self.episode_rewards))  # 누적 보상을 추가
        self.logger.record('rollout/episode_reward', np.sum(self.episode_rewards))
        self.logger.record('rollout/episode_length', np.sum(self.episode_lengths))

    def _on_training_end(self) -> None:
        # Save evaluation results to file or print them
        print(f"Mean episode reward: {np.mean(self.episode_rewards)}")
        print(f"Mean episode length: {np.mean(self.episode_lengths)}")
        print(f"Cumulative reward: {np.sum(self.episode_rewards)}")

        # Plot action distribution
        plt.figure(figsize=(12, 6))
        plt.hist(self.action_distribution, bins=3, align='left', rwidth=0.8)
        plt.xticks(range(3), ['Buy', 'Hold', 'Sell'])
        plt.xlabel('Actions')
        plt.ylabel('Frequency')
        plt.title('Action Distribution')
        plt.show()

        # Plot episode rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.episode_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Episode Reward')
        plt.title('Episode Reward over Episodes')
        plt.show()

        # Plot cumulative rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.cumulative_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Cumulative Reward')
        plt.title('Cumulative Reward over Episodes')
        plt.show()

        # Plot state visit frequency
        state_visit_sorted = sorted(self.state_visit_frequency.items(), key=lambda item: item[1], reverse=True)
        states, visits = zip(*state_visit_sorted)
        plt.figure(figsize=(12, 6))
        plt.bar(states[:10], visits[:10])
        plt.xlabel('States')
        plt.ylabel('Visit Frequency')
        plt.title('Top 10 Most Visited States')
        plt.show()

# %%
# 학습 환경 설정
train_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[0] for ticker in tickers]
test_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[1] for ticker in tickers]

train_env = DummyVecEnv([lambda: StockTradingEnv(train_df_list)])

# CUDA 사용 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
log_dir = "./ppo_stock_trading_v11"
os.makedirs(log_dir, exist_ok=True)
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# PPO 모델 학습
from stable_baselines3.common.callbacks import CheckpointCallback

# 체크포인트 저장 콜백 설정 (예: 10000 타임스텝마다 저장)
checkpoint_callback = CheckpointCallback(save_freq=20000, save_path='./Multi_management_HBI_GM_BXP/Checkpoint_0.35/', name_prefix='ppo_stock_trading')

# PPO 모델 학습
model = PPO('MlpPolicy', train_env, verbose=1, device=device)
model.set_logger(new_logger)
model.learn(total_timesteps=400000, callback=[checkpoint_callback, EvalCallback()])

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df_list)])

# 학습된 모델로 예측 및 결과 시각화
obs = test_env.reset()
total_rewards = 0
total_additional_rewards = 0
total_stability_bonus = 0

for _ in range(len(test_df_list[0])):
    action, _states = model.predict(obs)
    obs, rewards, done, info = test_env.step(action)
    total_rewards += info[0]['reward']
    total_additional_rewards += info[0]['additional_reward']
    total_stability_bonus += info[0]['stability_bonus']
    test_env.render()
    if done:
        break

print(f"Final Balance: {test_env.get_attr('balance')[0]}")
print(f"Total Profit: {test_env.get_attr('total_profit')[0]}")
print(f"Total Rewards: {total_rewards}")
print(f"Total Additional Rewards: {total_additional_rewards}")
print(f"Total Stability Bonus: {total_stability_bonus}")
print(f"profit: {total_rewards - total_additional_rewards - total_stability_bonus}")
# Out:
# Logging to ./ppo_stock_trading_v11
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    episode_length  | 1        |
# |    episode_reward  | 6.28     |
# | time/              |          |
# |    fps             | 236      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 2           |
# |    episode_reward       | 5.61        |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008754807 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.00209     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.79e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 7.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 3           |
# |    episode_reward       | 24.8        |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 3           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007662851 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.0334      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.14e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00572    |
# |    value_loss           | 7.92e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 4          |
# |    episode_reward       | 26.7       |
# | time/                   |            |
# |    fps                  | 197        |
# |    iterations           | 4          |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00848506 |
# |    clip_fraction        | 0.0621     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.0622     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.56e+03   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00543   |
# |    value_loss           | 4.87e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 5            |
# |    episode_reward       | 35.2         |
# | time/                   |              |
# |    fps                  | 197          |
# |    iterations           | 5            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0075508244 |
# |    clip_fraction        | 0.0966       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.25        |
# |    explained_variance   | 0.0425       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.24e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00881     |
# |    value_loss           | 4.37e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 6            |
# |    episode_reward       | 47.6         |
# | time/                   |              |
# |    fps                  | 196          |
# |    iterations           | 6            |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0061797965 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.24        |
# |    explained_variance   | 0.0595       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 6.98e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 7           |
# |    episode_reward       | 47          |
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 7           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009322999 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.0919      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00911    |
# |    value_loss           | 3.48e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 8           |
# |    episode_reward       | 43.8        |
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 8           |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007321003 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.0786      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.09e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00638    |
# |    value_loss           | 1.57e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 9          |
# |    episode_reward       | 43.2       |
# | time/                   |            |
# |    fps                  | 195        |
# |    iterations           | 9          |
# |    time_elapsed         | 94         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00745969 |
# |    clip_fraction        | 0.0346     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.11       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.83e+03   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00519   |
# |    value_loss           | 1.58e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 10           |
# |    episode_reward       | 40.5         |
# | time/                   |              |
# |    fps                  | 195          |
# |    iterations           | 10           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0068866517 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74e+04     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00446     |
# |    value_loss           | 1.8e+04      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 11          |
# |    episode_reward       | 40.6        |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 11          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009286348 |
# |    clip_fraction        | 0.056       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.15e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00687    |
# |    value_loss           | 1.58e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 12           |
# |    episode_reward       | 40           |
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 12           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0063166423 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.21        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.03e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00579     |
# |    value_loss           | 1.14e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 13          |
# |    episode_reward       | 39.4        |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 13          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010301542 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.43e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 8.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 14          |
# |    episode_reward       | 39.9        |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 14          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007724941 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.47e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00517    |
# |    value_loss           | 1.87e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 15           |
# |    episode_reward       | 36           |
# | time/                   |              |
# |    fps                  | 192          |
# |    iterations           | 15           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0076925787 |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.68e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0083      |
# |    value_loss           | 1.53e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 16          |
# |    episode_reward       | 35.5        |
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 16          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006912037 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.22e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 1.53e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 17          |
# |    episode_reward       | 35.1        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 17          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009628776 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.0772      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.83e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 1.56e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 18          |
# |    episode_reward       | 52.2        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 18          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005798421 |
# |    clip_fraction        | 0.0462      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.0698      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.88e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00679    |
# |    value_loss           | 1.8e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 19          |
# |    episode_reward       | 47.8        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 19          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007343529 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | -0.0161     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.04e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 1.4e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 20          |
# |    episode_reward       | 47.5        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 20          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008284939 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | -0.004      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.97e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 9.65e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 21          |
# |    episode_reward       | 47.2        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 21          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009391426 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.0143      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.83e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 1.14e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 22           |
# |    episode_reward       | -0.864       |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 22           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0076156193 |
# |    clip_fraction        | 0.074        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | 0.0227       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.33e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00816     |
# |    value_loss           | 5.79e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 23          |
# |    episode_reward       | -1.06       |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 23          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009478547 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.0406      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 4.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 24          |
# |    episode_reward       | -0.827      |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 24          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006213263 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.0388      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00757    |
# |    value_loss           | 4.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 25          |
# |    episode_reward       | -2.15       |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 25          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010029801 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.0837      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.47e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00968    |
# |    value_loss           | 2.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 26          |
# |    episode_reward       | -2.6        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 26          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009181334 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.0905      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.07e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00927    |
# |    value_loss           | 2.68e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 27           |
# |    episode_reward       | -3.09        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 27           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0074779396 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.0011       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 915          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00732     |
# |    value_loss           | 2.22e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 28          |
# |    episode_reward       | -3.5        |
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 28          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008078924 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | -0.0199     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00733    |
# |    value_loss           | 3.32e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 29          |
# |    episode_reward       | -7.74       |
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 29          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011923084 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | -0.012      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00992    |
# |    value_loss           | 2.29e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 30           |
# |    episode_reward       | -7.64        |
# | time/                   |              |
# |    fps                  | 190          |
# |    iterations           | 30           |
# |    time_elapsed         | 322          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0099716615 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.0177       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 723          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00818     |
# |    value_loss           | 1.37e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 31          |
# |    episode_reward       | -6.59       |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 31          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010050811 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.0375      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 482         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00749    |
# |    value_loss           | 926         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 32           |
# |    episode_reward       | -6.67        |
# | time/                   |              |
# |    fps                  | 189          |
# |    iterations           | 32           |
# |    time_elapsed         | 345          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0076748244 |
# |    clip_fraction        | 0.0806       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0424       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 677          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00935     |
# |    value_loss           | 1.52e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 33          |
# |    episode_reward       | -7.2        |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 33          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008564341 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.0747      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8e+03     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00738    |
# |    value_loss           | 3.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 34          |
# |    episode_reward       | -7.66       |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 34          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009683978 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 890         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00938    |
# |    value_loss           | 1.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 35          |
# |    episode_reward       | -8.09       |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 35          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007975311 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.58e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00671    |
# |    value_loss           | 3.89e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 36          |
# |    episode_reward       | -5.66       |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 36          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007806658 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.32e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 3.55e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 37           |
# |    episode_reward       | -5.49        |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 37           |
# |    time_elapsed         | 401          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0086535895 |
# |    clip_fraction        | 0.0925       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 2.25e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 38         |
# |    episode_reward       | 9.27       |
# | time/                   |            |
# |    fps                  | 188        |
# |    iterations           | 38         |
# |    time_elapsed         | 412        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00943483 |
# |    clip_fraction        | 0.0764     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.73      |
# |    explained_variance   | 0.129      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.55e+03   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00805   |
# |    value_loss           | 5.24e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 39          |
# |    episode_reward       | 8.7         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 39          |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008700699 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8e+03     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00465    |
# |    value_loss           | 4.81e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 40           |
# |    episode_reward       | 8.21         |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 40           |
# |    time_elapsed         | 435          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0060448684 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00568     |
# |    value_loss           | 2.38e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 41          |
# |    episode_reward       | 4.97        |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 41          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009995783 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00536    |
# |    value_loss           | 2.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 42          |
# |    episode_reward       | 16.6        |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 42          |
# |    time_elapsed         | 456         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008460907 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 891         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 1.65e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 43           |
# |    episode_reward       | 16.1         |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 43           |
# |    time_elapsed         | 467          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0073210774 |
# |    clip_fraction        | 0.0719       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1e+03        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00538     |
# |    value_loss           | 1.71e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 44          |
# |    episode_reward       | 16          |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 44          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008017175 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.0825      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 709         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00871    |
# |    value_loss           | 1.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 45          |
# |    episode_reward       | 15.4        |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 45          |
# |    time_elapsed         | 491         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007979604 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.0934      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 856         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 1.84e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 46           |
# |    episode_reward       | 14.8         |
# | time/                   |              |
# |    fps                  | 187          |
# |    iterations           | 46           |
# |    time_elapsed         | 502          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0075398833 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87e+03     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00763     |
# |    value_loss           | 3.73e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 47         |
# |    episode_reward       | 14.6       |
# | time/                   |            |
# |    fps                  | 187        |
# |    iterations           | 47         |
# |    time_elapsed         | 512        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01232475 |
# |    clip_fraction        | 0.0706     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.62      |
# |    explained_variance   | 0.165      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.12e+03   |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0075    |
# |    value_loss           | 8.02e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 48          |
# |    episode_reward       | 12.2        |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 48          |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008029014 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.22e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 9.75e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 49          |
# |    episode_reward       | 12          |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 49          |
# |    time_elapsed         | 533         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005295868 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 1.28e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 50           |
# |    episode_reward       | 8.37         |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 50           |
# |    time_elapsed         | 544          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0076377713 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.263        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+03     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00461     |
# |    value_loss           | 3.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 51          |
# |    episode_reward       | 11.1        |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 51          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.006632852 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.29e+03    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00391    |
# |    value_loss           | 1.12e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 52          |
# |    episode_reward       | 13.4        |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 52          |
# |    time_elapsed         | 565         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.005984076 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.13e+03    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00733    |
# |    value_loss           | 1.17e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 53          |
# |    episode_reward       | 18.1        |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 53          |
# |    time_elapsed         | 576         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.011429882 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39e+03    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00891    |
# |    value_loss           | 7.1e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 54           |
# |    episode_reward       | 54.2         |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 54           |
# |    time_elapsed         | 587          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0065843305 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.11e+03     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00595     |
# |    value_loss           | 6.94e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 55          |
# |    episode_reward       | 54          |
# | time/                   |             |
# |    fps                  | 188         |
# ...
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 180          |
# |    time_elapsed         | 1901         |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0050485265 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.19e+03     |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 1.18e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 181         |
# |    episode_reward       | 429         |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 181         |
# |    time_elapsed         | 1911        |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.005614481 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.12e+03    |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00412    |
# |    value_loss           | 1.18e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 182         |
# |    episode_reward       | 426         |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 182         |
# |    time_elapsed         | 1921        |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.006561283 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.44e+03    |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 8.55e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 183          |
# |    episode_reward       | 429          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 183          |
# |    time_elapsed         | 1931         |
# |    total_timesteps      | 374784       |
# | train/                  |              |
# |    approx_kl            | 0.0025944705 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.821       |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.22e+03     |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 9.52e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 184          |
# |    episode_reward       | 433          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 184          |
# |    time_elapsed         | 1941         |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0027285144 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.52e+03     |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 1.18e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 185          |
# |    episode_reward       | 434          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 185          |
# |    time_elapsed         | 1951         |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 0.0026852172 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.74e+03     |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 1.28e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 186         |
# |    episode_reward       | 464         |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 186         |
# |    time_elapsed         | 1961        |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.003887991 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.78e+03    |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00338    |
# |    value_loss           | 8.03e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 187          |
# |    episode_reward       | 463          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 187          |
# |    time_elapsed         | 1971         |
# |    total_timesteps      | 382976       |
# | train/                  |              |
# |    approx_kl            | 0.0052284813 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.13e+03     |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 8.16e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 188          |
# |    episode_reward       | 463          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 188          |
# |    time_elapsed         | 1981         |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0046539553 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.816       |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.07e+03     |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.00559     |
# |    value_loss           | 7.36e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 189         |
# |    episode_reward       | 463         |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 189         |
# |    time_elapsed         | 1991        |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.002671504 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.3e+03     |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 1.32e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 190          |
# |    episode_reward       | 462          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 190          |
# |    time_elapsed         | 2001         |
# |    total_timesteps      | 389120       |
# | train/                  |              |
# |    approx_kl            | 0.0039807255 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.799       |
# |    explained_variance   | 0.183        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.53e+03     |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 9.19e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 191          |
# |    episode_reward       | 461          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 191          |
# |    time_elapsed         | 2011         |
# |    total_timesteps      | 391168       |
# | train/                  |              |
# |    approx_kl            | 0.0021785223 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.809       |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.29e+03     |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 1.2e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 192          |
# |    episode_reward       | 460          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 192          |
# |    time_elapsed         | 2021         |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0026984212 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06e+03     |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 1.43e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 193         |
# |    episode_reward       | 460         |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 193         |
# |    time_elapsed         | 2031        |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.004197983 |
# |    clip_fraction        | 0.0285      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.49e+03    |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 1.4e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 194          |
# |    episode_reward       | 460          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 194          |
# |    time_elapsed         | 2040         |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 0.0023458144 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+04     |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 2.22e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 195         |
# |    episode_reward       | 455         |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 195         |
# |    time_elapsed         | 2050        |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.003627954 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+04    |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 2.21e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 196          |
# |    episode_reward       | 454          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 196          |
# |    time_elapsed         | 2059         |
# |    total_timesteps      | 401408       |
# | train/                  |              |
# |    approx_kl            | 0.0040580006 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.806       |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.13e+03     |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 1.92e+04     |
# ------------------------------------------
# Mean episode reward: 2.318296358008318
# Mean episode length: 1.0
# Cumulative reward: 454.3860861696303
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Balance: 100000
# Total Profit: 0
# Total Rewards: -3580.8136230248474
# Total Additional Rewards: 220.4999999999994
# Total Stability Bonus: -282.0836025017779
# profit: -3519.230020523069

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[0] for ticker in tickers]
test_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[1] for ticker in tickers]

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df_list)])

# 체크포인트 디렉토리 설정
checkpoint_dir = './Multi_management_HBI_GM_BXP/Checkpoint_0.35/'
checkpoint_files = [os.path.join(checkpoint_dir, f) for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]

results = []

# 각 체크포인트 평가
for checkpoint_file in checkpoint_files:
    model = PPO.load(checkpoint_file, env=test_env)

    obs = test_env.reset()
    total_rewards = 0
    total_additional_rewards = 0
    total_stability_bonus = 0
    done = False

    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = test_env.step(action)
        total_rewards += info[0]['reward']
        total_additional_rewards += info[0]['additional_reward']
        total_stability_bonus += info[0]['stability_bonus']

    results.append({
        'checkpoint': checkpoint_file,
        'total_rewards': total_rewards,
        'total_profit': total_rewards - total_additional_rewards - total_stability_bonus,
        'total_additional_rewards': total_additional_rewards,
        'total_stability_bonus': total_stability_bonus,
    })

# 결과 출력
for result in results:
    print(f"Checkpoint: {result['checkpoint']}")
    print(f"Total Rewards: {result['total_rewards']}")
    print(f"Total Additional Rewards: {result['total_additional_rewards']}")
    print(f"Total Stability Bonus: {result['total_stability_bonus']}")
    print(f"Total Profit: {result['total_profit']}")
    print("="*50)
# Out:
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_100000_steps.zip
# Total Rewards: -510.3072679283864
# Total Additional Rewards: 100.75
# Total Stability Bonus: -295.877282881999
# Total Profit: -315.1799850463874
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_120000_steps.zip
# Total Rewards: -733.7224863729738
# Total Additional Rewards: 113.5
# Total Stability Bonus: -290.6824897489813
# Total Profit: -556.5399966239925
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_140000_steps.zip
# Total Rewards: -487.43442533137403
# Total Additional Rewards: 118.0
# Total Stability Bonus: -302.4745003950793
# Total Profit: -302.9599249362948
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_160000_steps.zip
# Total Rewards: -166.73590167012193
# Total Additional Rewards: 121.75
# Total Stability Bonus: -243.98595865216242
# Total Profit: -44.49994301795954
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_180000_steps.zip
# Total Rewards: -529.2022051464833
# Total Additional Rewards: 130.25
# Total Stability Bonus: -297.9122237812795
# Total Profit: -361.53998136520374
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_200000_steps.zip
# Total Rewards: -512.3974265975925
# Total Additional Rewards: 129.25
# Total Stability Bonus: -282.9874124450657
# Total Profit: -358.6600141525268
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_20000_steps.zip
# Total Rewards: -327.227571064117
# Total Additional Rewards: 100.5
# Total Stability Bonus: -272.11757569897435
# Total Profit: -155.60999536514265
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_220000_steps.zip
# Total Rewards: -1005.032834827208
# Total Additional Rewards: 135.5
# Total Stability Bonus: -300.53281742265165
# Total Profit: -840.0000174045564
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_240000_steps.zip
# Total Rewards: -422.3826984759398
# Total Additional Rewards: 125.75
# Total Stability Bonus: -265.5926820632049
# Total Profit: -282.54001641273493
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_260000_steps.zip
# Total Rewards: -337.69205950552816
# Total Additional Rewards: 129.5
# Total Stability Bonus: -270.1220140343368
# Total Profit: -197.07004547119135
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_280000_steps.zip
# Total Rewards: -387.7433473424595
# Total Additional Rewards: 123.75
# Total Stability Bonus: -265.3833369569463
# Total Profit: -246.1100103855132
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_300000_steps.zip
# Total Rewards: -488.17179703802856
# Total Additional Rewards: 128.0
# Total Stability Bonus: -284.77183199019186
# Total Profit: -331.3999650478367
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_320000_steps.zip
# Total Rewards: -524.437896645629
# Total Additional Rewards: 126.5
# Total Stability Bonus: -282.42784730251924
# Total Profit: -368.5100493431098
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_340000_steps.zip
# Total Rewards: -524.4801414484483
# Total Additional Rewards: 130.5
# Total Stability Bonus: -280.6501129145128
# Total Profit: -374.3300285339355
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_360000_steps.zip
# Total Rewards: -588.3865595044524
# Total Additional Rewards: 130.75
# Total Stability Bonus: -295.9365432443053
# Total Profit: -423.2000162601471
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_380000_steps.zip
# Total Rewards: -495.55040144664815
# Total Additional Rewards: 132.5
# Total Stability Bonus: -272.79037141544393
# Total Profit: -355.2600300312042
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_400000_steps.zip
# Total Rewards: -389.870775934331
# Total Additional Rewards: 132.0
# Total Stability Bonus: -259.1107392274067
# Total Profit: -262.7600367069243
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_40000_steps.zip
# Total Rewards: -349.234717008731
# Total Additional Rewards: 101.25
# Total Stability Bonus: -290.55474889006325
# Total Profit: -159.92996811866777
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_60000_steps.zip
# Total Rewards: -537.7526492665154
# Total Additional Rewards: 100.5
# Total Stability Bonus: -287.832697589193
# Total Profit: -350.4199516773224
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.25/ppo_stock_trading_80000_steps.zip
# Total Rewards: -968.2280679936679
# Total Additional Rewards: 98.5
# Total Stability Bonus: -304.60804283574
# Total Profit: -762.120025157928
# ==================================================

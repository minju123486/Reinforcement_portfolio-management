# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library
from sklearn.model_selection import train_test_split

# 사용할 주식 티커 목록
tickers = ["HBI", "GM", "BXP"]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2018-01-01', end='2024-01-01')
    df.rename(columns={
        'Open': f'{ticker}_Open',
        'High': f'{ticker}_High',
        'Low': f'{ticker}_Low',
        'Close': f'{ticker}_Close',
        'Volume': f'{ticker}_Volume',
        'Adj Close': f'{ticker}_Adj_Close'
    }, inplace=True)
    df[f'{ticker}_ticker'] = ticker  # 티커 열 추가
    data[ticker] = df

# 데이터프레임을 동일한 날짜 인덱스로 결합
combined_df = pd.concat(data.values(), axis=1)

# 결합된 데이터프레임에 기술 지표 추가
for ticker in tickers:
    # 상대 강도 지수 (RSI: Relative Strength Index)
    combined_df[f'{ticker}_RSI'] = ta.momentum.RSIIndicator(combined_df[f'{ticker}_Close'], window=14).rsi()

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(combined_df[f'{ticker}_Close'], window=20, window_dev=2)
    combined_df[f'{ticker}_BB_High'] = bollinger.bollinger_hband()
    combined_df[f'{ticker}_BB_Low'] = bollinger.bollinger_lband()
    combined_df[f'{ticker}_BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    combined_df[f'{ticker}_RSI'].fillna(combined_df[f'{ticker}_RSI'].mean(), inplace=True)
    combined_df[f'{ticker}_BB_High'].fillna(combined_df[f'{ticker}_BB_High'].mean(), inplace=True)`
    combined_df[f'{ticker}_BB_Low'].fillna(combined_df[f'{ticker}_BB_Low'].mean(), inplace=True)
    combined_df[f'{ticker}_BB_Middle'].fillna(combined_df[f'{ticker}_BB_Middle'].mean(), inplace=True)

# 필요한 열 선택 (모든 feature 포함)
features = []
for ticker in tickers:
    features.extend([f'{ticker}_Open', f'{ticker}_High', f'{ticker}_Low', f'{ticker}_Close', f'{ticker}_Volume', f'{ticker}_RSI', f'{ticker}_BB_High', f'{ticker}_BB_Low', f'{ticker}_BB_Middle', f'{ticker}_ticker'])

combined_df = combined_df[features]

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df, test_df = train_test_split(combined_df, test_size=0.3, shuffle=False)

# 'Date'를 인덱스로 설정 (필요한 경우)
train_df.index.name = 'Date'
test_df.index.name = 'Date'

print("Train Set:")
print(train_df.head())
print("Test Set:")
print(test_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Train Set:
#              HBI_Open   HBI_High    HBI_Low  HBI_Close  HBI_Volume    HBI_RSI  \
# Date
# 2018-01-02  21.000000  21.639999  20.930000  21.299999     4906900  47.689706
# 2018-01-03  21.340000  21.459999  20.910000  21.030001     3093300  47.689706
# 2018-01-04  21.120001  21.290001  20.850000  21.260000     4158200  47.689706
# 2018-01-05  21.290001  21.350000  21.020000  21.230000     4362300  47.689706
# 2018-01-08  21.299999  21.840000  21.299999  21.600000     5278300  47.689706
#
#             HBI_BB_High  HBI_BB_Low  HBI_BB_Middle HBI_ticker  ...  \
# Date                                                           ...
# 2018-01-02    14.887307   12.554393       13.72085        HBI  ...
# 2018-01-03    14.887307   12.554393       13.72085        HBI  ...
# 2018-01-04    14.887307   12.554393       13.72085        HBI  ...
# 2018-01-05    14.887307   12.554393       13.72085        HBI  ...
# 2018-01-08    14.887307   12.554393       13.72085        HBI  ...
#
#               BXP_Open    BXP_High     BXP_Low   BXP_Close  BXP_Volume  \
# Date
# 2018-01-02  130.389999  130.389999  128.889999  129.279999      690000
# 2018-01-03  129.570007  129.800003  128.729996  129.350006      570600
# 2018-01-04  129.000000  129.000000  126.459999  126.480003     2079000
# 2018-01-05  126.830002  127.970001  126.519997  127.860001      860900
# 2018-01-08  127.540001  128.000000  125.820000  126.739998      724300
#
#               BXP_RSI  BXP_BB_High  BXP_BB_Low  BXP_BB_Middle BXP_ticker
# Date
# 2018-01-02  49.709772     109.5883   97.412739     103.500519        BXP
# 2018-01-03  49.709772     109.5883   97.412739     103.500519        BXP
# 2018-01-04  49.709772     109.5883   97.412739     103.500519        BXP
# 2018-01-05  49.709772     109.5883   97.412739     103.500519        BXP
# 2018-01-08  49.709772     109.5883   97.412739     103.500519        BXP
#
# [5 rows x 30 columns]
# Test Set:
#             HBI_Open  HBI_High  HBI_Low  HBI_Close  HBI_Volume    HBI_RSI  \
# Date
# 2022-03-14     15.63     15.79    15.05      15.16     3409900  45.354648
# 2022-03-15     15.10     15.33    14.69      14.89     5546000  42.454551
# 2022-03-16     14.95     15.67    14.95      15.33     7055700  48.260664
# 2022-03-17     15.31     15.35    15.07      15.30     4230000  47.905759
# 2022-03-18     15.02     15.47    14.91      15.39     9566500  49.114745
#
#             HBI_BB_High  HBI_BB_Low  HBI_BB_Middle HBI_ticker  ...  \
# Date                                                           ...
# 2022-03-14    15.922127   14.782873        15.3525        HBI  ...
# 2022-03-15    15.936891   14.729109        15.3330        HBI  ...
# 2022-03-16    15.925616   14.725384        15.3255        HBI  ...
# 2022-03-17    15.882347   14.729653        15.3060        HBI  ...
# 2022-03-18    15.890931   14.742069        15.3165        HBI  ...
#
#               BXP_Open    BXP_High     BXP_Low   BXP_Close  BXP_Volume  \
# Date
# 2022-03-14  124.669998  125.680000  122.239998  122.800003      876800
# 2022-03-15  123.470001  124.239998  121.419998  122.660004      674000
# 2022-03-16  124.120003  125.000000  121.410004  123.779999      760000
# 2022-03-17  123.269997  124.750000  122.879997  124.739998      536200
# 2022-03-18  124.339996  124.690002  122.589996  124.550003     1226100
#
#               BXP_RSI  BXP_BB_High  BXP_BB_Low  BXP_BB_Middle BXP_ticker
# Date
# 2022-03-14  55.073707   125.532769  118.051231     121.792000        BXP
# 2022-03-15  54.666765   125.098923  119.056078     122.077501        BXP
# 2022-03-16  57.379937   125.205755  119.337245     122.271500        BXP
# 2022-03-17  59.611250   125.504057  119.254943     122.379500        BXP
# 2022-03-18  58.953424   125.764101  119.247900     122.506001        BXP
#
# [5 rows x 30 columns]

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import configure
import torch
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

cumu_lst = []
cumu_hap = 0

class StockTradingEnv(gym.Env):
    global cumu_lst, cumu_hap
    metadata = {'render.modes': ['human']}

    def __init__(self, df_list, initial_balance=100000):
        super(StockTradingEnv, self).__init__()

        self.df_list = [df.drop(columns=[col for col in df.columns if 'ticker' in col]) for df in df_list]  # ticker 열 제거
        self.n_stocks = len(df_list)
        self.action_space = spaces.MultiDiscrete([3] * self.n_stocks)  # 각 주식에 대해 Buy, Hold, Sell
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.n_stocks, len(self.df_list[0].columns)), dtype=np.float32)

        self.initial_balance = initial_balance
        self.reset()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.total_profit = 0
        self.inventory = [[] for _ in range(self.n_stocks)]
        self.balance = self.initial_balance
        self.state = np.array([df.iloc[self.current_step].values for df in self.df_list])
        self.returns = [0]

        return self.state

    def step(self, action):
        global cumu_lst
        self.done = self.current_step >= len(self.df_list[0]) - 1
        reward = 0
        additional_reward = 0

        for i, act in enumerate(action):
            if act == 0 and not self.done:  # Buy
                if self.balance >= self.state[i][3]:  # Check if balance is sufficient to buy
                    self.inventory[i].append(self.state[i][3])  # Close price
                    self.balance -= self.state[i][3]

            elif act == 1 and not self.done:  # Sell
                if len(self.inventory[i]) > 0:
                    bought_price = self.inventory[i].pop(0)
                    reward += self.state[i][3] - bought_price  # Current price - Bought price
                    self.total_profit += reward
                    self.balance += self.state[i][3]

            # 추가된 보상 요소들
            if self.state[i][5] >= 70 and act == 1:  # RSI가 70 이상일 때 매도
                additional_reward += 0.225
            elif self.state[i][5] <= 30 and act == 0:  # RSI가 30 이하일 때 매수
                additional_reward += 0.225

            if self.state[i][3] >= self.state[i][6] and act == 1:  # 주가가 BB 상한선 이상일 때 매도
                additional_reward += 0.225
            elif self.state[i][3] <= self.state[i][7] and act == 0:  # 주가가 BB 하한선 이하일 때 매수
                additional_reward += 0.225

            if self.state[i][4] > self.df_list[i].iloc[:, 4].mean() and (act == 0 or act == 1):  # 거래량이 평균 이상일 때 매수 또는 매도
                additional_reward += 0.225

        total_reward = reward + additional_reward

        # Sharpe Ratio
        if len(self.returns) > 1:
            sharpe_ratio = np.mean(self.returns) / (np.std(self.returns) + 1e-10)
        else:
            sharpe_ratio = 0

        # Drawdown
        peak = np.max(self.returns)
        drawdown = peak - self.returns[-1]

        # 정규화된 Sharpe Ratio와 Drawdown
        normalized_sharpe = np.tanh(sharpe_ratio)  # -1에서 1 사이로 정규화
        normalized_drawdown = np.tanh(drawdown)  # -1에서 1 사이로 정규화

        # 스케일링 팩터
        sharpe_scale = 0.5
        drawdown_scale = 0.5

        # 보상 함수에 샤프 비율과 드로우다운 포함
        stability_bonus = sharpe_scale * normalized_sharpe - drawdown_scale * normalized_drawdown
        total_reward += stability_bonus

        # Update returns
        self.returns.append(total_reward)

        if not self.done:
            self.current_step += 1
            self.state = np.array([df.iloc[self.current_step].values for df in self.df_list])
        else:
            self.state = np.zeros(self.observation_space.shape)  # Done 상태에서 반환할 값
            cumu_lst.append(self.total_profit)
            self.total_profit = 0

        return self.state, total_reward, self.done, {"reward": total_reward, "additional_reward": additional_reward, "sharpe_ratio": sharpe_ratio, "drawdown": drawdown, "stability_bonus": stability_bonus}

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}, Balance: {self.balance}, Total Profit: {self.total_profit}, Sharpe Ratio: {np.mean(self.returns) / np.std(self.returns) if len(self.returns) > 1 else 0}, Drawdown: {(self.max_balance - self.balance) / self.max_balance}')

# %%
class EvalCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(EvalCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.action_distribution = []
        self.state_visit_frequency = {}
        self.cumulative_rewards = []  # 누적 보상을 저장하기 위한 리스트

    def _on_step(self) -> bool:
        # Record current step action for action distribution analysis
        actions = self.locals["actions"].flatten()  # Flatten actions to 1D
        self.action_distribution.extend(actions)
        
        # Record state visit frequency
        state_str = str(self.locals["new_obs"])
        if state_str in self.state_visit_frequency:
            self.state_visit_frequency[state_str] += 1
        else:
            self.state_visit_frequency[state_str] = 1
        return True

    def _on_rollout_end(self) -> None:
        # Log the reward and length for each episode
        episode_reward = sum(self.locals["rewards"])
        episode_length = len(self.locals["rewards"])
        self.episode_rewards.append(episode_reward)
        self.episode_lengths.append(episode_length)
        self.cumulative_rewards.append(sum(self.episode_rewards))  # 누적 보상을 추가
        self.logger.record('rollout/episode_reward', np.sum(self.episode_rewards))
        self.logger.record('rollout/episode_length', np.sum(self.episode_lengths))

    def _on_training_end(self) -> None:
        # Save evaluation results to file or print them
        print(f"Mean episode reward: {np.mean(self.episode_rewards)}")
        print(f"Mean episode length: {np.mean(self.episode_lengths)}")
        print(f"Cumulative reward: {np.sum(self.episode_rewards)}")

        # Plot action distribution
        plt.figure(figsize=(12, 6))
        plt.hist(self.action_distribution, bins=3, align='left', rwidth=0.8)
        plt.xticks(range(3), ['Buy', 'Hold', 'Sell'])
        plt.xlabel('Actions')
        plt.ylabel('Frequency')
        plt.title('Action Distribution')
        plt.show()

        # Plot episode rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.episode_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Episode Reward')
        plt.title('Episode Reward over Episodes')
        plt.show()

        # Plot cumulative rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.cumulative_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Cumulative Reward')
        plt.title('Cumulative Reward over Episodes')
        plt.show()

        # Plot state visit frequency
        state_visit_sorted = sorted(self.state_visit_frequency.items(), key=lambda item: item[1], reverse=True)
        states, visits = zip(*state_visit_sorted)
        plt.figure(figsize=(12, 6))
        plt.bar(states[:10], visits[:10])
        plt.xlabel('States')
        plt.ylabel('Visit Frequency')
        plt.title('Top 10 Most Visited States')
        plt.show()

# %%
# 학습 환경 설정
train_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[0] for ticker in tickers]
test_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[1] for ticker in tickers]

train_env = DummyVecEnv([lambda: StockTradingEnv(train_df_list)])

# CUDA 사용 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
log_dir = "./ppo_stock_trading_v11"
os.makedirs(log_dir, exist_ok=True)
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# PPO 모델 학습
from stable_baselines3.common.callbacks import CheckpointCallback

# 체크포인트 저장 콜백 설정 (예: 10000 타임스텝마다 저장)
checkpoint_callback = CheckpointCallback(save_freq=20000, save_path='./Multi_management_HBI_GM_BXP/Checkpoint_0.225/', name_prefix='ppo_stock_trading')

# PPO 모델 학습
model = PPO('MlpPolicy', train_env, verbose=1, device=device)
model.set_logger(new_logger)
model.learn(total_timesteps=400000, callback=[checkpoint_callback, EvalCallback()])

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df_list)])

# 학습된 모델로 예측 및 결과 시각화
obs = test_env.reset()
total_rewards = 0
total_additional_rewards = 0
total_stability_bonus = 0

for _ in range(len(test_df_list[0])):
    action, _states = model.predict(obs)
    obs, rewards, done, info = test_env.step(action)
    total_rewards += info[0]['reward']
    total_additional_rewards += info[0]['additional_reward']
    total_stability_bonus += info[0]['stability_bonus']
    test_env.render()
    if done:
        break

print(f"Final Balance: {test_env.get_attr('balance')[0]}")
print(f"Total Profit: {test_env.get_attr('total_profit')[0]}")
print(f"Total Rewards: {total_rewards}")
print(f"Total Additional Rewards: {total_additional_rewards}")
print(f"Total Stability Bonus: {total_stability_bonus}")
print(f"profit: {total_rewards - total_additional_rewards - total_stability_bonus}")
# Out:
# Logging to ./ppo_stock_trading_v11
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    episode_length  | 1        |
# |    episode_reward  | -0.531   |
# | time/              |          |
# |    fps             | 255      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 2           |
# |    episode_reward       | -1.09       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 2           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009578214 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | -0.000702   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.97e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00791    |
# |    value_loss           | 7.7e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 3           |
# |    episode_reward       | -1.37       |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 3           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010829407 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.0138      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.31e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 4.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 4           |
# |    episode_reward       | 17.6        |
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 4           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010265051 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.026       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.75e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 1.07e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 5           |
# |    episode_reward       | 37.5        |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 5           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008453513 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.0825      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 771         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 2.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 6           |
# |    episode_reward       | -22.8       |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 6           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008472517 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.068       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.79e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00637    |
# |    value_loss           | 1.07e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 7            |
# |    episode_reward       | -23.1        |
# | time/                   |              |
# |    fps                  | 178          |
# |    iterations           | 7            |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0048569823 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.24        |
# |    explained_variance   | 0.0784       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09e+04     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 1.44e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 8           |
# |    episode_reward       | -29.8       |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 8           |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007624246 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.38e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00634    |
# |    value_loss           | 7.79e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 9           |
# |    episode_reward       | -30.3       |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 9           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006288372 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.0835      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.48e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 1.28e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 10          |
# |    episode_reward       | -30.7       |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 10          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010658173 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.096       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2e+04     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00876    |
# |    value_loss           | 3.55e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 11          |
# |    episode_reward       | -30.8       |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 11          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009777844 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00681    |
# |    value_loss           | 1.68e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 12           |
# |    episode_reward       | -27.5        |
# | time/                   |              |
# |    fps                  | 170          |
# |    iterations           | 12           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0072212066 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39e+04     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00615     |
# |    value_loss           | 3.26e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 13          |
# |    episode_reward       | -28.1       |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 13          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008128829 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 2.39e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 14          |
# |    episode_reward       | -19.2       |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 14          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009652169 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.3e+04     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00527    |
# |    value_loss           | 4.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 15          |
# |    episode_reward       | -19.5       |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 15          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009982735 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00921    |
# |    value_loss           | 3.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 16          |
# |    episode_reward       | -19.3       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 16          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006942248 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.81e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 1.31e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 17           |
# |    episode_reward       | -19.6        |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 17           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0077974647 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8e+03        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00554     |
# |    value_loss           | 1.62e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 18          |
# |    episode_reward       | -20.1       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 18          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009272803 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.28e+04    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00819    |
# |    value_loss           | 3.05e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 19          |
# |    episode_reward       | -8.56       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 19          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006828089 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.55e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 2.34e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 20          |
# |    episode_reward       | 12.9        |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 20          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007925355 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.81e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 1.54e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 21           |
# |    episode_reward       | 19           |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 21           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0068353256 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.32e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00565     |
# |    value_loss           | 1.46e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 22          |
# |    episode_reward       | 22.9        |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 22          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008100418 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.9e+03     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00619    |
# |    value_loss           | 1.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 23          |
# |    episode_reward       | -20.1       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 23          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010017054 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.25e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 1.22e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 24          |
# |    episode_reward       | -42.5       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 24          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007551866 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.0758      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+04    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 1.83e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 25           |
# |    episode_reward       | -39.4        |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 25           |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0076203416 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 0.05         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.49e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00712     |
# |    value_loss           | 1.55e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 26          |
# |    episode_reward       | -31.9       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 26          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009340804 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.0778      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.69e+04    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00917    |
# |    value_loss           | 2.41e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 27          |
# |    episode_reward       | -34.8       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 27          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008275499 |
# |    clip_fraction        | 0.0841      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.97e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00783    |
# |    value_loss           | 1.63e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 28          |
# |    episode_reward       | -29.2       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 28          |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008168699 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00644    |
# |    value_loss           | 2.72e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 29           |
# |    episode_reward       | -32.1        |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 29           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0087824855 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.13        |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.27e+04     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0075      |
# |    value_loss           | 2.96e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 30          |
# |    episode_reward       | -33.3       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 30          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007449844 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.07e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 1.71e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 31          |
# |    episode_reward       | -33.8       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 31          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011328405 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.68e+03    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 1.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 32          |
# |    episode_reward       | -34.6       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 32          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009129917 |
# |    clip_fraction        | 0.0735      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0083     |
# |    value_loss           | 1.88e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 33           |
# |    episode_reward       | -35.2        |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 33           |
# |    time_elapsed         | 409          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0046394756 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.08        |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.97e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 1.7e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 34           |
# |    episode_reward       | -35.8        |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 34           |
# |    time_elapsed         | 422          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0067115324 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | 0.0246       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.24e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00418     |
# |    value_loss           | 1.36e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 35          |
# |    episode_reward       | -67.2       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 35          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011558768 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | -0.0206     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.83e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0091     |
# |    value_loss           | 9.63e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 36           |
# |    episode_reward       | -63.4        |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 36           |
# |    time_elapsed         | 447          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0093974685 |
# |    clip_fraction        | 0.0859       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | -0.0182      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.42e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 8.8e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 37          |
# |    episode_reward       | -62.1       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 37          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010456819 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.00696     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5e+03     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 5.82e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 38          |
# |    episode_reward       | -62.4       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 38          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010891046 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.18e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 5.97e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 39         |
# |    episode_reward       | -85.8      |
# | time/                   |            |
# |    fps                  | 164        |
# |    iterations           | 39         |
# |    time_elapsed         | 485        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01169134 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3         |
# |    explained_variance   | 0.0187     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.77e+03   |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00991   |
# |    value_loss           | 3.17e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 40          |
# |    episode_reward       | -85.9       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 40          |
# |    time_elapsed         | 497         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010051435 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.00921     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 892         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 2.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 41          |
# |    episode_reward       | -85.9       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 41          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008935734 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.0248      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 42          |
# |    episode_reward       | -87.2       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 42          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008729282 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.0159      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 806         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 1.78e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 43          |
# |    episode_reward       | -91.1       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 43          |
# |    time_elapsed         | 533         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011178656 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.0157      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 706         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 1.71e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 44           |
# |    episode_reward       | -92.7        |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 44           |
# |    time_elapsed         | 545          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0071266615 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | 0.0215       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 644          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00677     |
# |    value_loss           | 2.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 45           |
# |    episode_reward       | -75.8        |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 45           |
# |    time_elapsed         | 558          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0082429685 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.00419      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 821          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00933     |
# |    value_loss           | 1.63e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 46           |
# |    episode_reward       | -76.4        |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 46           |
# |    time_elapsed         | 570          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0073444895 |
# |    clip_fraction        | 0.0849       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.025        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 437          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0073      |
# |    value_loss           | 1.53e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 47          |
# |    episode_reward       | -80.1       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 47          |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008708053 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 254         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00986    |
# |    value_loss           | 1.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 48          |
# |    episode_reward       | -82.5       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 48          |
# |    time_elapsed         | 594         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007291875 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.0214      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0068     |
# |    value_loss           | 2.33e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 49        |
# |    episode_reward       | -83       |
# | time/                   |           |
# |    fps                  | 165       |
# |    iterations           | 49        |
# |    time_elapsed         | 607       |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.0070233 |
# |    clip_fraction        | 0.0417    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.89     |
# |    explained_variance   | 0.0298    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.41e+03  |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -0.00436  |
# |    value_loss           | 2.03e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 50         |
# |    episode_reward       | -83.1      |
# | time/                   |            |
# |    fps                  | 165        |
# |    iterations           | 50         |
# |    time_elapsed         | 619        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01123355 |
# |    clip_fraction        | 0.0927     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.9       |
# |    explained_variance   | 0.00825    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 400        |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00691   |
# |    value_loss           | 1.33e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 51          |
# |    episode_reward       | -85.2       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 51          |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.010009091 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.0097      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 736         |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00963    |
# |    value_loss           | 1.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 52          |
# |    episode_reward       | -85.7       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 52          |
# |    time_elapsed         | 643         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010559297 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.0269      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 920         |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 1.89e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 53          |
# |    episode_reward       | -85.4       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 53          |
# |    time_elapsed         | 655         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.009046063 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.0476      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92e+03    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 3.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 54          |
# |    episode_reward       | -70.3       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 54          |
# |    time_elapsed         | 668         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.006807032 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.0842      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95e+03    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00438    |
# |    value_loss           | 4.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 55          |
# |    episode_reward       | -70.8       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 55          |
# |    time_elapsed         | 680         |
# ...
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 180        |
# |    episode_reward       | 100        |
# | time/                   |            |
# |    fps                  | 166        |
# |    iterations           | 180        |
# |    time_elapsed         | 2209       |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.00559508 |
# |    clip_fraction        | 0.0665     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.0684     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 608        |
# |    n_updates            | 1790       |
# |    policy_gradient_loss | -0.00448   |
# |    value_loss           | 1.74e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 181         |
# |    episode_reward       | 100         |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 181         |
# |    time_elapsed         | 2222        |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.008429924 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.055       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 999         |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00505    |
# |    value_loss           | 2.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 182         |
# |    episode_reward       | 99.7        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 182         |
# |    time_elapsed         | 2235        |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.006874675 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0578      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 1.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 183         |
# |    episode_reward       | 99.1        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 183         |
# |    time_elapsed         | 2247        |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.009459877 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.0528      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 619         |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.00911    |
# |    value_loss           | 1.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 184         |
# |    episode_reward       | 98.8        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 184         |
# |    time_elapsed         | 2259        |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.005852298 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0749      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.0038     |
# |    value_loss           | 1.78e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 185         |
# |    episode_reward       | 98.5        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 185         |
# |    time_elapsed         | 2273        |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.004213026 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0572      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 910         |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 1.73e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 186          |
# |    episode_reward       | 98.9         |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 186          |
# |    time_elapsed         | 2285         |
# |    total_timesteps      | 380928       |
# | train/                  |              |
# |    approx_kl            | 0.0037693924 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.0527       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 732          |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 2.24e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 187         |
# |    episode_reward       | 98.4        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 187         |
# |    time_elapsed         | 2297        |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.007469055 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0487      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00508    |
# |    value_loss           | 2.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 188         |
# |    episode_reward       | 71          |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 188         |
# |    time_elapsed         | 2309        |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.005488352 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0642      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 667         |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00555    |
# |    value_loss           | 1.72e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 189          |
# |    episode_reward       | 70.8         |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 189          |
# |    time_elapsed         | 2321         |
# |    total_timesteps      | 387072       |
# | train/                  |              |
# |    approx_kl            | 0.0061283647 |
# |    clip_fraction        | 0.0821       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.0649       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 903          |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00569     |
# |    value_loss           | 1.81e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 190         |
# |    episode_reward       | 70.3        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 190         |
# |    time_elapsed         | 2333        |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.010152947 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.0835      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 611         |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 191         |
# |    episode_reward       | 68.1        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 191         |
# |    time_elapsed         | 2345        |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.007973598 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0924      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 621         |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.006      |
# |    value_loss           | 1.07e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 192          |
# |    episode_reward       | 62.3         |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 192          |
# |    time_elapsed         | 2357         |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0070667258 |
# |    clip_fraction        | 0.0587       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.0617       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 867          |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00445     |
# |    value_loss           | 1.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 193         |
# |    episode_reward       | 61.9        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 193         |
# |    time_elapsed         | 2369        |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.009582344 |
# |    clip_fraction        | 0.0868      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0614      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 959         |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00825    |
# |    value_loss           | 1.61e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    episode_length       | 194        |
# |    episode_reward       | 61.7       |
# | time/                   |            |
# |    fps                  | 166        |
# |    iterations           | 194        |
# |    time_elapsed         | 2381       |
# |    total_timesteps      | 397312     |
# | train/                  |            |
# |    approx_kl            | 0.00782329 |
# |    clip_fraction        | 0.0833     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.058      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 775        |
# |    n_updates            | 1930       |
# |    policy_gradient_loss | -0.00517   |
# |    value_loss           | 1.63e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 195          |
# |    episode_reward       | 58.5         |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 195          |
# |    time_elapsed         | 2393         |
# |    total_timesteps      | 399360       |
# | train/                  |              |
# |    approx_kl            | 0.0031132507 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.0521       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2e+03      |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 1.6e+03      |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 196       |
# |    episode_reward       | 59.3      |
# | time/                   |           |
# |    fps                  | 166       |
# |    iterations           | 196       |
# |    time_elapsed         | 2406      |
# |    total_timesteps      | 401408    |
# | train/                  |           |
# |    approx_kl            | 0.0094632 |
# |    clip_fraction        | 0.118     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.26     |
# |    explained_variance   | 0.056     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 851       |
# |    n_updates            | 1950      |
# |    policy_gradient_loss | -0.00665  |
# |    value_loss           | 1.82e+03  |
# ---------------------------------------
# Mean episode reward: 0.3026041227089341
# Mean episode length: 1.0
# Cumulative reward: 59.31040805095108
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Balance: 100000
# Total Profit: 0
# Total Rewards: -2915.395973354628
# Total Additional Rewards: 113.17499999999973
# Total Stability Bonus: -256.7209484160445
# profit: -2771.8500249385834

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[0] for ticker in tickers]
test_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[1] for ticker in tickers]

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df_list)])

# 체크포인트 디렉토리 설정
checkpoint_dir = './Multi_management_HBI_GM_BXP/Checkpoint_0.225/'
checkpoint_files = [os.path.join(checkpoint_dir, f) for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]

results = []

# 각 체크포인트 평가
for checkpoint_file in checkpoint_files:
    model = PPO.load(checkpoint_file, env=test_env)

    obs = test_env.reset()
    total_rewards = 0
    total_additional_rewards = 0
    total_stability_bonus = 0
    done = False

    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = test_env.step(action)
        total_rewards += info[0]['reward']
        total_additional_rewards += info[0]['additional_reward']
        total_stability_bonus += info[0]['stability_bonus']

    results.append({
        'checkpoint': checkpoint_file,
        'total_rewards': total_rewards,
        'total_profit': total_rewards - total_additional_rewards - total_stability_bonus,
        'total_additional_rewards': total_additional_rewards,
        'total_stability_bonus': total_stability_bonus,
    })

# 결과 출력
for result in results:
    print(f"Checkpoint: {result['checkpoint']}")
    print(f"Total Rewards: {result['total_rewards']}")
    print(f"Total Additional Rewards: {result['total_additional_rewards']}")
    print(f"Total Stability Bonus: {result['total_stability_bonus']}")
    print(f"Total Profit: {result['total_profit']}")
    print("="*50)
# Out:
# C:\Users\Joker\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_100000_steps.zip
# Total Rewards: -2452.988045697421
# Total Additional Rewards: 95.1749999999999
# Total Stability Bonus: -286.6530228187745
# Total Profit: -2261.5100228786464
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_120000_steps.zip
# Total Rewards: -2523.268473836321
# Total Additional Rewards: 105.5249999999998
# Total Stability Bonus: -278.82344686641005
# Total Profit: -2349.9700269699106
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_140000_steps.zip
# Total Rewards: -3159.8334190724813
# Total Additional Rewards: 107.32499999999975
# Total Stability Bonus: -288.278438746782
# Total Profit: -2978.8799803256993
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_160000_steps.zip
# Total Rewards: -2821.2315415773087
# Total Additional Rewards: 108.67499999999984
# Total Stability Bonus: -275.6565070066137
# Total Profit: -2654.250034570695
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_180000_steps.zip
# Total Rewards: -2796.3945209620724
# Total Additional Rewards: 103.27499999999984
# Total Stability Bonus: -279.5895367739921
# Total Profit: -2620.07998418808
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_200000_steps.zip
# Total Rewards: -3239.2369239999703
# Total Additional Rewards: 113.62499999999984
# Total Stability Bonus: -294.3119173719323
# Total Profit: -3058.550006628038
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_20000_steps.zip
# Total Rewards: -925.6375656981846
# Total Additional Rewards: 109.57499999999982
# Total Stability Bonus: -312.0526104350471
# Total Profit: -723.1599552631372
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_220000_steps.zip
# Total Rewards: -3104.8181756284393
# Total Additional Rewards: 112.04999999999976
# Total Stability Bonus: -254.7881540086423
# Total Profit: -2962.0800216197968
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_240000_steps.zip
# Total Rewards: -2778.987337626481
# Total Additional Rewards: 107.32499999999978
# Total Stability Bonus: -287.3623592748909
# Total Profit: -2598.94997835159
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_260000_steps.zip
# Total Rewards: -3033.519071370335
# Total Additional Rewards: 108.44999999999987
# Total Stability Bonus: -287.2090670883346
# Total Profit: -2854.7600042820004
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_280000_steps.zip
# Total Rewards: -3102.4482351392985
# Total Additional Rewards: 114.29999999999974
# Total Stability Bonus: -265.6382013887618
# Total Profit: -2951.1100337505363
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_300000_steps.zip
# Total Rewards: -2803.471896980006
# Total Additional Rewards: 113.6249999999997
# Total Stability Bonus: -260.51687178392973
# Total Profit: -2656.580025196076
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_320000_steps.zip
# Total Rewards: -3184.894208354776
# Total Additional Rewards: 111.8249999999997
# Total Stability Bonus: -261.6991878698563
# Total Profit: -3035.0200204849193
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_340000_steps.zip
# Total Rewards: -3017.885843854458
# Total Additional Rewards: 116.3249999999997
# Total Stability Bonus: -263.74081163934113
# Total Profit: -2870.4700322151166
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_360000_steps.zip
# Total Rewards: -2955.234643989418
# Total Additional Rewards: 122.6249999999997
# Total Stability Bonus: -258.7796106871099
# Total Profit: -2819.080033302308
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_380000_steps.zip
# Total Rewards: -2795.9098781384996
# Total Additional Rewards: 115.19999999999972
# Total Stability Bonus: -252.65982015510207
# Total Profit: -2658.4500579833975
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_400000_steps.zip
# Total Rewards: -3390.5427468086336
# Total Additional Rewards: 116.5499999999998
# Total Stability Bonus: -296.2427404667002
# Total Profit: -3210.8500063419333
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_40000_steps.zip
# Total Rewards: -1138.9075736708778
# Total Additional Rewards: 97.87499999999986
# Total Stability Bonus: -308.7925033278618
# Total Profit: -927.9900703430158
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_60000_steps.zip
# Total Rewards: -1155.6938848113891
# Total Additional Rewards: 98.99999999999989
# Total Stability Bonus: -313.9338829135775
# Total Profit: -940.7600018978117
# ==================================================
# Checkpoint: ./Multi_management_HBI_GM_BXP/Checkpoint_0.225/ppo_stock_trading_80000_steps.zip
# Total Rewards: -2265.6082666976417
# Total Additional Rewards: 97.19999999999983
# Total Stability Bonus: -290.0282631499728
# Total Profit: -2072.780003547669
# ==================================================
